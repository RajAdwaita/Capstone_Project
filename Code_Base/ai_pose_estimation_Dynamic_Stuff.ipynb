# %%
# !pip install mediapipe opencv-python
# Out:
# Requirement already satisfied: mediapipe in c:\users\user\anaconda3\envs\tens_old\lib\site-packages (0.10.11)
# Requirement already satisfied: opencv-python in c:\users\user\anaconda3\envs\tens_old\lib\site-packages (4.9.0.80)
# Requirement already satisfied: absl-py in c:\users\user\anaconda3\envs\tens_old\lib\site-packages (from mediapipe) (2.1.0)
# Requirement already satisfied: attrs>=19.1.0 in c:\users\user\anaconda3\envs\tens_old\lib\site-packages (from mediapipe) (23.1.0)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\user\anaconda3\envs\tens_old\lib\site-packages (from mediapipe) (24.3.25)
# Requirement already satisfied: jax in c:\users\user\anaconda3\envs\tens_old\lib\site-packages (from mediapipe) (0.4.13)
# Requirement already satisfied: matplotlib in c:\users\user\anaconda3\envs\tens_old\lib\site-packages (from mediapipe) (3.7.5)
# Requirement already satisfied: numpy in c:\users\user\appdata\roaming\python\python38\site-packages (from mediapipe) (1.22.4)
# Requirement already satisfied: opencv-contrib-python in c:\users\user\anaconda3\envs\tens_old\lib\site-packages (from mediapipe) (4.9.0.80)
# Requirement already satisfied: protobuf<4,>=3.11 in c:\users\user\anaconda3\envs\tens_old\lib\site-packages (from mediapipe) (3.20.3)
# Requirement already satisfied: sounddevice>=0.4.4 in c:\users\user\anaconda3\envs\tens_old\lib\site-packages (from mediapipe) (0.4.6)
# Requirement already satisfied: CFFI>=1.0 in c:\users\user\anaconda3\envs\tens_old\lib\site-packages (from sounddevice>=0.4.4->mediapipe) (1.16.0)
# Requirement already satisfied: ml-dtypes>=0.1.0 in c:\users\user\anaconda3\envs\tens_old\lib\site-packages (from jax->mediapipe) (0.2.0)
# Requirement already satisfied: opt-einsum in c:\users\user\anaconda3\envs\tens_old\lib\site-packages (from jax->mediapipe) (3.3.0)
# Requirement already satisfied: scipy>=1.7 in c:\users\user\anaconda3\envs\tens_old\lib\site-packages (from jax->mediapipe) (1.10.1)
# Requirement already satisfied: importlib-metadata>=4.6 in c:\users\user\anaconda3\envs\tens_old\lib\site-packages (from jax->mediapipe) (7.0.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\user\anaconda3\envs\tens_old\lib\site-packages (from matplotlib->mediapipe) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\user\anaconda3\envs\tens_old\lib\site-packages (from matplotlib->mediapipe) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\user\anaconda3\envs\tens_old\lib\site-packages (from matplotlib->mediapipe) (4.50.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\user\anaconda3\envs\tens_old\lib\site-packages (from matplotlib->mediapipe) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\user\anaconda3\envs\tens_old\lib\site-packages (from matplotlib->mediapipe) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\user\anaconda3\envs\tens_old\lib\site-packages (from matplotlib->mediapipe) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\user\anaconda3\envs\tens_old\lib\site-packages (from matplotlib->mediapipe) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\user\anaconda3\envs\tens_old\lib\site-packages (from matplotlib->mediapipe) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\user\anaconda3\envs\tens_old\lib\site-packages (from matplotlib->mediapipe) (6.1.1)
# Requirement already satisfied: pycparser in c:\users\user\anaconda3\envs\tens_old\lib\site-packages (from CFFI>=1.0->sounddevice>=0.4.4->mediapipe) (2.21)
# Requirement already satisfied: zipp>=0.5 in c:\users\user\anaconda3\envs\tens_old\lib\site-packages (from importlib-metadata>=4.6->jax->mediapipe) (3.17.0)
# Requirement already satisfied: six>=1.5 in c:\users\user\anaconda3\envs\tens_old\lib\site-packages (from python-dateutil>=2.7->matplotlib->mediapipe) (1.16.0)

# %%
from pydub import AudioSegment
from pydub.playback import play

# %%
import cv2
import mediapipe as mp
import numpy as np
mp_drawing = mp.solutions.drawing_utils
mp_pose = mp.solutions.pose

# %%
# VIDEO FEED

cap = cv2.VideoCapture(0)
while cap.isOpened():
    ret, frame = cap.read()
    cv2.imshow('MediaPipe Feed', frame)
    
    if cv2.waitKey(10) & 0xFF == ord('q'):
        break
cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# # PHOTOS

# %%
import cv2
import mediapipe as mp
import matplotlib.pyplot as plt

# %%
# Initialize mediapipe pose class.
mp_pose = mp.solutions.pose

# Setup the Pose function for images - independently for the images standalone processing.
pose_image = mp_pose.Pose(static_image_mode=True, min_detection_confidence=0.5)



# Initialize mediapipe drawing class - to draw the landmarks points.
mp_drawing = mp.solutions.drawing_utils

# %% [markdown]
# # adho mukha svanasana

# %%
import os
from PIL import Image

# Folder path containing images
folder_path = "E:/capstone/Dataset/possible_Ones/adho mukha svanasana"





# List to store image paths
image_paths = []

# Iterate over files in the folder
for filename in os.listdir(folder_path):
    # Check if the file is an image (you might want to add more image extensions)
    if filename.endswith(".jpg") or filename.endswith(".png"):
        # Construct the full file path
        file_path = os.path.join(folder_path, filename)
        # Append the file path to the list
        file_path.replace("\\",'/')
        image_paths.append(file_path)

# %%
image_paths
# Out:
# ['E:/capstone/Dataset/possible_Ones/adho mukha svanasana\\1. 1.png',
#  'E:/capstone/Dataset/possible_Ones/adho mukha svanasana\\1. 5-benefits-of-downward-facing-dog-pose.png',
#  'E:/capstone/Dataset/possible_Ones/adho mukha svanasana\\10. screen-shot-2017-09-15-at-17.00.06-1024x585.png',
#  'E:/capstone/Dataset/possible_Ones/adho mukha svanasana\\11. yoga_anatomy_using_muscle_awareness_to_lower_your_heels_in_downward_facing_dog_pose.png',
#  'E:/capstone/Dataset/possible_Ones/adho mukha svanasana\\12. 66a62b8c606fd88e0401b5af0a7cbca7.png',
#  'E:/capstone/Dataset/possible_Ones/adho mukha svanasana\\12. downward-facing-dog-pose.png',
#  'E:/capstone/Dataset/possible_Ones/adho mukha svanasana\\13. downward-facing-dog-800x490.png',
#  'E:/capstone/Dataset/possible_Ones/adho mukha svanasana\\14. downward-dog-pose-as-done-by-a-dog.png',
#  'E:/capstone/Dataset/possible_Ones/adho mukha svanasana\\14. untitled_design_33.png',
#  'E:/capstone/Dataset/possible_Ones/adho mukha svanasana\\16. one-leg-downward-facing-dog-yoga-pose.png',
#  'E:/capstone/Dataset/possible_Ones/adho mukha svanasana\\17. screen_shot_2014-03-20_at_2.05.15_pm.png',
#  'E:/capstone/Dataset/possible_Ones/adho mukha svanasana\\18. screenshot_20180504-085613-450x800.png',
#  'E:/capstone/Dataset/possible_Ones/adho mukha svanasana\\19. 1-adho-mukha-svanasana.png',
#  'E:/capstone/Dataset/possible_Ones/adho mukha svanasana\\2. screen-shot-2017-09-15-at-17.00.06-1024x585.png',
#  'E:/capstone/Dataset/possible_Ones/adho mukha svanasana\\21. adho-mukha-svanasana.png',
#  'E:/capstone/Dataset/possible_Ones/adho mukha svanasana\\22. photo-17-05-2015-18-28-30.png',
#  'E:/capstone/Dataset/possible_Ones/adho mukha svanasana\\23. george7.png',
#  'E:/capstone/Dataset/possible_Ones/adho mukha svanasana\\24. dsc_1007-resized-600.jpg',
#  'E:/capstone/Dataset/possible_Ones/adho mukha svanasana\\25. 11.png',
#  'E:/capstone/Dataset/possible_Ones/adho mukha svanasana\\28. screen-shot-2017-10-30-at-2.24.06-pm.png',
#  'E:/capstone/Dataset/possible_Ones/adho mukha svanasana\\29. adho-mukha-svanasana.png',
#  'E:/capstone/Dataset/possible_Ones/adho mukha svanasana\\3. downward-facing-dog-pose-567x567.png',
#  'E:/capstone/Dataset/possible_Ones/adho mukha svanasana\\32. 1473984207.png',
#  'E:/capstone/Dataset/possible_Ones/adho mukha svanasana\\32. down_dog_orthocarolina_winston.png',
#  'E:/capstone/Dataset/possible_Ones/adho mukha svanasana\\33. screenshot_2015-02-10-12-04-46.png',
#  'E:/capstone/Dataset/possible_Ones/adho mukha svanasana\\34. adho-mukha-svanasana.png',
#  'E:/capstone/Dataset/possible_Ones/adho mukha svanasana\\35. 068155f5a8d0310c34a6ed06cb089294.png',
#  'E:/capstone/Dataset/possible_Ones/adho mukha svanasana\\36. downward-facing-dog-800x490.png',
#  'E:/capstone/Dataset/possible_Ones/adho mukha svanasana\\39. screen-shot-2019-01-02-at-5.02.56-pm.png',
#  'E:/capstone/Dataset/possible_Ones/adho mukha svanasana\\39. untitled10.png',
#  'E:/capstone/Dataset/possible_Ones/adho mukha svanasana\\4. adho-mukha-svanasana-downward-dog-pose.png',
#  'E:/capstone/Dataset/possible_Ones/adho mukha svanasana\\4. downward-facing-dog.png',
#  'E:/capstone/Dataset/possible_Ones/adho mukha svanasana\\42. img_1199.png',
#  'E:/capstone/Dataset/possible_Ones/adho mukha svanasana\\43. downward-facing-dog-reboot-1.png',
#  'E:/capstone/Dataset/possible_Ones/adho mukha svanasana\\43. down_dog.png',
#  'E:/capstone/Dataset/possible_Ones/adho mukha svanasana\\45. 3_alignment_instructions_to_reconsider.png',
#  'E:/capstone/Dataset/possible_Ones/adho mukha svanasana\\46. yoga7b-754x394.png',
#  'E:/capstone/Dataset/possible_Ones/adho mukha svanasana\\47. downward-facing-dog-520x400.png',
#  'E:/capstone/Dataset/possible_Ones/adho mukha svanasana\\47. downward-facing-dog.png',
#  'E:/capstone/Dataset/possible_Ones/adho mukha svanasana\\49. adho-mukha-svanasana-768x429.png',
#  'E:/capstone/Dataset/possible_Ones/adho mukha svanasana\\5. f3949d27c6de7f86a293f207a49e1cf4.png',
#  'E:/capstone/Dataset/possible_Ones/adho mukha svanasana\\50. blog-14-size.png',
#  'E:/capstone/Dataset/possible_Ones/adho mukha svanasana\\51. screenshot_20180409-154224.png',
#  'E:/capstone/Dataset/possible_Ones/adho mukha svanasana\\54. bc56388aad161f17b93f5fb21faeddca.png',
#  'E:/capstone/Dataset/possible_Ones/adho mukha svanasana\\55. screen+shot+2017-12-13+at+9.12.42+am.png',
#  'E:/capstone/Dataset/possible_Ones/adho mukha svanasana\\56. dd2.png',
#  'E:/capstone/Dataset/possible_Ones/adho mukha svanasana\\59. 1511793208433233.png',
#  'E:/capstone/Dataset/possible_Ones/adho mukha svanasana\\60. adho-mukha-svanasana-downward-dog.png',
#  'E:/capstone/Dataset/possible_Ones/adho mukha svanasana\\62. dog-base.png',
#  'E:/capstone/Dataset/possible_Ones/adho mukha svanasana\\63. downward-facing-dog-yoga-pose-2.png',
#  'E:/capstone/Dataset/possible_Ones/adho mukha svanasana\\67. downward-facing-dog-adho-mukha-svanasana.png',
#  'E:/capstone/Dataset/possible_Ones/adho mukha svanasana\\7. 23-downward-facing-dog.png',
#  'E:/capstone/Dataset/possible_Ones/adho mukha svanasana\\7. downward-facing-dog-yoga-pose-adjustment-adho-mukha-svanasana.png',
#  'E:/capstone/Dataset/possible_Ones/adho mukha svanasana\\72. ff-4.png',
#  'E:/capstone/Dataset/possible_Ones/adho mukha svanasana\\72.png',
#  'E:/capstone/Dataset/possible_Ones/adho mukha svanasana\\73. d0c097f5131a546a004be3f0045aa074.png',
#  'E:/capstone/Dataset/possible_Ones/adho mukha svanasana\\76. tri-pada-adho-mukha-svanasana1.png',
#  'E:/capstone/Dataset/possible_Ones/adho mukha svanasana\\8. benefits-of-downward-dog_orig.png',
#  'E:/capstone/Dataset/possible_Ones/adho mukha svanasana\\80. down-dog-in-stowe-vt-blog-1.png',
#  'E:/capstone/Dataset/possible_Ones/adho mukha svanasana\\81. untitled1.png',
#  'E:/capstone/Dataset/possible_Ones/adho mukha svanasana\\83. downward-dog_final_rev2.png',
#  'E:/capstone/Dataset/possible_Ones/adho mukha svanasana\\85. adhomukhasavanasana-buildup.png',
#  'E:/capstone/Dataset/possible_Ones/adho mukha svanasana\\88. adho-mukha-svanasana-pies-z-glowacca8-w-dol-840x400.png',
#  'E:/capstone/Dataset/possible_Ones/adho mukha svanasana\\89. downward-facing-dog-yoga-pose.png',
#  'E:/capstone/Dataset/possible_Ones/adho mukha svanasana\\91. screen-shot-2016-04-11-at-2.41.39-pm.png',
#  'E:/capstone/Dataset/possible_Ones/adho mukha svanasana\\92. down-dog.png',
#  'E:/capstone/Dataset/possible_Ones/adho mukha svanasana\\94. dog.png',
#  'E:/capstone/Dataset/possible_Ones/adho mukha svanasana\\95. downward-facing-dog-pose.png',
#  'E:/capstone/Dataset/possible_Ones/adho mukha svanasana\\95. screen-shot-2018-06-03-at-10-46-24-pm.png']

# %% [markdown]
# # testing

# %%
import csv


def calculate_angles(a,b,c):
    a = np.array(a) # First
    b = np.array(b) # Second 
    c = np.array(c) # Third
    
    radians = np.arctan2(c[1]-b[1], c[0]-b[0]) - np.arctan2(a[1]-b[1], a[0]-b[0])
    angle = np.abs(radians*180.0/np.pi)
    
    if angle > 180.0:
        angle = 360-angle
    return angle


# left_arm_data = []
# right_arm_data = []
# left_leg_data = []
# right_leg_data = []

lower_body=[]
middle_body=[]
upper_body=[]



for image_path in image_paths:
#     image_path = "E:/capstone/Capstone_Project/DATASET/TEST/tree\\00000031.jpg"
    output = cv2.imread(image_path)

    image_pose = output 
    pose = pose_image
    draw = True
    display = True
    # def detectPose(image_pose, pose, draw=False, display=False):

    original_image = image_pose.copy()

    image_in_RGB = cv2.cvtColor(image_pose, cv2.COLOR_BGR2RGB)

    resultant = pose.process(image_in_RGB)
    
    if resultant.pose_landmarks and draw:    


        landmarks = resultant.pose_landmarks.landmark



    ####################################################################
        right_shoulder = [landmarks[mp_pose.PoseLandmark.RIGHT_SHOULDER.value].x,landmarks[mp_pose.PoseLandmark.RIGHT_SHOULDER.value].y] 
        left_shoulder = [landmarks[mp_pose.PoseLandmark.LEFT_SHOULDER.value].x,landmarks[mp_pose.PoseLandmark.LEFT_SHOULDER.value].y]

        right_elbow = [landmarks[mp_pose.PoseLandmark.RIGHT_ELBOW.value].x,landmarks[mp_pose.PoseLandmark.RIGHT_ELBOW.value].y]
        left_elbow = [landmarks[mp_pose.PoseLandmark.LEFT_ELBOW.value].x,landmarks[mp_pose.PoseLandmark.LEFT_ELBOW.value].y]

        right_wrist = [landmarks[mp_pose.PoseLandmark.RIGHT_WRIST.value].x,landmarks[mp_pose.PoseLandmark.RIGHT_WRIST.value].y]
        left_wrist = [landmarks[mp_pose.PoseLandmark.LEFT_WRIST.value].x,landmarks[mp_pose.PoseLandmark.LEFT_WRIST.value].y]

        right_hip = [landmarks[mp_pose.PoseLandmark.RIGHT_HIP.value].x,landmarks[mp_pose.PoseLandmark.RIGHT_HIP.value].y]
        left_hip = [landmarks[mp_pose.PoseLandmark.LEFT_HIP.value].x,landmarks[mp_pose.PoseLandmark.LEFT_HIP.value].y]


        right_knee = [landmarks[mp_pose.PoseLandmark.RIGHT_KNEE.value].x,landmarks[mp_pose.PoseLandmark.RIGHT_KNEE.value].y]
        left_knee = [landmarks[mp_pose.PoseLandmark.LEFT_KNEE.value].x,landmarks[mp_pose.PoseLandmark.LEFT_KNEE.value].y]

        right_ankle = [landmarks[mp_pose.PoseLandmark.RIGHT_ANKLE.value].x,landmarks[mp_pose.PoseLandmark.RIGHT_ANKLE.value].y]
        left_ankle = [landmarks[mp_pose.PoseLandmark.LEFT_ANKLE.value].x,landmarks[mp_pose.PoseLandmark.LEFT_ANKLE.value].y]




















    #########################################################
        # CALCULATE THE ANGLE
    #     angle_la = calculate_angles(left_wrist,left_elbow,left_shoulder)  
    #     angle_ra = calculate_angles(right_wrist,right_elbow,right_shoulder)  
    #     angle_ll = calculate_angles(left_hip,left_knee,left_ankle)  
    #     angle_rl = calculate_angles(right_hip,right_knee,right_ankle)  


        lower_body_1 = calculate_angles(left_ankle,left_knee,left_hip)
        lower_body_2 = calculate_angles(right_ankle,right_knee,right_hip)

        middle_body_1 = calculate_angles(left_knee,left_hip,left_shoulder)
        middle_body_2 = calculate_angles(right_knee,right_hip,right_shoulder)

        upper_body_1 = calculate_angles(left_hip,left_shoulder,left_wrist)
        upper_body_2 = calculate_angles(right_hip,right_shoulder,right_wrist)



    #     print(angle)


    #     arms_data.append(angle)

    #     left_arm_data.append(angle_la)
    #     right_arm_data.append(angle_ra)
    #     left_leg_data.append(angle_ll)
    #     right_leg_data.append(angle_rl)

        lower_body.append(lower_body_1)
        lower_body.append(lower_body_2)
        middle_body.append(middle_body_1)
        middle_body.append(middle_body_2)
        upper_body.append(upper_body_1)
        upper_body.append(upper_body_2)



    # Sample data
    # data = [angle]

    # # Specify the file name
    # csv_file = "data.csv"

    # # Write data to CSV file
    # with open(csv_file, mode='a', newline='') as file:
    #     writer = csv.writer(file)
    #     writer.writerow(data)

# %%
import csv

# Sample data

data = zip(lower_body,middle_body,upper_body)
# Specify the file name
csv_file = "data.csv"

# Write data to CSV file
with open(csv_file, mode='a', newline="") as file:
    writer = csv.writer(file)
    writer.writerow(['LOWER-BODY','           MIDDLE-BODY','         UPPER-BODY'])
    
    for row in data:
        writer.writerow(row)

# %%
import pandas as pd
df = pd.read_csv('data.csv')

# %%
df.head()
# Out:
#              Left-Arm           Right-Arm            Left-Leg  \
# 0  162.15544949496376  166.77964388298156    175.581564203023
# 1  162.45582703525642  160.44018695358793  178.92493247306027
# 2  145.33324585737935    143.099256996344  171.29431384343954
# 3  139.90030189742046  157.42728613320787  22.304689558751193
# 4  163.00417055547126   166.5834535536934   43.36507639063092
#
#             Right-Leg
# 0  31.379594719417014
# 1   38.02129476402971
# 2    24.4538795555697
# 3  174.64375422868807
# 4   178.0434940245503

# %%
s=0
lb=0
ub=0
mb=0
for i in lower_body:
    s+=i
lb=s/len(lower_body)
s=0
for i in middle_body:
    s+=i
mb=s/len(middle_body)
s=0
for i in upper_body:
    s+=i
ub=s/len(upper_body)

# %%
print("LB:",lb,"\nMB: ",mb,"\nUB: ",ub)
# Out:
# LB: 174.37816463364078
# MB:  61.1786440880586
# UB:  171.7667346213712

# %% [markdown]
# # ardha uttanasana

# %%
import os
from PIL import Image

# Folder path containing images
folder_path = "E:/capstone/Dataset/possible_Ones/ardha uttanasana"

# # List to store image data
# images = []

# # Iterate over files in the folder
# for filename in os.listdir(folder_path):
#     # Check if the file is an image (you might want to add more image extensions)
#     if filename.endswith(".jpg") or filename.endswith(".png"):
#         # Construct the full file path
#         file_path = os.path.join(folder_path, filename)
#         # Open the image using Pillow
#         img = Image.open(file_path)
#         # Append the image to the list
#         images.append(img)
#         # You can perform any processing or testing here with the image

# # Now you have all the images loaded in the 'images' list
# # You can loop through this list to perform testing or processing




# List to store image paths
image_paths = []

# Iterate over files in the folder
for filename in os.listdir(folder_path):
    # Check if the file is an image (you might want to add more image extensions)
    if filename.endswith(".jpg") or filename.endswith(".png"):
        # Construct the full file path
        file_path = os.path.join(folder_path, filename)
        # Append the file path to the list
        file_path.replace("\\",'/')
        image_paths.append(file_path)

# %%
image_paths
# Out:
# ['E:/capstone/Dataset/possible_Ones/ardha uttanasana\\0-0.png',
#  'E:/capstone/Dataset/possible_Ones/ardha uttanasana\\1-0.png',
#  'E:/capstone/Dataset/possible_Ones/ardha uttanasana\\1-2.png',
#  'E:/capstone/Dataset/possible_Ones/ardha uttanasana\\10-0.png',
#  'E:/capstone/Dataset/possible_Ones/ardha uttanasana\\11-0 (2).png',
#  'E:/capstone/Dataset/possible_Ones/ardha uttanasana\\11-0.png',
#  'E:/capstone/Dataset/possible_Ones/ardha uttanasana\\12-0.png',
#  'E:/capstone/Dataset/possible_Ones/ardha uttanasana\\13-0.png',
#  'E:/capstone/Dataset/possible_Ones/ardha uttanasana\\15-0.png',
#  'E:/capstone/Dataset/possible_Ones/ardha uttanasana\\16-0 (2).png',
#  'E:/capstone/Dataset/possible_Ones/ardha uttanasana\\16-0.png',
#  'E:/capstone/Dataset/possible_Ones/ardha uttanasana\\16-1.png',
#  'E:/capstone/Dataset/possible_Ones/ardha uttanasana\\17-0 (2).png',
#  'E:/capstone/Dataset/possible_Ones/ardha uttanasana\\17-0.png',
#  'E:/capstone/Dataset/possible_Ones/ardha uttanasana\\18-0 (2).png',
#  'E:/capstone/Dataset/possible_Ones/ardha uttanasana\\18-0.png',
#  'E:/capstone/Dataset/possible_Ones/ardha uttanasana\\19-0 (2).png',
#  'E:/capstone/Dataset/possible_Ones/ardha uttanasana\\19-0.png',
#  'E:/capstone/Dataset/possible_Ones/ardha uttanasana\\2-0.png',
#  'E:/capstone/Dataset/possible_Ones/ardha uttanasana\\20-0 (2).png',
#  'E:/capstone/Dataset/possible_Ones/ardha uttanasana\\20-0.png',
#  'E:/capstone/Dataset/possible_Ones/ardha uttanasana\\21-0 (2).png',
#  'E:/capstone/Dataset/possible_Ones/ardha uttanasana\\21-0.png',
#  'E:/capstone/Dataset/possible_Ones/ardha uttanasana\\22-0 (2).png',
#  'E:/capstone/Dataset/possible_Ones/ardha uttanasana\\22-0.png',
#  'E:/capstone/Dataset/possible_Ones/ardha uttanasana\\23-0.png',
#  'E:/capstone/Dataset/possible_Ones/ardha uttanasana\\24-0.png',
#  'E:/capstone/Dataset/possible_Ones/ardha uttanasana\\26-0 (2).png',
#  'E:/capstone/Dataset/possible_Ones/ardha uttanasana\\26-0.png',
#  'E:/capstone/Dataset/possible_Ones/ardha uttanasana\\27-0 (2).png',
#  'E:/capstone/Dataset/possible_Ones/ardha uttanasana\\27-0.png',
#  'E:/capstone/Dataset/possible_Ones/ardha uttanasana\\28-0 (2).png',
#  'E:/capstone/Dataset/possible_Ones/ardha uttanasana\\28-0.png',
#  'E:/capstone/Dataset/possible_Ones/ardha uttanasana\\29-0 (2).png',
#  'E:/capstone/Dataset/possible_Ones/ardha uttanasana\\29-0.png',
#  'E:/capstone/Dataset/possible_Ones/ardha uttanasana\\3-0 (2).png',
#  'E:/capstone/Dataset/possible_Ones/ardha uttanasana\\3-0.png',
#  'E:/capstone/Dataset/possible_Ones/ardha uttanasana\\30-0.png',
#  'E:/capstone/Dataset/possible_Ones/ardha uttanasana\\31-0 (2).png',
#  'E:/capstone/Dataset/possible_Ones/ardha uttanasana\\31-0.png',
#  'E:/capstone/Dataset/possible_Ones/ardha uttanasana\\32-1.png',
#  'E:/capstone/Dataset/possible_Ones/ardha uttanasana\\33-0.png',
#  'E:/capstone/Dataset/possible_Ones/ardha uttanasana\\34-0.png',
#  'E:/capstone/Dataset/possible_Ones/ardha uttanasana\\34-1.png',
#  'E:/capstone/Dataset/possible_Ones/ardha uttanasana\\34-2.png',
#  'E:/capstone/Dataset/possible_Ones/ardha uttanasana\\36-0 (2).png',
#  'E:/capstone/Dataset/possible_Ones/ardha uttanasana\\36-0.png',
#  'E:/capstone/Dataset/possible_Ones/ardha uttanasana\\37-0.png',
#  'E:/capstone/Dataset/possible_Ones/ardha uttanasana\\38-0.png',
#  'E:/capstone/Dataset/possible_Ones/ardha uttanasana\\39-0 (2).png',
#  'E:/capstone/Dataset/possible_Ones/ardha uttanasana\\39-0.png',
#  'E:/capstone/Dataset/possible_Ones/ardha uttanasana\\4-0 (2).png',
#  'E:/capstone/Dataset/possible_Ones/ardha uttanasana\\4-0.png',
#  'E:/capstone/Dataset/possible_Ones/ardha uttanasana\\4-1.png',
#  'E:/capstone/Dataset/possible_Ones/ardha uttanasana\\40-0.png',
#  'E:/capstone/Dataset/possible_Ones/ardha uttanasana\\41-0.png',
#  'E:/capstone/Dataset/possible_Ones/ardha uttanasana\\42-0 (2).png',
#  'E:/capstone/Dataset/possible_Ones/ardha uttanasana\\42-0.png',
#  'E:/capstone/Dataset/possible_Ones/ardha uttanasana\\43-0 (2).png',
#  'E:/capstone/Dataset/possible_Ones/ardha uttanasana\\43-0.png',
#  'E:/capstone/Dataset/possible_Ones/ardha uttanasana\\43-1.png',
#  'E:/capstone/Dataset/possible_Ones/ardha uttanasana\\44-0 (2).png',
#  'E:/capstone/Dataset/possible_Ones/ardha uttanasana\\44-0.png',
#  'E:/capstone/Dataset/possible_Ones/ardha uttanasana\\45-0.png',
#  'E:/capstone/Dataset/possible_Ones/ardha uttanasana\\46-0.png',
#  'E:/capstone/Dataset/possible_Ones/ardha uttanasana\\47-0.png',
#  'E:/capstone/Dataset/possible_Ones/ardha uttanasana\\48-0 (2).png',
#  'E:/capstone/Dataset/possible_Ones/ardha uttanasana\\48-0.png',
#  'E:/capstone/Dataset/possible_Ones/ardha uttanasana\\49-0.png',
#  'E:/capstone/Dataset/possible_Ones/ardha uttanasana\\5-0.png',
#  'E:/capstone/Dataset/possible_Ones/ardha uttanasana\\51-0 (2).png',
#  'E:/capstone/Dataset/possible_Ones/ardha uttanasana\\51-0.png',
#  'E:/capstone/Dataset/possible_Ones/ardha uttanasana\\51-1.png',
#  'E:/capstone/Dataset/possible_Ones/ardha uttanasana\\53-0.png',
#  'E:/capstone/Dataset/possible_Ones/ardha uttanasana\\55-0 (2).png',
#  'E:/capstone/Dataset/possible_Ones/ardha uttanasana\\55-0.png',
#  'E:/capstone/Dataset/possible_Ones/ardha uttanasana\\56-0.png',
#  'E:/capstone/Dataset/possible_Ones/ardha uttanasana\\57-0.png',
#  'E:/capstone/Dataset/possible_Ones/ardha uttanasana\\58-0.png',
#  'E:/capstone/Dataset/possible_Ones/ardha uttanasana\\59-0.png',
#  'E:/capstone/Dataset/possible_Ones/ardha uttanasana\\60-0.png',
#  'E:/capstone/Dataset/possible_Ones/ardha uttanasana\\62-0.png',
#  'E:/capstone/Dataset/possible_Ones/ardha uttanasana\\63-0.png',
#  'E:/capstone/Dataset/possible_Ones/ardha uttanasana\\64-0.png',
#  'E:/capstone/Dataset/possible_Ones/ardha uttanasana\\65-0.png',
#  'E:/capstone/Dataset/possible_Ones/ardha uttanasana\\65-1.png',
#  'E:/capstone/Dataset/possible_Ones/ardha uttanasana\\66-1.png',
#  'E:/capstone/Dataset/possible_Ones/ardha uttanasana\\66-2.png',
#  'E:/capstone/Dataset/possible_Ones/ardha uttanasana\\68-0.png',
#  'E:/capstone/Dataset/possible_Ones/ardha uttanasana\\69-0 (2).png',
#  'E:/capstone/Dataset/possible_Ones/ardha uttanasana\\69-0.png',
#  'E:/capstone/Dataset/possible_Ones/ardha uttanasana\\7-0.png',
#  'E:/capstone/Dataset/possible_Ones/ardha uttanasana\\70-0 (2).png',
#  'E:/capstone/Dataset/possible_Ones/ardha uttanasana\\70-0.png',
#  'E:/capstone/Dataset/possible_Ones/ardha uttanasana\\71-0.png',
#  'E:/capstone/Dataset/possible_Ones/ardha uttanasana\\72-0 (2).png',
#  'E:/capstone/Dataset/possible_Ones/ardha uttanasana\\72-0.png',
#  'E:/capstone/Dataset/possible_Ones/ardha uttanasana\\74-0.png',
#  'E:/capstone/Dataset/possible_Ones/ardha uttanasana\\74-1.png',
#  'E:/capstone/Dataset/possible_Ones/ardha uttanasana\\75-0.png',
#  'E:/capstone/Dataset/possible_Ones/ardha uttanasana\\75-1.png',
#  'E:/capstone/Dataset/possible_Ones/ardha uttanasana\\76-0.png',
#  'E:/capstone/Dataset/possible_Ones/ardha uttanasana\\77-0 (2).png',
#  'E:/capstone/Dataset/possible_Ones/ardha uttanasana\\77-0.png',
#  'E:/capstone/Dataset/possible_Ones/ardha uttanasana\\79-0.png',
#  'E:/capstone/Dataset/possible_Ones/ardha uttanasana\\80-0.png',
#  'E:/capstone/Dataset/possible_Ones/ardha uttanasana\\82-0 (2).png',
#  'E:/capstone/Dataset/possible_Ones/ardha uttanasana\\82-0.png',
#  'E:/capstone/Dataset/possible_Ones/ardha uttanasana\\83-0.png',
#  'E:/capstone/Dataset/possible_Ones/ardha uttanasana\\84-0.png',
#  'E:/capstone/Dataset/possible_Ones/ardha uttanasana\\84-1.png',
#  'E:/capstone/Dataset/possible_Ones/ardha uttanasana\\85-0.png',
#  'E:/capstone/Dataset/possible_Ones/ardha uttanasana\\85-1 (2).png',
#  'E:/capstone/Dataset/possible_Ones/ardha uttanasana\\85-1.png',
#  'E:/capstone/Dataset/possible_Ones/ardha uttanasana\\86-0.png',
#  'E:/capstone/Dataset/possible_Ones/ardha uttanasana\\88-0.png',
#  'E:/capstone/Dataset/possible_Ones/ardha uttanasana\\89-0.png',
#  'E:/capstone/Dataset/possible_Ones/ardha uttanasana\\9-0 (2).png',
#  'E:/capstone/Dataset/possible_Ones/ardha uttanasana\\9-0.png',
#  'E:/capstone/Dataset/possible_Ones/ardha uttanasana\\90-2.png',
#  'E:/capstone/Dataset/possible_Ones/ardha uttanasana\\91-0 (2).png',
#  'E:/capstone/Dataset/possible_Ones/ardha uttanasana\\91-0.png',
#  'E:/capstone/Dataset/possible_Ones/ardha uttanasana\\92-0 (2).png',
#  'E:/capstone/Dataset/possible_Ones/ardha uttanasana\\92-0.png',
#  'E:/capstone/Dataset/possible_Ones/ardha uttanasana\\93-0.png',
#  'E:/capstone/Dataset/possible_Ones/ardha uttanasana\\96-0.png',
#  'E:/capstone/Dataset/possible_Ones/ardha uttanasana\\97-0.png']

# %% [markdown]
# # testing

# %%
import csv


def calculate_angles(a,b,c):
    a = np.array(a) # First
    b = np.array(b) # Second 
    c = np.array(c) # Third
    
    radians = np.arctan2(c[1]-b[1], c[0]-b[0]) - np.arctan2(a[1]-b[1], a[0]-b[0])
    angle = np.abs(radians*180.0/np.pi)
    
    if angle > 180.0:
        angle = 360-angle
    return angle


# left_arm_data = []
# right_arm_data = []
# left_leg_data = []
# right_leg_data = []

legs=[]
hips=[]
shoulder=[]
arms=[]



for image_path in image_paths:
#     image_path = "E:/capstone/Capstone_Project/DATASET/TEST/tree\\00000031.jpg"
    output = cv2.imread(image_path)

    image_pose = output 
    pose = pose_image
    draw = True
    display = True
    # def detectPose(image_pose, pose, draw=False, display=False):

    original_image = image_pose.copy()

    image_in_RGB = cv2.cvtColor(image_pose, cv2.COLOR_BGR2RGB)

    resultant = pose.process(image_in_RGB)
    
    if resultant.pose_landmarks and draw:    


        landmarks = resultant.pose_landmarks.landmark



    ####################################################################
        right_shoulder = [landmarks[mp_pose.PoseLandmark.RIGHT_SHOULDER.value].x,landmarks[mp_pose.PoseLandmark.RIGHT_SHOULDER.value].y] 
        left_shoulder = [landmarks[mp_pose.PoseLandmark.LEFT_SHOULDER.value].x,landmarks[mp_pose.PoseLandmark.LEFT_SHOULDER.value].y]

        right_elbow = [landmarks[mp_pose.PoseLandmark.RIGHT_ELBOW.value].x,landmarks[mp_pose.PoseLandmark.RIGHT_ELBOW.value].y]
        left_elbow = [landmarks[mp_pose.PoseLandmark.LEFT_ELBOW.value].x,landmarks[mp_pose.PoseLandmark.LEFT_ELBOW.value].y]

        right_wrist = [landmarks[mp_pose.PoseLandmark.RIGHT_WRIST.value].x,landmarks[mp_pose.PoseLandmark.RIGHT_WRIST.value].y]
        left_wrist = [landmarks[mp_pose.PoseLandmark.LEFT_WRIST.value].x,landmarks[mp_pose.PoseLandmark.LEFT_WRIST.value].y]

        right_hip = [landmarks[mp_pose.PoseLandmark.RIGHT_HIP.value].x,landmarks[mp_pose.PoseLandmark.RIGHT_HIP.value].y]
        left_hip = [landmarks[mp_pose.PoseLandmark.LEFT_HIP.value].x,landmarks[mp_pose.PoseLandmark.LEFT_HIP.value].y]


        right_knee = [landmarks[mp_pose.PoseLandmark.RIGHT_KNEE.value].x,landmarks[mp_pose.PoseLandmark.RIGHT_KNEE.value].y]
        left_knee = [landmarks[mp_pose.PoseLandmark.LEFT_KNEE.value].x,landmarks[mp_pose.PoseLandmark.LEFT_KNEE.value].y]

        right_ankle = [landmarks[mp_pose.PoseLandmark.RIGHT_ANKLE.value].x,landmarks[mp_pose.PoseLandmark.RIGHT_ANKLE.value].y]
        left_ankle = [landmarks[mp_pose.PoseLandmark.LEFT_ANKLE.value].x,landmarks[mp_pose.PoseLandmark.LEFT_ANKLE.value].y]




















    #########################################################
        # CALCULATE THE ANGLE
    #     angle_la = calculate_angles(left_wrist,left_elbow,left_shoulder)  
    #     angle_ra = calculate_angles(right_wrist,right_elbow,right_shoulder)  
    #     angle_ll = calculate_angles(left_hip,left_knee,left_ankle)  
    #     angle_rl = calculate_angles(right_hip,right_knee,right_ankle)  


        leg_1 = calculate_angles(left_ankle,left_knee,left_hip)
        leg_2 = calculate_angles(right_ankle,right_knee,right_hip)

        hip_1 = calculate_angles(left_knee,left_hip,left_shoulder)
        hip_2 = calculate_angles(right_knee,right_hip,right_shoulder)

        shoulder_1 = calculate_angles(left_hip,left_shoulder,left_elbow)
        shoulder_2 = calculate_angles(right_hip,right_shoulder,right_elbow)
        
        arms_1 = calculate_angles(left_shoulder,left_elbow,left_wrist)
        arms_2 = calculate_angles(right_shoulder,right_elbow,right_wrist)



    #     print(angle)


    #     arms_data.append(angle)

    #     left_arm_data.append(angle_la)
    #     right_arm_data.append(angle_ra)
    #     left_leg_data.append(angle_ll)
    #     right_leg_data.append(angle_rl)

        legs.append(leg_1)
        legs.append(leg_2)
        hips.append(hip_1)
        hips.append(hip_2)
        shoulder.append(shoulder_1)
        shoulder.append(shoulder_2)
        arms.append(arms_1)
        arms.append(arms_2)



    # Sample data
    # data = [angle]

    # # Specify the file name
    # csv_file = "data.csv"

    # # Write data to CSV file
    # with open(csv_file, mode='a', newline='') as file:
    #     writer = csv.writer(file)
    #     writer.writerow(data)

# %%
arms
# Out:
# [179.03732593270962,
#  170.54517109612647,
#  169.30848951287575,
#  165.91533548190793,
#  168.97313455948634,
#  164.41304458698363,
#  141.31599049548473,
#  148.08310527351512,
#  130.32434471700736,
#  156.18386497073482,
#  175.18209275161962,
#  178.74815981719817,
#  174.44871979310128,
#  172.42688335917427,
#  164.9298016628858,
#  168.48773899310154,
#  151.33991527475686,
#  176.18751015454154,
#  156.77811445033169,
#  155.35931076172852,
#  160.95358209524207,
#  170.46672547075121,
#  178.92124798056082,
#  158.6188374512167,
#  159.8979360098571,
#  177.33164434869403,
#  157.1505975787499,
#  169.41261453847548,
#  170.6344523416762,
#  162.08995561421446,
#  167.3573516641361,
#  167.06777778234718,
#  169.53226822328338,
#  167.4631350040052,
#  164.42492913683887,
#  175.20877281335902,
#  123.61919547317783,
#  135.65496762164378,
#  153.11916759488236,
#  152.19126974795913,
#  160.13599299428134,
#  163.9011590313052,
#  98.34060216762367,
#  164.480365842267,
#  172.76621312306045,
#  175.12464406684143,
#  179.66403139041225,
#  132.32779064809836,
#  50.19834986190688,
#  80.61291688426479,
#  159.79593422337817,
#  166.32324758338294,
#  144.41691792220192,
#  138.29946521382155,
#  174.52519152129707,
#  178.36382330144278,
#  100.19810306491274,
#  107.28530041209757,
#  165.46485631048154,
#  166.77684000506994,
#  163.4547715102561,
#  138.78283019847063,
#  168.62445909831567,
#  157.80135292408488,
#  139.40935213001742,
#  35.62887190792476,
#  164.9298016628858,
#  168.48773899310154,
#  135.69413681891277,
#  141.17395167673567,
#  154.55273931228658,
#  156.56219061989813,
#  166.59282139641041,
#  161.08869273678212,
#  140.39646886731757,
#  5.220925557755257,
#  152.59668570080538,
#  135.29807064162287,
#  176.10931002603158,
#  176.97408059325332,
#  174.8820980403475,
#  174.6429381081781,
#  171.31290433580634,
#  176.31303159220954,
#  113.4499203425417,
#  101.19176384838711,
#  179.11864260028273,
#  175.67548643870867,
#  111.35109910319369,
#  111.88242780232534,
#  61.784937011923546,
#  69.87339588799762,
#  130.56162435937023,
#  117.19890008160819,
#  173.70624894227456,
#  174.48876278859615,
#  82.4135720899162,
#  76.49212796378224,
#  162.38733045208673,
#  166.95051274874558,
#  53.575361604122406,
#  78.43822872136786,
#  178.02192930369247,
#  179.31236260533439,
#  178.54565856133502,
#  178.8975228608227,
#  150.3670524412123,
#  163.9330429534162,
#  153.12409659506142,
#  151.76786700931538,
#  165.46485631048154,
#  166.77684000506994,
#  179.0929375583362,
#  178.5081515670395,
#  177.2359776656766,
#  179.10619420758854,
#  51.40229483709143,
#  102.89967966804721,
#  176.49288332510517,
#  177.9916561485665,
#  117.98721302254313,
#  166.5157217149542,
#  99.61472599539849,
#  123.84809520954627,
#  179.4557369255881,
#  159.34971707232017,
#  67.31084938988022,
#  102.87352628642793,
#  168.0175295796011,
#  171.76406320635496,
#  159.25324844341398,
#  159.10525089614637,
#  172.6049289522265,
#  169.92187940083033,
#  140.44868839051674,
#  143.0432190749596,
#  178.1166671429127,
#  176.24248874334498,
#  159.02805374758475,
#  157.3500660653705,
#  164.4768587137868,
#  162.79410779151854,
#  165.0461545083234,
#  159.04743335669235,
#  89.27194624005557,
#  133.78497225738852,
#  164.4768587137868,
#  162.79410779151854,
#  179.2804840086451,
#  141.96578849441033,
#  150.94223587587285,
#  147.83207319502978,
#  68.39687123389842,
#  81.15867042878347,
#  176.42133482765635,
#  170.97321117290113,
#  168.8199245452204,
#  159.59789112898844,
#  167.11647165828907,
#  166.2841720079264,
#  164.94460800432304,
#  152.20979421230834,
#  162.9168482999538,
#  177.9011073804797,
#  77.62519440792775,
#  78.75728326658607,
#  143.0708880402781,
#  145.41987210151913,
#  163.28158638171274,
#  158.2746465063756,
#  119.53260523783428,
#  140.97969869644112,
#  170.5810142746198,
#  162.15548711090943,
#  149.93444023908046,
#  129.17737661046093,
#  166.3130414335526,
#  158.69830694364606,
#  137.76673290362842,
#  132.44896367824447,
#  79.14926923507234,
#  67.66944741860631,
#  165.979110399355,
#  166.22397543366577,
#  126.67823541165899,
#  146.2105183617223,
#  147.7281291847052,
#  126.09087108786977,
#  164.94460800432304,
#  152.20979421230834,
#  152.71523049024992,
#  151.66388972470318,
#  64.46279291558932,
#  68.9988008010501,
#  155.46129453687175,
#  135.48090811648487,
#  173.11936977812545,
#  164.49546356433285,
#  164.19126161636441,
#  166.72353963382676,
#  168.12652744498868,
#  170.25675995114847,
#  176.32717428624747,
#  179.03825708230264,
#  157.3852928495075,
#  157.13972633097896,
#  167.11647165828907,
#  166.2841720079264,
#  173.74082562358618,
#  171.78341011840584,
#  179.35956033116952,
#  147.66353979845135,
#  157.7353801856998,
#  139.60419601891485,
#  170.5810142746198,
#  162.15548711090943,
#  176.32717428624747,
#  179.03825708230264,
#  151.42365321475882,
#  174.8579621047398,
#  157.24654159401302,
#  157.34469412142684,
#  143.0708880402781,
#  145.41987210151913,
#  147.8675580511266,
#  151.2359020660458,
#  178.5278730015573,
#  174.80167548024298,
#  107.26877039239285,
#  104.29164407589539,
#  157.3852928495075,
#  157.13972633097896,
#  70.53625706031494,
#  82.14812270867509,
#  107.57749981295615,
#  106.2937324502624]

# %%
import csv

# Sample data

data = zip(legs,hips,shoulder,arms)
# Specify the file name
csv_file = "aardha_uttanasana.csv"

# Write data to CSV file
with open(csv_file, mode='a', newline="") as file:
    writer = csv.writer(file)
    writer.writerow(['LEGS','    HIPS','    SHOULDER','    ARMS'])
    
    for row in data:
        writer.writerow(row)

# %%
import pandas as pd
df = pd.read_csv('aardha_uttanasana.csv')

# %%
df.head()
# Out:
#          LEGS        HIPS      SHOULDER        ARMS
# 0    0.606236  130.298806     81.014151  179.037326
# 1  173.589540   82.384793     62.858728  170.545171
# 2  168.093594   56.414541    112.333660  169.308490
# 3  168.625992   62.233454    107.188910  165.915335
# 4  168.696266   49.619433     86.024877  168.973135

# %%
s=0
ARM=0
SHOULDER=0
HIP=0
LEG=0
for i in arms:
    s+=i
ARM=s/len(arms)
s=0
for i in shoulder:
    s+=i
SHOULDER=s/len(shoulder)
s=0
for i in hips:
    s+=i
HIP=s/len(hips)
s=0
for i in legs:
    s+=i
LEG=s/len(legs)

# %%
print("ARMS:",ARM,"\nSHOULDER: ",SHOULDER,"\nHIPS: ",HIP,"\nLEGS: ",LEG)
# Out:
# ARMS: 148.35905903953437
# SHOULDER:  92.16104999344766
# HIPS:  55.59189081153377
# LEGS:  162.1458291426553

# %% [markdown]
# # balasana

# %%
import os
from PIL import Image

# Folder path containing images
folder_path = "E:/capstone/Dataset/possible_Ones/balasana"

# # List to store image data
# images = []

# # Iterate over files in the folder
# for filename in os.listdir(folder_path):
#     # Check if the file is an image (you might want to add more image extensions)
#     if filename.endswith(".jpg") or filename.endswith(".png"):
#         # Construct the full file path
#         file_path = os.path.join(folder_path, filename)
#         # Open the image using Pillow
#         img = Image.open(file_path)
#         # Append the image to the list
#         images.append(img)
#         # You can perform any processing or testing here with the image

# # Now you have all the images loaded in the 'images' list
# # You can loop through this list to perform testing or processing




# List to store image paths
image_paths = []

# Iterate over files in the folder
for filename in os.listdir(folder_path):
    # Check if the file is an image (you might want to add more image extensions)
    if filename.endswith(".jpg") or filename.endswith(".png"):
        # Construct the full file path
        file_path = os.path.join(folder_path, filename)
        # Append the file path to the list
        file_path.replace("\\",'/')
        image_paths.append(file_path)

# %%
image_paths
# Out:
# ['E:/capstone/Dataset/possible_Ones/balasana\\1. child_wide-2x.png',
#  'E:/capstone/Dataset/possible_Ones/balasana\\1. image0011.png',
#  'E:/capstone/Dataset/possible_Ones/balasana\\10. 17.png',
#  'E:/capstone/Dataset/possible_Ones/balasana\\10. 22.10.2017-e1508409633499.png',
#  'E:/capstone/Dataset/possible_Ones/balasana\\11. a85313ca89524af1b8ee8766021b4dba.png',
#  'E:/capstone/Dataset/possible_Ones/balasana\\11. d52a384b55f968afda3e4717b9e76f31.png',
#  'E:/capstone/Dataset/possible_Ones/balasana\\12. child_pose.png',
#  'E:/capstone/Dataset/possible_Ones/balasana\\12. yoga-child-pose-meditation-balasana-512.png',
#  'E:/capstone/Dataset/possible_Ones/balasana\\13. child-pose-yoga.png',
#  'E:/capstone/Dataset/possible_Ones/balasana\\13. how-and-when-to-do-childs-pose-or-balasana_14.png',
#  'E:/capstone/Dataset/possible_Ones/balasana\\14. childs-pose-position-source-123rf-royalty-free-lmages-cobra-position-10042240.png',
#  'E:/capstone/Dataset/possible_Ones/balasana\\14. stretching-inner-thighs-balasana-baddha-konasana-side-splits-malasana-man-15965869.png',
#  'E:/capstone/Dataset/possible_Ones/balasana\\15. balasana-childs-resting-pose-helps-alleviate-stress-and-anxiety.png',
#  'E:/capstone/Dataset/possible_Ones/balasana\\16. screen+shot+2018-03-02+at+6.23.32+pm.png',
#  'E:/capstone/Dataset/possible_Ones/balasana\\16. yoga-child-pose-meditation-balasana-512.png',
#  'E:/capstone/Dataset/possible_Ones/balasana\\17. balasana.png',
#  'E:/capstone/Dataset/possible_Ones/balasana\\17. extended-child-pose.png',
#  'E:/capstone/Dataset/possible_Ones/balasana\\18. balasana2c+double+bolster.png',
#  'E:/capstone/Dataset/possible_Ones/balasana\\19. 20181201_114715_0001780273561.png',
#  'E:/capstone/Dataset/possible_Ones/balasana\\19. adho+muka+virasana.png',
#  'E:/capstone/Dataset/possible_Ones/balasana\\2. childs-pose-modifications-plus-size-yoga.png',
#  'E:/capstone/Dataset/possible_Ones/balasana\\20. balasana-childs-pose.png',
#  'E:/capstone/Dataset/possible_Ones/balasana\\20. yoga_child.png',
#  'E:/capstone/Dataset/possible_Ones/balasana\\21. child-pose.png',
#  'E:/capstone/Dataset/possible_Ones/balasana\\21. happy-baby-pose-520x400.png',
#  'E:/capstone/Dataset/possible_Ones/balasana\\22. childpose.png',
#  'E:/capstone/Dataset/possible_Ones/balasana\\22. content_blog_inner_94c5556e.png',
#  'E:/capstone/Dataset/possible_Ones/balasana\\23. child-402x.png',
#  'E:/capstone/Dataset/possible_Ones/balasana\\23. happy-baby-pose-ananda-balasana-2-683x1024.png',
#  'E:/capstone/Dataset/possible_Ones/balasana\\24. 3-childspose-shutterstock.png',
#  'E:/capstone/Dataset/possible_Ones/balasana\\24. d5c032bbf41c1ec359790477ec48836d.png',
#  'E:/capstone/Dataset/possible_Ones/balasana\\25. shishusana-or-the-child-pose copy.png',
#  'E:/capstone/Dataset/possible_Ones/balasana\\25. shishusana-or-the-child-pose.png',
#  'E:/capstone/Dataset/possible_Ones/balasana\\27. balasana.png',
#  'E:/capstone/Dataset/possible_Ones/balasana\\28. 1000x1000_child20pose0asan20image.jpg',
#  'E:/capstone/Dataset/possible_Ones/balasana\\29. balasana.png',
#  'E:/capstone/Dataset/possible_Ones/balasana\\29. child-s-pose-stretch_orig.png',
#  'E:/capstone/Dataset/possible_Ones/balasana\\3. childs-pose-567x567.png',
#  'E:/capstone/Dataset/possible_Ones/balasana\\30. yoga-child-pose-800x480.png',
#  'E:/capstone/Dataset/possible_Ones/balasana\\31. childspose2.png',
#  'E:/capstone/Dataset/possible_Ones/balasana\\32. child-pose.png',
#  'E:/capstone/Dataset/possible_Ones/balasana\\33. yoga-child-pose.png',
#  'E:/capstone/Dataset/possible_Ones/balasana\\34. file.jpg',
#  'E:/capstone/Dataset/possible_Ones/balasana\\37. balasana-2.png',
#  'E:/capstone/Dataset/possible_Ones/balasana\\37. childspose-postheader.png',
#  'E:/capstone/Dataset/possible_Ones/balasana\\38. yoga-poses-to-do-at-your-desk-1.png',
#  'E:/capstone/Dataset/possible_Ones/balasana\\4. childs-pose-balasana.png',
#  'E:/capstone/Dataset/possible_Ones/balasana\\41. childs-pose.png',
#  'E:/capstone/Dataset/possible_Ones/balasana\\42. balasana-1024x646.png',
#  'E:/capstone/Dataset/possible_Ones/balasana\\42. childs-yoga-pose.png',
#  'E:/capstone/Dataset/possible_Ones/balasana\\43. content.png',
#  'E:/capstone/Dataset/possible_Ones/balasana\\44. balasana+child+pose+anatomy.png',
#  'E:/capstone/Dataset/possible_Ones/balasana\\44. extended-child-pose1.png',
#  'E:/capstone/Dataset/possible_Ones/balasana\\45. 4276901736001_4744530330001_4744498901001-vs.jpg',
#  'E:/capstone/Dataset/possible_Ones/balasana\\45. curry-_sisters_child-pose copy.png',
#  'E:/capstone/Dataset/possible_Ones/balasana\\45. curry-_sisters_child-pose.png',
#  'E:/capstone/Dataset/possible_Ones/balasana\\46. images-3.png',
#  'E:/capstone/Dataset/possible_Ones/balasana\\46. screen-shot-2016-11-08-at-16.16.43-e1478710868586.png',
#  'E:/capstone/Dataset/possible_Ones/balasana\\47. 882af92d43b82dd25d4fdfd5e300d79b-child-yoga-pose-silhouette-by-vexels.png',
#  'E:/capstone/Dataset/possible_Ones/balasana\\48. parsva-balasana-_23 copy.png',
#  'E:/capstone/Dataset/possible_Ones/balasana\\48. parsva-balasana-_23.png',
#  'E:/capstone/Dataset/possible_Ones/balasana\\49. screen-shot-2016-11-08-at-16.16.43-e1478710868586.png',
#  'E:/capstone/Dataset/possible_Ones/balasana\\5. yoga-child-pose-2.png',
#  'E:/capstone/Dataset/possible_Ones/balasana\\50. balasana.png',
#  'E:/capstone/Dataset/possible_Ones/balasana\\6. balasana.png',
#  'E:/capstone/Dataset/possible_Ones/balasana\\6. child-pose-back-pain.png',
#  'E:/capstone/Dataset/possible_Ones/balasana\\7. 6963804_orig.png',
#  'E:/capstone/Dataset/possible_Ones/balasana\\7. is-childs-pose-good-for-your-fertility-.png',
#  'E:/capstone/Dataset/possible_Ones/balasana\\8. 17.png',
#  'E:/capstone/Dataset/possible_Ones/balasana\\8. ananda-balasana-happy-child-pose.png',
#  'E:/capstone/Dataset/possible_Ones/balasana\\9. setubandhasana-balasana.png']

# %% [markdown]
# # testing

# %%
import csv


def calculate_angles(a,b,c):
    a = np.array(a) # First
    b = np.array(b) # Second 
    c = np.array(c) # Third
    
    radians = np.arctan2(c[1]-b[1], c[0]-b[0]) - np.arctan2(a[1]-b[1], a[0]-b[0])
    angle = np.abs(radians*180.0/np.pi)
    
    if angle > 180.0:
        angle = 360-angle
    return angle


# left_arm_data = []
# right_arm_data = []
# left_leg_data = []
# right_leg_data = []

lower_body=[]
middle_body=[]
upper_body=[]



for image_path in image_paths:
#     image_path = "E:/capstone/Capstone_Project/DATASET/TEST/tree\\00000031.jpg"
    output = cv2.imread(image_path)

    image_pose = output 
    pose = pose_image
    draw = True
    display = True
    # def detectPose(image_pose, pose, draw=False, display=False):

    original_image = image_pose.copy()

    image_in_RGB = cv2.cvtColor(image_pose, cv2.COLOR_BGR2RGB)

    resultant = pose.process(image_in_RGB)
    
    if resultant.pose_landmarks and draw:    


        landmarks = resultant.pose_landmarks.landmark



    ####################################################################
        right_shoulder = [landmarks[mp_pose.PoseLandmark.RIGHT_SHOULDER.value].x,landmarks[mp_pose.PoseLandmark.RIGHT_SHOULDER.value].y] 
        left_shoulder = [landmarks[mp_pose.PoseLandmark.LEFT_SHOULDER.value].x,landmarks[mp_pose.PoseLandmark.LEFT_SHOULDER.value].y]

        right_elbow = [landmarks[mp_pose.PoseLandmark.RIGHT_ELBOW.value].x,landmarks[mp_pose.PoseLandmark.RIGHT_ELBOW.value].y]
        left_elbow = [landmarks[mp_pose.PoseLandmark.LEFT_ELBOW.value].x,landmarks[mp_pose.PoseLandmark.LEFT_ELBOW.value].y]

        right_wrist = [landmarks[mp_pose.PoseLandmark.RIGHT_WRIST.value].x,landmarks[mp_pose.PoseLandmark.RIGHT_WRIST.value].y]
        left_wrist = [landmarks[mp_pose.PoseLandmark.LEFT_WRIST.value].x,landmarks[mp_pose.PoseLandmark.LEFT_WRIST.value].y]

        right_hip = [landmarks[mp_pose.PoseLandmark.RIGHT_HIP.value].x,landmarks[mp_pose.PoseLandmark.RIGHT_HIP.value].y]
        left_hip = [landmarks[mp_pose.PoseLandmark.LEFT_HIP.value].x,landmarks[mp_pose.PoseLandmark.LEFT_HIP.value].y]


        right_knee = [landmarks[mp_pose.PoseLandmark.RIGHT_KNEE.value].x,landmarks[mp_pose.PoseLandmark.RIGHT_KNEE.value].y]
        left_knee = [landmarks[mp_pose.PoseLandmark.LEFT_KNEE.value].x,landmarks[mp_pose.PoseLandmark.LEFT_KNEE.value].y]

        right_ankle = [landmarks[mp_pose.PoseLandmark.RIGHT_ANKLE.value].x,landmarks[mp_pose.PoseLandmark.RIGHT_ANKLE.value].y]
        left_ankle = [landmarks[mp_pose.PoseLandmark.LEFT_ANKLE.value].x,landmarks[mp_pose.PoseLandmark.LEFT_ANKLE.value].y]




















    #########################################################
        # CALCULATE THE ANGLE
    #     angle_la = calculate_angles(left_wrist,left_elbow,left_shoulder)  
    #     angle_ra = calculate_angles(right_wrist,right_elbow,right_shoulder)  
    #     angle_ll = calculate_angles(left_hip,left_knee,left_ankle)  
    #     angle_rl = calculate_angles(right_hip,right_knee,right_ankle)  


        lower_body_1 = calculate_angles(left_ankle,left_knee,left_hip)
        lower_body_2 = calculate_angles(right_ankle,right_knee,right_hip)

        middle_body_1 = calculate_angles(left_knee,left_hip,left_shoulder)
        middle_body_2 = calculate_angles(right_knee,right_hip,right_shoulder)

        upper_body_1 = calculate_angles(left_shoulder,left_elbow,left_wrist)
        upper_body_2 = calculate_angles(right_shoulder,right_elbow,right_wrist)



    #     print(angle)


    #     arms_data.append(angle)

    #     left_arm_data.append(angle_la)
    #     right_arm_data.append(angle_ra)
    #     left_leg_data.append(angle_ll)
    #     right_leg_data.append(angle_rl)

        lower_body.append(lower_body_1)
        lower_body.append(lower_body_2)
        middle_body.append(middle_body_1)
        middle_body.append(middle_body_2)
        upper_body.append(upper_body_1)
        upper_body.append(upper_body_2)



    # Sample data
    # data = [angle]

    # # Specify the file name
    # csv_file = "data.csv"

    # # Write data to CSV file
    # with open(csv_file, mode='a', newline='') as file:
    #     writer = csv.writer(file)
    #     writer.writerow(data)

# %%
import csv

# Sample data

data = zip(lower_body,middle_body,upper_body)
# Specify the file name
csv_file = "balasana.csv"

# Write data to CSV file
with open(csv_file, mode='a', newline="") as file:
    writer = csv.writer(file)
    writer.writerow(['LOWER-BODY','           MIDDLE-BODY','         UPPER-BODY'])
    
    for row in data:
        writer.writerow(row)

# %%
import pandas as pd
df = pd.read_csv('balasana.csv')

# %%
df.head()
# Out:
#    LOWER-BODY             MIDDLE-BODY           UPPER-BODY
# 0   45.354573               56.166168            68.316998
# 1   37.707201               59.712067            66.675789
# 2   50.941162               27.464772           169.670921
# 3   44.991239               20.678392           147.361055
# 4   53.938221               33.256029           140.047125

# %%
s=0
lb=0
ub=0
mb=0
for i in lower_body:
    s+=i
lb=s/len(lower_body)
s=0
for i in middle_body:
    s+=i
mb=s/len(middle_body)
s=0
for i in upper_body:
    s+=i
ub=s/len(upper_body)

# %%
print("LB:",lb,"\nMB: ",mb,"\nUB: ",ub)
# Out:
# LB: 57.51497297797986
# MB:  39.483192567638646
# UB:  145.8335371982136

# %% [markdown]
# # bhujangasana

# %%
import os
from PIL import Image

# Folder path containing images
folder_path = "E:/capstone/Dataset/possible_Ones/bhujangasana"

# # List to store image data
# images = []

# # Iterate over files in the folder
# for filename in os.listdir(folder_path):
#     # Check if the file is an image (you might want to add more image extensions)
#     if filename.endswith(".jpg") or filename.endswith(".png"):
#         # Construct the full file path
#         file_path = os.path.join(folder_path, filename)
#         # Open the image using Pillow
#         img = Image.open(file_path)
#         # Append the image to the list
#         images.append(img)
#         # You can perform any processing or testing here with the image

# # Now you have all the images loaded in the 'images' list
# # You can loop through this list to perform testing or processing




# List to store image paths
image_paths = []

# Iterate over files in the folder
for filename in os.listdir(folder_path):
    # Check if the file is an image (you might want to add more image extensions)
    if filename.endswith(".jpg") or filename.endswith(".png"):
        # Construct the full file path
        file_path = os.path.join(folder_path, filename)
        # Append the file path to the list
        file_path.replace("\\",'/')
        image_paths.append(file_path)

# %%
image_paths
# Out:
# ['E:/capstone/Dataset/possible_Ones/bhujangasana\\0-0.png',
#  'E:/capstone/Dataset/possible_Ones/bhujangasana\\1-0.png',
#  'E:/capstone/Dataset/possible_Ones/bhujangasana\\10-0.png',
#  'E:/capstone/Dataset/possible_Ones/bhujangasana\\14-0.png',
#  'E:/capstone/Dataset/possible_Ones/bhujangasana\\15-0.png',
#  'E:/capstone/Dataset/possible_Ones/bhujangasana\\16-0.png',
#  'E:/capstone/Dataset/possible_Ones/bhujangasana\\17-0.png',
#  'E:/capstone/Dataset/possible_Ones/bhujangasana\\18-0.png',
#  'E:/capstone/Dataset/possible_Ones/bhujangasana\\19-0.png',
#  'E:/capstone/Dataset/possible_Ones/bhujangasana\\2-0.png',
#  'E:/capstone/Dataset/possible_Ones/bhujangasana\\21-0.png',
#  'E:/capstone/Dataset/possible_Ones/bhujangasana\\22-0.png',
#  'E:/capstone/Dataset/possible_Ones/bhujangasana\\23-0.png',
#  'E:/capstone/Dataset/possible_Ones/bhujangasana\\28-0.png',
#  'E:/capstone/Dataset/possible_Ones/bhujangasana\\29-1.png',
#  'E:/capstone/Dataset/possible_Ones/bhujangasana\\3-0.png',
#  'E:/capstone/Dataset/possible_Ones/bhujangasana\\30-0.png',
#  'E:/capstone/Dataset/possible_Ones/bhujangasana\\32-0.png',
#  'E:/capstone/Dataset/possible_Ones/bhujangasana\\33-0.png',
#  'E:/capstone/Dataset/possible_Ones/bhujangasana\\34-0.png',
#  'E:/capstone/Dataset/possible_Ones/bhujangasana\\35-0.png',
#  'E:/capstone/Dataset/possible_Ones/bhujangasana\\37-0.png',
#  'E:/capstone/Dataset/possible_Ones/bhujangasana\\38-0.png',
#  'E:/capstone/Dataset/possible_Ones/bhujangasana\\4-0.png',
#  'E:/capstone/Dataset/possible_Ones/bhujangasana\\40-0.png',
#  'E:/capstone/Dataset/possible_Ones/bhujangasana\\41-0.png',
#  'E:/capstone/Dataset/possible_Ones/bhujangasana\\42-0.png',
#  'E:/capstone/Dataset/possible_Ones/bhujangasana\\44-0.png',
#  'E:/capstone/Dataset/possible_Ones/bhujangasana\\45-0.png',
#  'E:/capstone/Dataset/possible_Ones/bhujangasana\\46-0.png',
#  'E:/capstone/Dataset/possible_Ones/bhujangasana\\47-0.png',
#  'E:/capstone/Dataset/possible_Ones/bhujangasana\\49-0.png',
#  'E:/capstone/Dataset/possible_Ones/bhujangasana\\5-0.png',
#  'E:/capstone/Dataset/possible_Ones/bhujangasana\\50-0.png',
#  'E:/capstone/Dataset/possible_Ones/bhujangasana\\53-0.png',
#  'E:/capstone/Dataset/possible_Ones/bhujangasana\\56-0.png',
#  'E:/capstone/Dataset/possible_Ones/bhujangasana\\57-1.png',
#  'E:/capstone/Dataset/possible_Ones/bhujangasana\\58-0.png',
#  'E:/capstone/Dataset/possible_Ones/bhujangasana\\6-0.png',
#  'E:/capstone/Dataset/possible_Ones/bhujangasana\\60-0.png',
#  'E:/capstone/Dataset/possible_Ones/bhujangasana\\61-0.png',
#  'E:/capstone/Dataset/possible_Ones/bhujangasana\\62-0.png',
#  'E:/capstone/Dataset/possible_Ones/bhujangasana\\65-0.png',
#  'E:/capstone/Dataset/possible_Ones/bhujangasana\\66-0.png',
#  'E:/capstone/Dataset/possible_Ones/bhujangasana\\68-0.png',
#  'E:/capstone/Dataset/possible_Ones/bhujangasana\\7-0.png',
#  'E:/capstone/Dataset/possible_Ones/bhujangasana\\70-0.png',
#  'E:/capstone/Dataset/possible_Ones/bhujangasana\\71-0.png',
#  'E:/capstone/Dataset/possible_Ones/bhujangasana\\72-2.png',
#  'E:/capstone/Dataset/possible_Ones/bhujangasana\\74-0.png',
#  'E:/capstone/Dataset/possible_Ones/bhujangasana\\76-0.png',
#  'E:/capstone/Dataset/possible_Ones/bhujangasana\\77-0.png',
#  'E:/capstone/Dataset/possible_Ones/bhujangasana\\78-0.png',
#  'E:/capstone/Dataset/possible_Ones/bhujangasana\\79-1.png',
#  'E:/capstone/Dataset/possible_Ones/bhujangasana\\8-0.png',
#  'E:/capstone/Dataset/possible_Ones/bhujangasana\\80-0.png',
#  'E:/capstone/Dataset/possible_Ones/bhujangasana\\82-0.png',
#  'E:/capstone/Dataset/possible_Ones/bhujangasana\\82-1.png',
#  'E:/capstone/Dataset/possible_Ones/bhujangasana\\83-1.png',
#  'E:/capstone/Dataset/possible_Ones/bhujangasana\\84-0.png',
#  'E:/capstone/Dataset/possible_Ones/bhujangasana\\85-0.png',
#  'E:/capstone/Dataset/possible_Ones/bhujangasana\\87-0.png',
#  'E:/capstone/Dataset/possible_Ones/bhujangasana\\88-0.png',
#  'E:/capstone/Dataset/possible_Ones/bhujangasana\\89-0.png',
#  'E:/capstone/Dataset/possible_Ones/bhujangasana\\9-0.png',
#  'E:/capstone/Dataset/possible_Ones/bhujangasana\\90-0.png',
#  'E:/capstone/Dataset/possible_Ones/bhujangasana\\91-0.png',
#  'E:/capstone/Dataset/possible_Ones/bhujangasana\\92-0.png',
#  'E:/capstone/Dataset/possible_Ones/bhujangasana\\95-0.png',
#  'E:/capstone/Dataset/possible_Ones/bhujangasana\\96-0.png',
#  'E:/capstone/Dataset/possible_Ones/bhujangasana\\97-0.png',
#  'E:/capstone/Dataset/possible_Ones/bhujangasana\\98-0.png',
#  'E:/capstone/Dataset/possible_Ones/bhujangasana\\99-0.png']

# %% [markdown]
# # testing

# %%
import csv


def calculate_angles(a,b,c):
    a = np.array(a) # First
    b = np.array(b) # Second 
    c = np.array(c) # Third
    
    radians = np.arctan2(c[1]-b[1], c[0]-b[0]) - np.arctan2(a[1]-b[1], a[0]-b[0])
    angle = np.abs(radians*180.0/np.pi)
    
    if angle > 180.0:
        angle = 360-angle
    return angle


# left_arm_data = []
# right_arm_data = []
# left_leg_data = []
# right_leg_data = []

lower_body=[]
middle_body=[]
upper_body=[]



for image_path in image_paths:
#     image_path = "E:/capstone/Capstone_Project/DATASET/TEST/tree\\00000031.jpg"
    output = cv2.imread(image_path)

    image_pose = output 
    pose = pose_image
    draw = True
    display = True
    # def detectPose(image_pose, pose, draw=False, display=False):

    original_image = image_pose.copy()

    image_in_RGB = cv2.cvtColor(image_pose, cv2.COLOR_BGR2RGB)

    resultant = pose.process(image_in_RGB)
    
    if resultant.pose_landmarks and draw:    


        landmarks = resultant.pose_landmarks.landmark



    ####################################################################
        right_shoulder = [landmarks[mp_pose.PoseLandmark.RIGHT_SHOULDER.value].x,landmarks[mp_pose.PoseLandmark.RIGHT_SHOULDER.value].y] 
        left_shoulder = [landmarks[mp_pose.PoseLandmark.LEFT_SHOULDER.value].x,landmarks[mp_pose.PoseLandmark.LEFT_SHOULDER.value].y]

        right_elbow = [landmarks[mp_pose.PoseLandmark.RIGHT_ELBOW.value].x,landmarks[mp_pose.PoseLandmark.RIGHT_ELBOW.value].y]
        left_elbow = [landmarks[mp_pose.PoseLandmark.LEFT_ELBOW.value].x,landmarks[mp_pose.PoseLandmark.LEFT_ELBOW.value].y]

        right_wrist = [landmarks[mp_pose.PoseLandmark.RIGHT_WRIST.value].x,landmarks[mp_pose.PoseLandmark.RIGHT_WRIST.value].y]
        left_wrist = [landmarks[mp_pose.PoseLandmark.LEFT_WRIST.value].x,landmarks[mp_pose.PoseLandmark.LEFT_WRIST.value].y]

        right_hip = [landmarks[mp_pose.PoseLandmark.RIGHT_HIP.value].x,landmarks[mp_pose.PoseLandmark.RIGHT_HIP.value].y]
        left_hip = [landmarks[mp_pose.PoseLandmark.LEFT_HIP.value].x,landmarks[mp_pose.PoseLandmark.LEFT_HIP.value].y]


        right_knee = [landmarks[mp_pose.PoseLandmark.RIGHT_KNEE.value].x,landmarks[mp_pose.PoseLandmark.RIGHT_KNEE.value].y]
        left_knee = [landmarks[mp_pose.PoseLandmark.LEFT_KNEE.value].x,landmarks[mp_pose.PoseLandmark.LEFT_KNEE.value].y]

        right_ankle = [landmarks[mp_pose.PoseLandmark.RIGHT_ANKLE.value].x,landmarks[mp_pose.PoseLandmark.RIGHT_ANKLE.value].y]
        left_ankle = [landmarks[mp_pose.PoseLandmark.LEFT_ANKLE.value].x,landmarks[mp_pose.PoseLandmark.LEFT_ANKLE.value].y]




















    #########################################################
        # CALCULATE THE ANGLE
    #     angle_la = calculate_angles(left_wrist,left_elbow,left_shoulder)  
    #     angle_ra = calculate_angles(right_wrist,right_elbow,right_shoulder)  
    #     angle_ll = calculate_angles(left_hip,left_knee,left_ankle)  
    #     angle_rl = calculate_angles(right_hip,right_knee,right_ankle)  


        lower_body_1 = calculate_angles(left_ankle,left_knee,left_hip)
        lower_body_2 = calculate_angles(right_ankle,right_knee,right_hip)

        middle_body_1 = calculate_angles(left_knee,left_hip,left_shoulder)
        middle_body_2 = calculate_angles(right_knee,right_hip,right_shoulder)

        upper_body_1 = calculate_angles(left_shoulder,left_elbow,left_wrist)
        upper_body_2 = calculate_angles(right_shoulder,right_elbow,right_wrist)



    #     print(angle)


    #     arms_data.append(angle)

    #     left_arm_data.append(angle_la)
    #     right_arm_data.append(angle_ra)
    #     left_leg_data.append(angle_ll)
    #     right_leg_data.append(angle_rl)

        lower_body.append(lower_body_1)
        lower_body.append(lower_body_2)
        middle_body.append(middle_body_1)
        middle_body.append(middle_body_2)
        upper_body.append(upper_body_1)
        upper_body.append(upper_body_2)



    # Sample data
    # data = [angle]

    # # Specify the file name
    # csv_file = "data.csv"

    # # Write data to CSV file
    # with open(csv_file, mode='a', newline='') as file:
    #     writer = csv.writer(file)
    #     writer.writerow(data)

# %%
import csv

# Sample data

data = zip(lower_body,middle_body,upper_body)
# Specify the file name
csv_file = "bhujangasana.csv"

# Write data to CSV file
with open(csv_file, mode='a', newline="") as file:
    writer = csv.writer(file)
    writer.writerow(['LOWER-BODY','MIDDLE-BODY','UPPER-BODY'])
    
    for row in data:
        writer.writerow(row)

# %%
import pandas as pd
df = pd.read_csv('bhujangasana.csv')

# %%
df.head()
# Out:
#    LOWER-BODY  MIDDLE-BODY  UPPER-BODY
# 0  174.966750   127.755857  126.802544
# 1  175.833686   117.716890  120.954162
# 2   75.234221   172.262083  149.268466
# 3  123.664627   153.831513  159.985745
# 4  148.502634   126.829454  171.642230

# %%
s=0
lb=0
ub=0
mb=0
for i in lower_body:
    s+=i
lb=s/len(lower_body)
s=0
for i in middle_body:
    s+=i
mb=s/len(middle_body)
s=0
for i in upper_body:
    s+=i
ub=s/len(upper_body)

# %%
print("LB:",lb,"\nMB: ",mb,"\nUB: ",ub)
# Out:
# LB: 152.6851541569787
# MB:  123.1402159361457
# UB:  156.79654376008088

# %%
print("LB:",lb,"\nMB: ",mb,"\nUB: ",ub)
# Out:
# LB: 152.6851541569787
# MB:  123.1402159361457
# UB:  156.79654376008088

# %% [markdown]
# # setu bandha sarvangasana

# %%
import os
from PIL import Image

# Folder path containing images
folder_path = "E:/capstone/Dataset/possible_Ones/setu bandha sarvangasana"

# # List to store image data
# images = []

# # Iterate over files in the folder
# for filename in os.listdir(folder_path):
#     # Check if the file is an image (you might want to add more image extensions)
#     if filename.endswith(".jpg") or filename.endswith(".png"):
#         # Construct the full file path
#         file_path = os.path.join(folder_path, filename)
#         # Open the image using Pillow
#         img = Image.open(file_path)
#         # Append the image to the list
#         images.append(img)
#         # You can perform any processing or testing here with the image

# # Now you have all the images loaded in the 'images' list
# # You can loop through this list to perform testing or processing




# List to store image paths
image_paths = []

# Iterate over files in the folder
for filename in os.listdir(folder_path):
    # Check if the file is an image (you might want to add more image extensions)
    if filename.endswith(".jpg") or filename.endswith(".png"):
        # Construct the full file path
        file_path = os.path.join(folder_path, filename)
        # Append the file path to the list
        file_path.replace("\\",'/')
        image_paths.append(file_path)

# %%
image_paths
# Out:
# ['E:/capstone/Dataset/possible_Ones/setu bandha sarvangasana\\1-0.png',
#  'E:/capstone/Dataset/possible_Ones/setu bandha sarvangasana\\10-0.png',
#  'E:/capstone/Dataset/possible_Ones/setu bandha sarvangasana\\11-0.png',
#  'E:/capstone/Dataset/possible_Ones/setu bandha sarvangasana\\14-0.png',
#  'E:/capstone/Dataset/possible_Ones/setu bandha sarvangasana\\15-0.png',
#  'E:/capstone/Dataset/possible_Ones/setu bandha sarvangasana\\16-0.png',
#  'E:/capstone/Dataset/possible_Ones/setu bandha sarvangasana\\19-0.png',
#  'E:/capstone/Dataset/possible_Ones/setu bandha sarvangasana\\2-0.png',
#  'E:/capstone/Dataset/possible_Ones/setu bandha sarvangasana\\20-0.png',
#  'E:/capstone/Dataset/possible_Ones/setu bandha sarvangasana\\21-0.png',
#  'E:/capstone/Dataset/possible_Ones/setu bandha sarvangasana\\22-0.png',
#  'E:/capstone/Dataset/possible_Ones/setu bandha sarvangasana\\23-0.png',
#  'E:/capstone/Dataset/possible_Ones/setu bandha sarvangasana\\24-0.png',
#  'E:/capstone/Dataset/possible_Ones/setu bandha sarvangasana\\25-0.png',
#  'E:/capstone/Dataset/possible_Ones/setu bandha sarvangasana\\26-0.png',
#  'E:/capstone/Dataset/possible_Ones/setu bandha sarvangasana\\28-0.png',
#  'E:/capstone/Dataset/possible_Ones/setu bandha sarvangasana\\29-0.png',
#  'E:/capstone/Dataset/possible_Ones/setu bandha sarvangasana\\30-0.png',
#  'E:/capstone/Dataset/possible_Ones/setu bandha sarvangasana\\31-0.png',
#  'E:/capstone/Dataset/possible_Ones/setu bandha sarvangasana\\32-0.png',
#  'E:/capstone/Dataset/possible_Ones/setu bandha sarvangasana\\33-0.png',
#  'E:/capstone/Dataset/possible_Ones/setu bandha sarvangasana\\34-0.png',
#  'E:/capstone/Dataset/possible_Ones/setu bandha sarvangasana\\35-0.png',
#  'E:/capstone/Dataset/possible_Ones/setu bandha sarvangasana\\39-0.png',
#  'E:/capstone/Dataset/possible_Ones/setu bandha sarvangasana\\4-0.png',
#  'E:/capstone/Dataset/possible_Ones/setu bandha sarvangasana\\41-0.png',
#  'E:/capstone/Dataset/possible_Ones/setu bandha sarvangasana\\42-0.png',
#  'E:/capstone/Dataset/possible_Ones/setu bandha sarvangasana\\43-0.png',
#  'E:/capstone/Dataset/possible_Ones/setu bandha sarvangasana\\44-0.png',
#  'E:/capstone/Dataset/possible_Ones/setu bandha sarvangasana\\45-0.png',
#  'E:/capstone/Dataset/possible_Ones/setu bandha sarvangasana\\46-0.png',
#  'E:/capstone/Dataset/possible_Ones/setu bandha sarvangasana\\47-0.png',
#  'E:/capstone/Dataset/possible_Ones/setu bandha sarvangasana\\48-0.png',
#  'E:/capstone/Dataset/possible_Ones/setu bandha sarvangasana\\49-0.png',
#  'E:/capstone/Dataset/possible_Ones/setu bandha sarvangasana\\5-0.png',
#  'E:/capstone/Dataset/possible_Ones/setu bandha sarvangasana\\51-0.png',
#  'E:/capstone/Dataset/possible_Ones/setu bandha sarvangasana\\52-0.png',
#  'E:/capstone/Dataset/possible_Ones/setu bandha sarvangasana\\53-0.png',
#  'E:/capstone/Dataset/possible_Ones/setu bandha sarvangasana\\54-0.png',
#  'E:/capstone/Dataset/possible_Ones/setu bandha sarvangasana\\55-0.png',
#  'E:/capstone/Dataset/possible_Ones/setu bandha sarvangasana\\56-0.png',
#  'E:/capstone/Dataset/possible_Ones/setu bandha sarvangasana\\58-0.png',
#  'E:/capstone/Dataset/possible_Ones/setu bandha sarvangasana\\59-0.png',
#  'E:/capstone/Dataset/possible_Ones/setu bandha sarvangasana\\60-0.png',
#  'E:/capstone/Dataset/possible_Ones/setu bandha sarvangasana\\61-0.png',
#  'E:/capstone/Dataset/possible_Ones/setu bandha sarvangasana\\62-0.png',
#  'E:/capstone/Dataset/possible_Ones/setu bandha sarvangasana\\File10.jpg',
#  'E:/capstone/Dataset/possible_Ones/setu bandha sarvangasana\\File24.jpg',
#  'E:/capstone/Dataset/possible_Ones/setu bandha sarvangasana\\File25.jpg',
#  'E:/capstone/Dataset/possible_Ones/setu bandha sarvangasana\\File30.jpg',
#  'E:/capstone/Dataset/possible_Ones/setu bandha sarvangasana\\File34.png',
#  'E:/capstone/Dataset/possible_Ones/setu bandha sarvangasana\\File38.jpg',
#  'E:/capstone/Dataset/possible_Ones/setu bandha sarvangasana\\File42.jpg',
#  'E:/capstone/Dataset/possible_Ones/setu bandha sarvangasana\\File45.jpg',
#  'E:/capstone/Dataset/possible_Ones/setu bandha sarvangasana\\File51.jpg',
#  'E:/capstone/Dataset/possible_Ones/setu bandha sarvangasana\\File56.jpg',
#  'E:/capstone/Dataset/possible_Ones/setu bandha sarvangasana\\File62.jpg',
#  'E:/capstone/Dataset/possible_Ones/setu bandha sarvangasana\\File63.jpg']

# %% [markdown]
# # testing

# %%
import csv


def calculate_angles(a,b,c):
    a = np.array(a) # First
    b = np.array(b) # Second 
    c = np.array(c) # Third
    
    radians = np.arctan2(c[1]-b[1], c[0]-b[0]) - np.arctan2(a[1]-b[1], a[0]-b[0])
    angle = np.abs(radians*180.0/np.pi)
    
    if angle > 180.0:
        angle = 360-angle
    return angle


# left_arm_data = []
# right_arm_data = []
# left_leg_data = []
# right_leg_data = []

legs=[]
hips=[]
shoulder=[]
arms=[]



for image_path in image_paths:
#     image_path = "E:/capstone/Capstone_Project/DATASET/TEST/tree\\00000031.jpg"
    output = cv2.imread(image_path)

    image_pose = output 
    pose = pose_image
    draw = True
    display = True
    # def detectPose(image_pose, pose, draw=False, display=False):

    original_image = image_pose.copy()

    image_in_RGB = cv2.cvtColor(image_pose, cv2.COLOR_BGR2RGB)

    resultant = pose.process(image_in_RGB)
    
    if resultant.pose_landmarks and draw:    


        landmarks = resultant.pose_landmarks.landmark



    ####################################################################
        right_shoulder = [landmarks[mp_pose.PoseLandmark.RIGHT_SHOULDER.value].x,landmarks[mp_pose.PoseLandmark.RIGHT_SHOULDER.value].y] 
        left_shoulder = [landmarks[mp_pose.PoseLandmark.LEFT_SHOULDER.value].x,landmarks[mp_pose.PoseLandmark.LEFT_SHOULDER.value].y]

        right_elbow = [landmarks[mp_pose.PoseLandmark.RIGHT_ELBOW.value].x,landmarks[mp_pose.PoseLandmark.RIGHT_ELBOW.value].y]
        left_elbow = [landmarks[mp_pose.PoseLandmark.LEFT_ELBOW.value].x,landmarks[mp_pose.PoseLandmark.LEFT_ELBOW.value].y]

        right_wrist = [landmarks[mp_pose.PoseLandmark.RIGHT_WRIST.value].x,landmarks[mp_pose.PoseLandmark.RIGHT_WRIST.value].y]
        left_wrist = [landmarks[mp_pose.PoseLandmark.LEFT_WRIST.value].x,landmarks[mp_pose.PoseLandmark.LEFT_WRIST.value].y]

        right_hip = [landmarks[mp_pose.PoseLandmark.RIGHT_HIP.value].x,landmarks[mp_pose.PoseLandmark.RIGHT_HIP.value].y]
        left_hip = [landmarks[mp_pose.PoseLandmark.LEFT_HIP.value].x,landmarks[mp_pose.PoseLandmark.LEFT_HIP.value].y]


        right_knee = [landmarks[mp_pose.PoseLandmark.RIGHT_KNEE.value].x,landmarks[mp_pose.PoseLandmark.RIGHT_KNEE.value].y]
        left_knee = [landmarks[mp_pose.PoseLandmark.LEFT_KNEE.value].x,landmarks[mp_pose.PoseLandmark.LEFT_KNEE.value].y]

        right_ankle = [landmarks[mp_pose.PoseLandmark.RIGHT_ANKLE.value].x,landmarks[mp_pose.PoseLandmark.RIGHT_ANKLE.value].y]
        left_ankle = [landmarks[mp_pose.PoseLandmark.LEFT_ANKLE.value].x,landmarks[mp_pose.PoseLandmark.LEFT_ANKLE.value].y]




















    #########################################################
        # CALCULATE THE ANGLE
    #     angle_la = calculate_angles(left_wrist,left_elbow,left_shoulder)  
    #     angle_ra = calculate_angles(right_wrist,right_elbow,right_shoulder)  
    #     angle_ll = calculate_angles(left_hip,left_knee,left_ankle)  
    #     angle_rl = calculate_angles(right_hip,right_knee,right_ankle)  


        leg_1 = calculate_angles(left_ankle,left_knee,left_hip)
        leg_2 = calculate_angles(right_ankle,right_knee,right_hip)

        hip_1 = calculate_angles(left_knee,left_hip,left_shoulder)
        hip_2 = calculate_angles(right_knee,right_hip,right_shoulder)

        shoulder_1 = calculate_angles(left_hip,left_shoulder,left_elbow)
        shoulder_2 = calculate_angles(right_hip,right_shoulder,right_elbow)
        
        arms_1 = calculate_angles(left_shoulder,left_elbow,left_wrist)
        arms_2 = calculate_angles(right_shoulder,right_elbow,right_wrist)



    #     print(angle)


    #     arms_data.append(angle)

    #     left_arm_data.append(angle_la)
    #     right_arm_data.append(angle_ra)
    #     left_leg_data.append(angle_ll)
    #     right_leg_data.append(angle_rl)

        legs.append(leg_1)
        legs.append(leg_2)
        hips.append(hip_1)
        hips.append(hip_2)
        shoulder.append(shoulder_1)
        shoulder.append(shoulder_2)
        arms.append(arms_1)
        arms.append(arms_2)



    # Sample data
    # data = [angle]

    # # Specify the file name
    # csv_file = "data.csv"

    # # Write data to CSV file
    # with open(csv_file, mode='a', newline='') as file:
    #     writer = csv.writer(file)
    #     writer.writerow(data)

# %%
import csv

# Sample data

data = zip(legs,hips,shoulder,arms)
# Specify the file name
csv_file = "setu_bandha_sarvangasana.csv"

# Write data to CSV file
with open(csv_file, mode='a', newline="") as file:
    writer = csv.writer(file)
    writer.writerow(['LEGS','HIPS','SHOULDER','ARMS'])
    
    for row in data:
        writer.writerow(row)

# %%
import pandas as pd
df = pd.read_csv('setu_bandha_sarvangasana.csv')

# %%
df.head()
# Out:
#         LEGS        HIPS   SHOULDER        ARMS
# 0  43.690477  177.699583  72.918715  144.503815
# 1  44.466126  179.974818  70.193697  129.620883
# 2  61.220540  143.662298  59.303318  168.625265
# 3  69.759382  141.803457  64.175534  170.256971
# 4  67.040498  177.861715  45.491088   57.759245

# %%
legs
# Out:
# [43.69047722368328,
#  44.466126293121086,
#  61.22053958271469,
#  69.75938216679228,
#  67.04049839723537,
#  125.07991795798858,
#  63.140730305189784,
#  67.37398437726364,
#  70.38695655659455,
#  75.91357715127819,
#  43.78469474474429,
#  38.907064316664794,
#  67.50959612666769,
#  61.346801119583176,
#  61.16013696663371,
#  55.41011085701858,
#  174.61189182022605,
#  173.8937630381772,
#  98.40329019399705,
#  116.01201944343205,
#  65.81513875997095,
#  65.27282639510928,
#  49.70127869868551,
#  48.974773572336076,
#  108.23185894566532,
#  108.46065887539334,
#  30.521233453854972,
#  34.93890939354317,
#  83.28848777092294,
#  61.3302469745951,
#  80.51812310052567,
#  86.54606607747242,
#  28.80991907198399,
#  25.223708125887995,
#  68.86883517913896,
#  68.0650491989194,
#  63.12834165511203,
#  57.471301695112075,
#  36.335682815179666,
#  28.95828992378213,
#  51.16135721489196,
#  49.250861718870645,
#  56.61458153616731,
#  50.25148957602277,
#  65.20262058100487,
#  64.97284419184342,
#  60.15244011095435,
#  49.75429892464556,
#  53.19368918457537,
#  43.26050525696094,
#  47.166602736355564,
#  48.65698594918665,
#  22.00814784843818,
#  22.224918655541707,
#  96.34859019620082,
#  111.23369412980506,
#  19.242039621243837,
#  31.483164978175957,
#  46.390590582653196,
#  41.56189113674561,
#  45.33979104192216,
#  53.54123067826105,
#  72.22012752060692,
#  68.60586214220987,
#  64.17776073543243,
#  70.95253239271614,
#  53.1973451457467,
#  55.077754270749466,
#  56.20933157741746,
#  96.8659745539246,
#  45.45644191807437,
#  49.63781474761564,
#  72.18543183147904,
#  73.36711357583938,
#  33.392365428968354,
#  35.924102549367305,
#  60.8870481052073,
#  54.50224630655787,
#  54.87664119320138,
#  60.32156712834691,
#  50.224374816888485,
#  42.502265456894314,
#  76.19725098451829,
#  89.02898220145812,
#  47.51948290140752,
#  46.78849457092013,
#  72.06430083724103,
#  72.95739126122923,
#  44.1170834295876,
#  35.493296573661,
#  83.91064297147905,
#  64.25865285643758,
#  71.42745319752161,
#  64.67769996937513,
#  50.606746972222666,
#  47.12293365637646,
#  48.260250967670586,
#  43.718658318575436,
#  77.96543789902961,
#  83.01414322622645,
#  77.06067269243813,
#  75.88884946192441,
#  73.26712968276445,
#  78.08130111790199,
#  77.35478202202289,
#  84.32309452057855,
#  50.33796651173484,
#  45.632491993307326,
#  61.29752193655354,
#  69.23191507095521,
#  60.498062291912795,
#  54.35349128742412,
#  71.4079087617628,
#  72.953272320494]

# %%
s=0
ARM=0
SHOULDER=0
HIP=0
LEG=0
for i in arms:
    s+=i
ARM=s/len(arms)
s=0
for i in shoulder:
    s+=i
SHOULDER=s/len(shoulder)
s=0
for i in hips:
    s+=i
HIP=s/len(hips)
s=0
for i in legs:
    s+=i
LEG=s/len(legs)

# %%
print("ARMS:",ARM,"\nSHOULDER: ",SHOULDER,"\nHIPS: ",HIP,"\nLEGS: ",LEG)
# Out:
# ARMS: 156.54029001671586
# SHOULDER:  68.14830332107572
# HIPS:  154.32994997869338
# LEGS:  62.71917621084754

# %% [markdown]
# # utthita trikonasana

# %%
import os
from PIL import Image

# Folder path containing images
folder_path = "E:/capstone/Dataset/possible_Ones/utthita trikonasana"

# # List to store image data
# images = []

# # Iterate over files in the folder
# for filename in os.listdir(folder_path):
#     # Check if the file is an image (you might want to add more image extensions)
#     if filename.endswith(".jpg") or filename.endswith(".png"):
#         # Construct the full file path
#         file_path = os.path.join(folder_path, filename)
#         # Open the image using Pillow
#         img = Image.open(file_path)
#         # Append the image to the list
#         images.append(img)
#         # You can perform any processing or testing here with the image

# # Now you have all the images loaded in the 'images' list
# # You can loop through this list to perform testing or processing




# List to store image paths
image_paths = []

# Iterate over files in the folder
for filename in os.listdir(folder_path):
    # Check if the file is an image (you might want to add more image extensions)
    if filename.endswith(".jpg") or filename.endswith(".png"):
        # Construct the full file path
        file_path = os.path.join(folder_path, filename)
        # Append the file path to the list
        file_path.replace("\\",'/')
        image_paths.append(file_path)

# %%
image_paths
# Out:
# ['E:/capstone/Dataset/possible_Ones/utthita trikonasana\\0-0.png',
#  'E:/capstone/Dataset/possible_Ones/utthita trikonasana\\1-0.png',
#  'E:/capstone/Dataset/possible_Ones/utthita trikonasana\\10-0.png',
#  'E:/capstone/Dataset/possible_Ones/utthita trikonasana\\11-0.png',
#  'E:/capstone/Dataset/possible_Ones/utthita trikonasana\\11-1.png',
#  'E:/capstone/Dataset/possible_Ones/utthita trikonasana\\11-2.png',
#  'E:/capstone/Dataset/possible_Ones/utthita trikonasana\\12-0.png',
#  'E:/capstone/Dataset/possible_Ones/utthita trikonasana\\13-0.png',
#  'E:/capstone/Dataset/possible_Ones/utthita trikonasana\\14-0.png',
#  'E:/capstone/Dataset/possible_Ones/utthita trikonasana\\15-0.png',
#  'E:/capstone/Dataset/possible_Ones/utthita trikonasana\\16-0.png',
#  'E:/capstone/Dataset/possible_Ones/utthita trikonasana\\17-0.png',
#  'E:/capstone/Dataset/possible_Ones/utthita trikonasana\\17-1.png',
#  'E:/capstone/Dataset/possible_Ones/utthita trikonasana\\19-0.png',
#  'E:/capstone/Dataset/possible_Ones/utthita trikonasana\\2-0.png',
#  'E:/capstone/Dataset/possible_Ones/utthita trikonasana\\20-0.png',
#  'E:/capstone/Dataset/possible_Ones/utthita trikonasana\\21-0.png',
#  'E:/capstone/Dataset/possible_Ones/utthita trikonasana\\22-0.png',
#  'E:/capstone/Dataset/possible_Ones/utthita trikonasana\\24-0.png',
#  'E:/capstone/Dataset/possible_Ones/utthita trikonasana\\25-0.png',
#  'E:/capstone/Dataset/possible_Ones/utthita trikonasana\\26-0.png',
#  'E:/capstone/Dataset/possible_Ones/utthita trikonasana\\27-0.png',
#  'E:/capstone/Dataset/possible_Ones/utthita trikonasana\\28-0.png',
#  'E:/capstone/Dataset/possible_Ones/utthita trikonasana\\3-0.png',
#  'E:/capstone/Dataset/possible_Ones/utthita trikonasana\\3-1.png',
#  'E:/capstone/Dataset/possible_Ones/utthita trikonasana\\30-0.png',
#  'E:/capstone/Dataset/possible_Ones/utthita trikonasana\\31-0.png',
#  'E:/capstone/Dataset/possible_Ones/utthita trikonasana\\32-0.png',
#  'E:/capstone/Dataset/possible_Ones/utthita trikonasana\\34-0.png',
#  'E:/capstone/Dataset/possible_Ones/utthita trikonasana\\36-0.png',
#  'E:/capstone/Dataset/possible_Ones/utthita trikonasana\\37-0.png',
#  'E:/capstone/Dataset/possible_Ones/utthita trikonasana\\38-0.png',
#  'E:/capstone/Dataset/possible_Ones/utthita trikonasana\\39-0.png',
#  'E:/capstone/Dataset/possible_Ones/utthita trikonasana\\4-0.png',
#  'E:/capstone/Dataset/possible_Ones/utthita trikonasana\\40-0.png',
#  'E:/capstone/Dataset/possible_Ones/utthita trikonasana\\41-0.png',
#  'E:/capstone/Dataset/possible_Ones/utthita trikonasana\\42-0.png',
#  'E:/capstone/Dataset/possible_Ones/utthita trikonasana\\43-0.png',
#  'E:/capstone/Dataset/possible_Ones/utthita trikonasana\\44-0.png',
#  'E:/capstone/Dataset/possible_Ones/utthita trikonasana\\45-0.png',
#  'E:/capstone/Dataset/possible_Ones/utthita trikonasana\\47-0.png',
#  'E:/capstone/Dataset/possible_Ones/utthita trikonasana\\48-0.png',
#  'E:/capstone/Dataset/possible_Ones/utthita trikonasana\\49-0.png',
#  'E:/capstone/Dataset/possible_Ones/utthita trikonasana\\51-0.png',
#  'E:/capstone/Dataset/possible_Ones/utthita trikonasana\\53-0.png',
#  'E:/capstone/Dataset/possible_Ones/utthita trikonasana\\55-0.png',
#  'E:/capstone/Dataset/possible_Ones/utthita trikonasana\\56-0.png',
#  'E:/capstone/Dataset/possible_Ones/utthita trikonasana\\6-0.png',
#  'E:/capstone/Dataset/possible_Ones/utthita trikonasana\\60-0.png',
#  'E:/capstone/Dataset/possible_Ones/utthita trikonasana\\61-0.png',
#  'E:/capstone/Dataset/possible_Ones/utthita trikonasana\\62-1.png',
#  'E:/capstone/Dataset/possible_Ones/utthita trikonasana\\66-0.png',
#  'E:/capstone/Dataset/possible_Ones/utthita trikonasana\\67-0.png',
#  'E:/capstone/Dataset/possible_Ones/utthita trikonasana\\68-0.png',
#  'E:/capstone/Dataset/possible_Ones/utthita trikonasana\\69-0.png',
#  'E:/capstone/Dataset/possible_Ones/utthita trikonasana\\7-0.png',
#  'E:/capstone/Dataset/possible_Ones/utthita trikonasana\\70-0.png',
#  'E:/capstone/Dataset/possible_Ones/utthita trikonasana\\71-0.png',
#  'E:/capstone/Dataset/possible_Ones/utthita trikonasana\\71-1.png',
#  'E:/capstone/Dataset/possible_Ones/utthita trikonasana\\72-0.png',
#  'E:/capstone/Dataset/possible_Ones/utthita trikonasana\\75-0.png',
#  'E:/capstone/Dataset/possible_Ones/utthita trikonasana\\8-0.png',
#  'E:/capstone/Dataset/possible_Ones/utthita trikonasana\\84-0.png',
#  'E:/capstone/Dataset/possible_Ones/utthita trikonasana\\86-0.png',
#  'E:/capstone/Dataset/possible_Ones/utthita trikonasana\\88-0.png',
#  'E:/capstone/Dataset/possible_Ones/utthita trikonasana\\89-0.png',
#  'E:/capstone/Dataset/possible_Ones/utthita trikonasana\\9-0.png',
#  'E:/capstone/Dataset/possible_Ones/utthita trikonasana\\93-0.png',
#  'E:/capstone/Dataset/possible_Ones/utthita trikonasana\\97-1.png']

# %% [markdown]
# # testing

# %%
import csv


def calculate_angles(a,b,c):
    a = np.array(a) # First
    b = np.array(b) # Second 
    c = np.array(c) # Third
    
    radians = np.arctan2(c[1]-b[1], c[0]-b[0]) - np.arctan2(a[1]-b[1], a[0]-b[0])
    angle = np.abs(radians*180.0/np.pi)
    
    if angle > 180.0:
        angle = 360-angle
    return angle


# left_arm_data = []
# right_arm_data = []
# left_leg_data = []
# right_leg_data = []

legs=[]
hips=[]
shoulder=[]
arms=[]

hip_cone=[]

for image_path in image_paths:
#     image_path = "E:/capstone/Capstone_Project/DATASET/TEST/tree\\00000031.jpg"
    output = cv2.imread(image_path)

    image_pose = output 
    pose = pose_image
    draw = True
    display = True
    # def detectPose(image_pose, pose, draw=False, display=False):

    original_image = image_pose.copy()

    image_in_RGB = cv2.cvtColor(image_pose, cv2.COLOR_BGR2RGB)

    resultant = pose.process(image_in_RGB)
    
    if resultant.pose_landmarks and draw:    


        landmarks = resultant.pose_landmarks.landmark



    ####################################################################
        right_shoulder = [landmarks[mp_pose.PoseLandmark.RIGHT_SHOULDER.value].x,landmarks[mp_pose.PoseLandmark.RIGHT_SHOULDER.value].y] 
        left_shoulder = [landmarks[mp_pose.PoseLandmark.LEFT_SHOULDER.value].x,landmarks[mp_pose.PoseLandmark.LEFT_SHOULDER.value].y]

        right_elbow = [landmarks[mp_pose.PoseLandmark.RIGHT_ELBOW.value].x,landmarks[mp_pose.PoseLandmark.RIGHT_ELBOW.value].y]
        left_elbow = [landmarks[mp_pose.PoseLandmark.LEFT_ELBOW.value].x,landmarks[mp_pose.PoseLandmark.LEFT_ELBOW.value].y]

        right_wrist = [landmarks[mp_pose.PoseLandmark.RIGHT_WRIST.value].x,landmarks[mp_pose.PoseLandmark.RIGHT_WRIST.value].y]
        left_wrist = [landmarks[mp_pose.PoseLandmark.LEFT_WRIST.value].x,landmarks[mp_pose.PoseLandmark.LEFT_WRIST.value].y]

        right_hip = [landmarks[mp_pose.PoseLandmark.RIGHT_HIP.value].x,landmarks[mp_pose.PoseLandmark.RIGHT_HIP.value].y]
        mid_hip_pt = [(left_hip[0]+right_hip[0])/2 , (left_hip[1]+right_hip[1])/2]
        left_hip = [landmarks[mp_pose.PoseLandmark.LEFT_HIP.value].x,landmarks[mp_pose.PoseLandmark.LEFT_HIP.value].y]

        print("L: ",left_hip,"\nR: ",right_hip,"\n",mid_hip_pt)

        right_knee = [landmarks[mp_pose.PoseLandmark.RIGHT_KNEE.value].x,landmarks[mp_pose.PoseLandmark.RIGHT_KNEE.value].y]
        left_knee = [landmarks[mp_pose.PoseLandmark.LEFT_KNEE.value].x,landmarks[mp_pose.PoseLandmark.LEFT_KNEE.value].y]

        right_ankle = [landmarks[mp_pose.PoseLandmark.RIGHT_ANKLE.value].x,landmarks[mp_pose.PoseLandmark.RIGHT_ANKLE.value].y]
        left_ankle = [landmarks[mp_pose.PoseLandmark.LEFT_ANKLE.value].x,landmarks[mp_pose.PoseLandmark.LEFT_ANKLE.value].y]




















    #########################################################
        # CALCULATE THE ANGLE
    #     angle_la = calculate_angles(left_wrist,left_elbow,left_shoulder)  
    #     angle_ra = calculate_angles(right_wrist,right_elbow,right_shoulder)  
    #     angle_ll = calculate_angles(left_hip,left_knee,left_ankle)  
    #     angle_rl = calculate_angles(right_hip,right_knee,right_ankle)  
        

        leg_1 = calculate_angles(left_ankle,left_knee,left_hip)
        leg_2 = calculate_angles(right_ankle,right_knee,right_hip)

        hip_1 = calculate_angles(left_knee,left_hip,left_shoulder)
        hip_triangle = calculate_angles(left_ankle,mid_hip_pt,right_ankle)
        hip_2 = calculate_angles(right_knee,right_hip,right_shoulder)

        shoulder_1 = calculate_angles(left_hip,left_shoulder,left_elbow)
        shoulder_2 = calculate_angles(right_hip,right_shoulder,right_elbow)
        
        arms_1 = calculate_angles(left_shoulder,left_elbow,left_wrist)
        arms_2 = calculate_angles(right_shoulder,right_elbow,right_wrist)



    #     print(angle)


    #     arms_data.append(angle)

    #     left_arm_data.append(angle_la)
    #     right_arm_data.append(angle_ra)
    #     left_leg_data.append(angle_ll)
    #     right_leg_data.append(angle_rl)

        legs.append(leg_1)
        legs.append(leg_2)
        hips.append(hip_1)
        hips.append(hip_2)
        shoulder.append(shoulder_1)
        shoulder.append(shoulder_2)
        arms.append(arms_1)
        arms.append(arms_2)
        hip_cone.append(hip_triangle)


    # Sample data
    # data = [angle]

    # # Specify the file name
    # csv_file = "data.csv"

    # # Write data to CSV file
    # with open(csv_file, mode='a', newline='') as file:
    #     writer = csv.writer(file)
    #     writer.writerow(data)
# Out:
# L:  [0.4481692314147949, 0.5867918729782104]
# R:  [0.37842974066734314, 0.5222099423408508]
#  [0.4256267696619034, 0.5772292912006378]
# L:  [0.37534207105636597, 0.5980386137962341]
# R:  [0.2052152454853058, 0.5391913652420044]
#  [0.32669223845005035, 0.5629916191101074]
# L:  [0.6029983162879944, 0.23983821272850037]
# R:  [0.5344739556312561, 0.33428382873535156]
#  [0.45490801334381104, 0.46616122126579285]
# L:  [0.33680522441864014, 0.5369276404380798]
# R:  [0.42491641640663147, 0.6031737923622131]
#  [0.5139573663473129, 0.42150600254535675]
# L:  [0.32509616017341614, 0.4698545038700104]
# R:  [0.3501840829849243, 0.515660285949707]
#  [0.3434946537017822, 0.5262939631938934]
# L:  [0.230423241853714, 0.19216138124465942]
# R:  [0.23216475546360016, 0.2481565773487091]
#  [0.27863045781850815, 0.35900554060935974]
# L:  [0.47452211380004883, 0.588497519493103]
# R:  [0.31985223293304443, 0.5391550660133362]
#  [0.2751377373933792, 0.3656582236289978]
# L:  [0.47494229674339294, 0.5608769059181213]
# R:  [0.36848247051239014, 0.5094041228294373]
#  [0.4215022921562195, 0.5489508211612701]
# L:  [0.46526074409484863, 0.5788213014602661]
# R:  [0.3814290165901184, 0.5083678364753723]
#  [0.4281856566667557, 0.5346223711967468]
# L:  [0.5758001804351807, 0.4897500276565552]
# R:  [0.4587031304836273, 0.5401732325553894]
#  [0.461981937289238, 0.5594972670078278]
# L:  [0.47759461402893066, 0.6234721541404724]
# R:  [0.360809862613678, 0.5690926909446716]
#  [0.4683050215244293, 0.5294213593006134]
# L:  [0.462988018989563, 0.5885043740272522]
# R:  [0.40504878759384155, 0.5308322310447693]
#  [0.4413217008113861, 0.5771521925926208]
# L:  [0.4752024710178375, 0.3915536105632782]
# R:  [0.4047871232032776, 0.2788791358470917]
#  [0.4338875710964203, 0.43369175493717194]
# L:  [0.45448580384254456, 0.5904750227928162]
# R:  [0.35797709226608276, 0.5195662379264832]
#  [0.41658978164196014, 0.4555599242448807]
# L:  [0.44284993410110474, 0.6136282086372375]
# R:  [0.35429438948631287, 0.561707079410553]
#  [0.4043900966644287, 0.5760910511016846]
# L:  [0.43957769870758057, 0.6082661747932434]
# R:  [0.3556596636772156, 0.5427712798118591]
#  [0.39925479888916016, 0.5781997442245483]
# L:  [0.6210505366325378, 0.5664542317390442]
# R:  [0.5320344567298889, 0.6143834590911865]
#  [0.48580607771873474, 0.611324816942215]
# L:  [0.39230072498321533, 0.572150707244873]
# R:  [0.33187851309776306, 0.5155618786811829]
#  [0.47646452486515045, 0.5410080552101135]
# L:  [0.5970518589019775, 0.45361775159835815]
# R:  [0.49518343806266785, 0.5155349373817444]
#  [0.4437420815229416, 0.5438428223133087]
# L:  [0.5885756611824036, 0.5181650519371033]
# R:  [0.5104047656059265, 0.6010400056838989]
#  [0.553728312253952, 0.5273288786411285]
# L:  [0.4542419910430908, 0.6022356152534485]
# R:  [0.34245505928993225, 0.5430540442466736]
#  [0.4655153602361679, 0.5306095480918884]
# L:  [0.6849343180656433, 0.5008609890937805]
# R:  [0.6402556896209717, 0.5427506566047668]
#  [0.5472488403320312, 0.5724931359291077]
# L:  [0.5669242143630981, 0.5630762577056885]
# R:  [0.47074437141418457, 0.6234249472618103]
#  [0.5778393447399139, 0.5621429681777954]
# L:  [0.6293646097183228, 0.49742114543914795]
# R:  [0.5848774313926697, 0.49219298362731934]
#  [0.5759008228778839, 0.5276346206665039]
# L:  [0.5659061670303345, 0.5001216530799866]
# R:  [0.5832463502883911, 0.5109446048736572]
#  [0.6063054800033569, 0.5041828751564026]
# L:  [0.6579840779304504, 0.5025646090507507]
# R:  [0.5747374296188354, 0.5673468708992004]
#  [0.570321798324585, 0.5337342619895935]
# L:  [0.6333010196685791, 0.41981571912765503]
# R:  [0.5271202921867371, 0.49757978320121765]
#  [0.5925521850585938, 0.5000721961259842]
# L:  [0.5355268716812134, 0.6731173396110535]
# R:  [0.41316479444503784, 0.6966867446899414]
#  [0.5232329070568085, 0.5582512319087982]
# L:  [0.6619005799293518, 0.5410392880439758]
# R:  [0.5402210354804993, 0.5919471979141235]
#  [0.5378739535808563, 0.6325322687625885]
# L:  [0.6918708682060242, 0.39105528593063354]
# R:  [0.6098724007606506, 0.47058579325675964]
#  [0.6358864903450012, 0.5058125406503677]
# L:  [0.4930301308631897, 0.5536669492721558]
# R:  [0.4053374230861664, 0.49749892950057983]
#  [0.5486041456460953, 0.4442771077156067]
# L:  [0.7407281398773193, 0.16432416439056396]
# R:  [0.6594993472099304, 0.2727031111717224]
#  [0.5762647390365601, 0.4131850302219391]
# L:  [0.6234118342399597, 0.5769859552383423]
# R:  [0.5101786851882935, 0.629968523979187]
#  [0.6254534125328064, 0.3971463441848755]
# L:  [0.7036905288696289, 0.48079055547714233]
# R:  [0.5958471894264221, 0.5517978668212891]
#  [0.6096295118331909, 0.5643919110298157]
# L:  [0.4379270672798157, 0.587243914604187]
# R:  [0.32744359970092773, 0.5374845266342163]
#  [0.5155670642852783, 0.5091375410556793]
# L:  [0.6165214776992798, 0.5863649249076843]
# R:  [0.6241499185562134, 0.5548157691955566]
#  [0.5310384929180145, 0.5710298418998718]
# L:  [0.45503902435302734, 0.6594289541244507]
# R:  [0.5155223608016968, 0.6459025144577026]
#  [0.5660219192504883, 0.6161337196826935]
# L:  [0.6231489181518555, 0.5492141246795654]
# R:  [0.5319616198539734, 0.6073307394981384]
#  [0.49350032210350037, 0.6333798468112946]
# L:  [0.6981377601623535, 0.5016389489173889]
# R:  [0.5864792466163635, 0.5729939341545105]
#  [0.6048140823841095, 0.561104029417038]
# L:  [0.449550062417984, 0.5897643566131592]
# R:  [0.3770597577095032, 0.5210738778114319]
#  [0.5375987589359283, 0.5113564133644104]
# L:  [0.39762529730796814, 0.5038796663284302]
# R:  [0.41233742237091064, 0.5371941924095154]
#  [0.4309437423944473, 0.5634792745113373]
# L:  [0.6556058526039124, 0.5012184381484985]
# R:  [0.578996479511261, 0.5818538665771484]
#  [0.48831088840961456, 0.5428667664527893]
# L:  [0.6618514657020569, 0.5652803182601929]
# R:  [0.5568488836288452, 0.6134257316589355]
#  [0.6062273681163788, 0.557322084903717]
# L:  [0.630186140537262, 0.5180330872535706]
# R:  [0.5295915007591248, 0.5731039047241211]
#  [0.5957214832305908, 0.569192111492157]
# L:  [0.6414365768432617, 0.5485569834709167]
# R:  [0.5577856302261353, 0.612481415271759]
#  [0.5939858853816986, 0.5652572512626648]
# L:  [0.47473421692848206, 0.5467159748077393]
# R:  [0.3765774965286255, 0.4817974865436554]
#  [0.5090070366859436, 0.5151772350072861]
# L:  [0.6290352940559387, 0.5959444642066956]
# R:  [0.5284234881401062, 0.6343013644218445]
#  [0.5015788525342941, 0.5905086696147919]
# L:  [0.6938838958740234, 0.5476429462432861]
# R:  [0.5496150255203247, 0.5923969745635986]
#  [0.5893251597881317, 0.5941707193851471]
# L:  [0.43040451407432556, 0.5429500937461853]
# R:  [0.3377265930175781, 0.5042972564697266]
#  [0.5158052444458008, 0.5259701013565063]
# L:  [0.46892252564430237, 0.6345126032829285]
# R:  [0.349456250667572, 0.5837273001670837]
#  [0.3899303823709488, 0.5633386969566345]
# L:  [0.6519922018051147, 0.4776236116886139]
# R:  [0.5697370171546936, 0.5561266541481018]
#  [0.519329771399498, 0.5953196287155151]
# L:  [0.5950297713279724, 0.5397146344184875]
# R:  [0.49117231369018555, 0.5961372256278992]
#  [0.5715822577476501, 0.5368804186582565]
# L:  [0.6194174289703369, 0.4238208532333374]
# R:  [0.5438407063484192, 0.49449875950813293]
#  [0.5694352388381958, 0.5171066969633102]
# L:  [0.4259408712387085, 0.6069656610488892]
# R:  [0.32825279235839844, 0.553509533405304]
#  [0.4738351106643677, 0.4886651933193207]
# L:  [0.6072375178337097, 0.5672033429145813]
# R:  [0.519927978515625, 0.6275177001953125]
#  [0.47293442487716675, 0.6172416806221008]
# L:  [0.74112468957901, 0.5563937425613403]
# R:  [0.5874407291412354, 0.6033483743667603]
#  [0.5973391234874725, 0.5852758586406708]
# L:  [0.6203922033309937, 0.5420008897781372]
# R:  [0.5252726078033447, 0.6190320253372192]
#  [0.6331986486911774, 0.5877128839492798]
# L:  [0.7152935266494751, 0.4642937183380127]
# R:  [0.6114012598991394, 0.5269991755485535]
#  [0.6158967316150665, 0.5345000326633453]
# L:  [0.2705700397491455, 0.47589313983917236]
# R:  [0.19124539196491241, 0.4203031361103058]
#  [0.45326945930719376, 0.44229842722415924]
# L:  [0.645622968673706, 0.5092239379882812]
# R:  [0.5686780214309692, 0.5695312023162842]
#  [0.4196240305900574, 0.5227121710777283]
# L:  [0.6025696992874146, 0.6919617652893066]
# R:  [0.4892556369304657, 0.6474195718765259]
#  [0.5674393028020859, 0.5783217549324036]
# L:  [0.6287986040115356, 0.5320878028869629]
# R:  [0.5438574552536011, 0.5950464010238647]
#  [0.5732135772705078, 0.6435040831565857]
# L:  [0.45171037316322327, 0.6283281445503235]
# R:  [0.4129217267036438, 0.5973169207572937]
#  [0.5208601653575897, 0.5647023618221283]
# L:  [0.5396595597267151, 0.644624650478363]
# R:  [0.6004865169525146, 0.5847219228744507]
#  [0.526098445057869, 0.6065250337123871]
# L:  [0.6810846924781799, 0.55605548620224]
# R:  [0.5602874159812927, 0.6008486151695251]
#  [0.5499734878540039, 0.6227366328239441]
# L:  [0.3621288537979126, 0.46852603554725647]
# R:  [0.29498881101608276, 0.38945019245147705]
#  [0.48803675174713135, 0.4727528393268585]
# L:  [0.6334533095359802, 0.38387882709503174]
# R:  [0.5489543080329895, 0.450186163187027]
#  [0.45554158091545105, 0.4593560993671417]
# L:  [0.6241502165794373, 0.5240427255630493]
# R:  [0.5318854451179504, 0.5922164916992188]
#  [0.5826693773269653, 0.48804765939712524]
# L:  [0.4728237986564636, 0.6322486400604248]
# R:  [0.3454260528087616, 0.5716062188148499]
#  [0.4847881346940994, 0.5478244721889496]

# %%
import csv

# Sample data

data = zip(legs,hips,shoulder,arms,hip_cone)
# Specify the file name
csv_file = "utthita_trikonasana.csv"

# Write data to CSV file
with open(csv_file, mode='a', newline="") as file:
    writer = csv.writer(file)
    writer.writerow(['LEGS','HIPS','SHOULDER','ARMS','HIP_CONE'])
    
    for row in data:
        writer.writerow(row)

# %%
import pandas as pd
df = pd.read_csv('utthita_trikonasana.csv')

# %%
df.head()
# Out:
#          LEGS        HIPS    SHOULDER        ARMS   HIP_CONE
# 0  177.833358   32.948177   93.408763  145.906137  99.567117
# 1  177.949397  145.662565  101.032211  175.942146  88.633503
# 2  159.729437   52.848552   90.031765  153.077225  81.660612
# 3  170.504376  137.712744   92.503767  151.618642  82.018509
# 4  177.238981  130.893623   69.892118  169.770694  81.559911

# %%
s=0
ARM=0
SHOULDER=0
HIP=0
LEG=0
HIP_CONE=0
for i in arms:
    s+=i
ARM=s/len(arms)
s=0
for i in shoulder:
    s+=i
SHOULDER=s/len(shoulder)
s=0
for i in hips:
    s+=i
HIP=s/len(hips)
s=0
for i in legs:
    s+=i
LEG=s/len(legs)
s=0
for i in hip_cone:
    s+=i
HIP_CONE=s/len(hip_cone)

# %%
print("ARMS:",ARM,"\nSHOULDER: ",SHOULDER,"\nHIPS: ",HIP,"\nLEGS: ",LEG,"\nHIP_CONE: ",HIP_CONE)
# Out:
# ARMS: 167.34257238671964
# SHOULDER:  97.98112632636058
# HIPS:  95.57334816726625
# LEGS:  169.2673807013754
# HIP_CONE:  88.09754521772363

# %%
hip_cone
# Out:
# [99.56711735846156,
#  88.63350310128894,
#  81.66061226327463,
#  82.01850901121892,
#  81.55991062112996,
#  63.85760316827441,
#  67.67854000771715,
#  95.43498507240399,
#  74.05260762857729,
#  108.13289045327653,
#  82.99436058303255,
#  93.74133933133204,
#  68.94123694395915,
#  71.76118137394431,
#  95.03221333410171,
#  91.13332033773905,
#  101.78165349987978,
#  82.97680842148569,
#  113.90883546530776,
#  87.86432831786429,
#  83.68524207867702,
#  91.50588134457497,
#  87.18211484190304,
#  79.62952997985106,
#  83.62171293762044,
#  87.83277960776753,
#  83.93457788510582,
#  97.17805600873406,
#  103.1577209925242,
#  163.06213104180762,
#  83.95868324796014,
#  60.51437412156685,
#  70.6733102991368,
#  94.79730486614295,
#  80.933793915426,
#  24.107382537905245,
#  95.87590017845478,
#  99.73581731954313,
#  95.90359329911249,
#  84.86442192085798,
#  92.89306460835547,
#  90.73032388008497,
#  104.62485304787016,
#  100.57711386767625,
#  97.5727761972872,
#  83.25590824810148,
#  99.45988647807926,
#  99.3380173723227,
#  88.91066539035702,
#  89.63132466656373,
#  93.64434610858304,
#  104.03116662119854,
#  82.15714416027758,
#  85.24795312028814,
#  103.39777256782614,
#  88.38909661046523,
#  102.21016278855548,
#  83.93183212059581,
#  0.26192181460132113,
#  81.23212324854535,
#  96.37148829560465,
#  100.75655520677039,
#  94.87114877444627,
#  109.17584700627518,
#  103.1125330045843,
#  73.29406046763697,
#  80.68025499066668,
#  83.84253309716006,
#  80.24286154320876]

# %% [markdown]
# # bitlasana

# %% [markdown]
# # cat_pose

# %%
import os
from PIL import Image

# Folder path containing images
folder_path = "E:/capstone/Dataset/possible_Ones/bitilasana/cat"

# # List to store image data
# images = []

# # Iterate over files in the folder
# for filename in os.listdir(folder_path):
#     # Check if the file is an image (you might want to add more image extensions)
#     if filename.endswith(".jpg") or filename.endswith(".png"):
#         # Construct the full file path
#         file_path = os.path.join(folder_path, filename)
#         # Open the image using Pillow
#         img = Image.open(file_path)
#         # Append the image to the list
#         images.append(img)
#         # You can perform any processing or testing here with the image

# # Now you have all the images loaded in the 'images' list
# # You can loop through this list to perform testing or processing




# List to store image paths
image_paths = []

# Iterate over files in the folder
for filename in os.listdir(folder_path):
    # Check if the file is an image (you might want to add more image extensions)
    if filename.endswith(".jpg") or filename.endswith(".png"):
        # Construct the full file path
        file_path = os.path.join(folder_path, filename)
        # Append the file path to the list
        file_path.replace("\\",'/')
        image_paths.append(file_path)

# %%
image_paths
# Out:
# ['E:/capstone/Dataset/possible_Ones/bitilasana/cat\\0-0.png',
#  'E:/capstone/Dataset/possible_Ones/bitilasana/cat\\0-1.png',
#  'E:/capstone/Dataset/possible_Ones/bitilasana/cat\\1-0.png',
#  'E:/capstone/Dataset/possible_Ones/bitilasana/cat\\10-0.png',
#  'E:/capstone/Dataset/possible_Ones/bitilasana/cat\\104-0.png',
#  'E:/capstone/Dataset/possible_Ones/bitilasana/cat\\11-0.png',
#  'E:/capstone/Dataset/possible_Ones/bitilasana/cat\\13-0.png',
#  'E:/capstone/Dataset/possible_Ones/bitilasana/cat\\14-0.png',
#  'E:/capstone/Dataset/possible_Ones/bitilasana/cat\\15-0.png',
#  'E:/capstone/Dataset/possible_Ones/bitilasana/cat\\16-0.png',
#  'E:/capstone/Dataset/possible_Ones/bitilasana/cat\\16-1.png',
#  'E:/capstone/Dataset/possible_Ones/bitilasana/cat\\17-0 (2).png',
#  'E:/capstone/Dataset/possible_Ones/bitilasana/cat\\17-0.png',
#  'E:/capstone/Dataset/possible_Ones/bitilasana/cat\\19-0 (2).png',
#  'E:/capstone/Dataset/possible_Ones/bitilasana/cat\\19-0.png',
#  'E:/capstone/Dataset/possible_Ones/bitilasana/cat\\2-0 (2).png',
#  'E:/capstone/Dataset/possible_Ones/bitilasana/cat\\2-1.png',
#  'E:/capstone/Dataset/possible_Ones/bitilasana/cat\\20-0.png',
#  'E:/capstone/Dataset/possible_Ones/bitilasana/cat\\21-0.png',
#  'E:/capstone/Dataset/possible_Ones/bitilasana/cat\\23-0.png',
#  'E:/capstone/Dataset/possible_Ones/bitilasana/cat\\24-0 (2).png',
#  'E:/capstone/Dataset/possible_Ones/bitilasana/cat\\24-0.png',
#  'E:/capstone/Dataset/possible_Ones/bitilasana/cat\\25-0 (2).png',
#  'E:/capstone/Dataset/possible_Ones/bitilasana/cat\\25-0.png',
#  'E:/capstone/Dataset/possible_Ones/bitilasana/cat\\26-0 (2).png',
#  'E:/capstone/Dataset/possible_Ones/bitilasana/cat\\26-0.png',
#  'E:/capstone/Dataset/possible_Ones/bitilasana/cat\\26-2.png',
#  'E:/capstone/Dataset/possible_Ones/bitilasana/cat\\29-0 (2).png',
#  'E:/capstone/Dataset/possible_Ones/bitilasana/cat\\29-0.png',
#  'E:/capstone/Dataset/possible_Ones/bitilasana/cat\\3-0.png',
#  'E:/capstone/Dataset/possible_Ones/bitilasana/cat\\30-0.png',
#  'E:/capstone/Dataset/possible_Ones/bitilasana/cat\\31-0.png',
#  'E:/capstone/Dataset/possible_Ones/bitilasana/cat\\31-1.png',
#  'E:/capstone/Dataset/possible_Ones/bitilasana/cat\\32-0 (2).png',
#  'E:/capstone/Dataset/possible_Ones/bitilasana/cat\\32-0.png',
#  'E:/capstone/Dataset/possible_Ones/bitilasana/cat\\32-1.png',
#  'E:/capstone/Dataset/possible_Ones/bitilasana/cat\\33-0 (2).png',
#  'E:/capstone/Dataset/possible_Ones/bitilasana/cat\\33-0.png',
#  'E:/capstone/Dataset/possible_Ones/bitilasana/cat\\34-0 (2).png',
#  'E:/capstone/Dataset/possible_Ones/bitilasana/cat\\34-0.png',
#  'E:/capstone/Dataset/possible_Ones/bitilasana/cat\\35-0.png',
#  'E:/capstone/Dataset/possible_Ones/bitilasana/cat\\36-0 (2).png',
#  'E:/capstone/Dataset/possible_Ones/bitilasana/cat\\36-0.png',
#  'E:/capstone/Dataset/possible_Ones/bitilasana/cat\\37-0 (2).png',
#  'E:/capstone/Dataset/possible_Ones/bitilasana/cat\\37-0.png',
#  'E:/capstone/Dataset/possible_Ones/bitilasana/cat\\38-0 (2).png',
#  'E:/capstone/Dataset/possible_Ones/bitilasana/cat\\38-0.png',
#  'E:/capstone/Dataset/possible_Ones/bitilasana/cat\\39-0.png',
#  'E:/capstone/Dataset/possible_Ones/bitilasana/cat\\39-1.png',
#  'E:/capstone/Dataset/possible_Ones/bitilasana/cat\\4-0.png',
#  'E:/capstone/Dataset/possible_Ones/bitilasana/cat\\40-0 (2).png',
#  'E:/capstone/Dataset/possible_Ones/bitilasana/cat\\40-0.png',
#  'E:/capstone/Dataset/possible_Ones/bitilasana/cat\\41-0 (2).png',
#  'E:/capstone/Dataset/possible_Ones/bitilasana/cat\\42-0 (2).png',
#  'E:/capstone/Dataset/possible_Ones/bitilasana/cat\\42-0.png',
#  'E:/capstone/Dataset/possible_Ones/bitilasana/cat\\43-0.png',
#  'E:/capstone/Dataset/possible_Ones/bitilasana/cat\\46-0 (2).png',
#  'E:/capstone/Dataset/possible_Ones/bitilasana/cat\\46-0.png',
#  'E:/capstone/Dataset/possible_Ones/bitilasana/cat\\48-0 (2).png',
#  'E:/capstone/Dataset/possible_Ones/bitilasana/cat\\48-0.png',
#  'E:/capstone/Dataset/possible_Ones/bitilasana/cat\\49-0 (2).png',
#  'E:/capstone/Dataset/possible_Ones/bitilasana/cat\\49-0.png',
#  'E:/capstone/Dataset/possible_Ones/bitilasana/cat\\5-0 (2).png',
#  'E:/capstone/Dataset/possible_Ones/bitilasana/cat\\5-0.png',
#  'E:/capstone/Dataset/possible_Ones/bitilasana/cat\\50-0.png',
#  'E:/capstone/Dataset/possible_Ones/bitilasana/cat\\51-0.png',
#  'E:/capstone/Dataset/possible_Ones/bitilasana/cat\\52-0 (2).png',
#  'E:/capstone/Dataset/possible_Ones/bitilasana/cat\\52-0.png',
#  'E:/capstone/Dataset/possible_Ones/bitilasana/cat\\53-0.png',
#  'E:/capstone/Dataset/possible_Ones/bitilasana/cat\\55-0.png',
#  'E:/capstone/Dataset/possible_Ones/bitilasana/cat\\58-0.png',
#  'E:/capstone/Dataset/possible_Ones/bitilasana/cat\\59-0.png',
#  'E:/capstone/Dataset/possible_Ones/bitilasana/cat\\6-0 (2).png',
#  'E:/capstone/Dataset/possible_Ones/bitilasana/cat\\6-0.png',
#  'E:/capstone/Dataset/possible_Ones/bitilasana/cat\\60-0.png',
#  'E:/capstone/Dataset/possible_Ones/bitilasana/cat\\61-0.png',
#  'E:/capstone/Dataset/possible_Ones/bitilasana/cat\\63-0.png',
#  'E:/capstone/Dataset/possible_Ones/bitilasana/cat\\65-0.png',
#  'E:/capstone/Dataset/possible_Ones/bitilasana/cat\\66-0.png',
#  'E:/capstone/Dataset/possible_Ones/bitilasana/cat\\67-0.png',
#  'E:/capstone/Dataset/possible_Ones/bitilasana/cat\\69-1.png',
#  'E:/capstone/Dataset/possible_Ones/bitilasana/cat\\7-0 (2).png',
#  'E:/capstone/Dataset/possible_Ones/bitilasana/cat\\7-0.png',
#  'E:/capstone/Dataset/possible_Ones/bitilasana/cat\\70-0.png',
#  'E:/capstone/Dataset/possible_Ones/bitilasana/cat\\71-1.png',
#  'E:/capstone/Dataset/possible_Ones/bitilasana/cat\\72-0.png',
#  'E:/capstone/Dataset/possible_Ones/bitilasana/cat\\74-0.png',
#  'E:/capstone/Dataset/possible_Ones/bitilasana/cat\\77-0.png',
#  'E:/capstone/Dataset/possible_Ones/bitilasana/cat\\78-0.png',
#  'E:/capstone/Dataset/possible_Ones/bitilasana/cat\\8-0.png',
#  'E:/capstone/Dataset/possible_Ones/bitilasana/cat\\82-2.png',
#  'E:/capstone/Dataset/possible_Ones/bitilasana/cat\\84-0.png',
#  'E:/capstone/Dataset/possible_Ones/bitilasana/cat\\88-1.png',
#  'E:/capstone/Dataset/possible_Ones/bitilasana/cat\\89-0.png',
#  'E:/capstone/Dataset/possible_Ones/bitilasana/cat\\9-0.png',
#  'E:/capstone/Dataset/possible_Ones/bitilasana/cat\\92-0.png',
#  'E:/capstone/Dataset/possible_Ones/bitilasana/cat\\93-0.png',
#  'E:/capstone/Dataset/possible_Ones/bitilasana/cat\\94-1.png',
#  'E:/capstone/Dataset/possible_Ones/bitilasana/cat\\95-0.png',
#  'E:/capstone/Dataset/possible_Ones/bitilasana/cat\\96-0.png']

# %%
import math
def angle_of_singleline(point1, point2):
    """ Calculate angle of a single line """
    x_diff = point2[0] - point1[0]
    y_diff = point2[1] - point1[1]
    return math.degrees(math.atan2(y_diff, x_diff))

# %%
angle_of_singleline([1,1],[4,5])
# Out:
# 53.13010235415598

# %%
import csv

def angle_of_singleline(a, b):
    """ Calculate angle of a single line """
#     x_diff = point2[0] - point1[0]
#     y_diff = point2[1] - point1[1]
#     return math.degrees(math.atan2(y_diff, x_diff))

    radians = np.arctan2(b[1]-a[1],b[0]-a[0])
    angle = np.abs(radians*180/np.pi)
    if angle > 180.0:
        angle = 360-angle
    return angle
    



def calculate_angles(a,b,c):
    a = np.array(a) # First
    b = np.array(b) # Second 
    c = np.array(c) # Third
    
    radians = np.arctan2(c[1]-b[1], c[0]-b[0]) - np.arctan2(a[1]-b[1], a[0]-b[0])
    angle = np.abs(radians*180.0/np.pi)
    
    if angle > 180.0:
        angle = 360-angle
    return angle


# left_arm_data = []
# right_arm_data = []
# left_leg_data = []
# right_leg_data = []

legs=[]
hips=[]
shoulder=[]
arms=[]
hip_angle_left=[]
hip_angle_right=[]
hip_to_nose=[]

for image_path in image_paths:
#     image_path = "E:/capstone/Capstone_Project/DATASET/TEST/tree\\00000031.jpg"
    output = cv2.imread(image_path)

    image_pose = output 
    pose = pose_image
    draw = True
    display = True
    # def detectPose(image_pose, pose, draw=False, display=False):

    original_image = image_pose.copy()

    image_in_RGB = cv2.cvtColor(image_pose, cv2.COLOR_BGR2RGB)

    resultant = pose.process(image_in_RGB)
    
    if resultant.pose_landmarks and draw:    


        landmarks = resultant.pose_landmarks.landmark



    ####################################################################
        right_shoulder = [landmarks[mp_pose.PoseLandmark.RIGHT_SHOULDER.value].x,landmarks[mp_pose.PoseLandmark.RIGHT_SHOULDER.value].y] 
        left_shoulder = [landmarks[mp_pose.PoseLandmark.LEFT_SHOULDER.value].x,landmarks[mp_pose.PoseLandmark.LEFT_SHOULDER.value].y]

        right_elbow = [landmarks[mp_pose.PoseLandmark.RIGHT_ELBOW.value].x,landmarks[mp_pose.PoseLandmark.RIGHT_ELBOW.value].y]
        left_elbow = [landmarks[mp_pose.PoseLandmark.LEFT_ELBOW.value].x,landmarks[mp_pose.PoseLandmark.LEFT_ELBOW.value].y]

        right_wrist = [landmarks[mp_pose.PoseLandmark.RIGHT_WRIST.value].x,landmarks[mp_pose.PoseLandmark.RIGHT_WRIST.value].y]
        left_wrist = [landmarks[mp_pose.PoseLandmark.LEFT_WRIST.value].x,landmarks[mp_pose.PoseLandmark.LEFT_WRIST.value].y]

        right_hip = [landmarks[mp_pose.PoseLandmark.RIGHT_HIP.value].x,landmarks[mp_pose.PoseLandmark.RIGHT_HIP.value].y]
        left_hip = [landmarks[mp_pose.PoseLandmark.LEFT_HIP.value].x,landmarks[mp_pose.PoseLandmark.LEFT_HIP.value].y]


        right_knee = [landmarks[mp_pose.PoseLandmark.RIGHT_KNEE.value].x,landmarks[mp_pose.PoseLandmark.RIGHT_KNEE.value].y]
        left_knee = [landmarks[mp_pose.PoseLandmark.LEFT_KNEE.value].x,landmarks[mp_pose.PoseLandmark.LEFT_KNEE.value].y]

        right_ankle = [landmarks[mp_pose.PoseLandmark.RIGHT_ANKLE.value].x,landmarks[mp_pose.PoseLandmark.RIGHT_ANKLE.value].y]
        left_ankle = [landmarks[mp_pose.PoseLandmark.LEFT_ANKLE.value].x,landmarks[mp_pose.PoseLandmark.LEFT_ANKLE.value].y]

        
        nose = [landmarks[mp_pose.PoseLandmark.NOSE.value].x,landmarks[mp_pose.PoseLandmark.NOSE.value].y]




















    #########################################################
        # CALCULATE THE ANGLE
    #     angle_la = calculate_angles(left_wrist,left_elbow,left_shoulder)  
    #     angle_ra = calculate_angles(right_wrist,right_elbow,right_shoulder)  
    #     angle_ll = calculate_angles(left_hip,left_knee,left_ankle)  
    #     angle_rl = calculate_angles(right_hip,right_knee,right_ankle)  


        leg_1 = calculate_angles(left_ankle,left_knee,left_hip)
        leg_2 = calculate_angles(right_ankle,right_knee,right_hip)

#         hip_1 = calculate_angles(left_knee,left_hip,left_shoulder)
#         hip_2 = calculate_angles(right_knee,right_hip,right_shoulder)
        
        hip_1_1 = calculate_angles(left_knee,left_hip,nose)
        hip_2_2 = calculate_angles(right_knee,right_hip,nose)
        print("\nHIP_1: ",hip_1_1,"\tHIP_2: ",hip_2_2)

#         shoulder_1 = calculate_angles(left_hip,left_shoulder,left_elbow)
#         shoulder_2 = calculate_angles(right_hip,right_shoulder,right_elbow)
        
        arms_1 = calculate_angles(left_shoulder,left_elbow,left_wrist)
        arms_2 = calculate_angles(right_shoulder,right_elbow,right_wrist)
    
    
#         sinle_line_left = angle_of_singleline(left_hip,left_shoulder)
        
#         sinle_line_right = angle_of_singleline(right_hip,right_shoulder)
        
        
        
        sinle_line_left = angle_of_singleline(left_hip,nose)
        
        sinle_line_right = angle_of_singleline(right_hip,nose)



    #     print(angle)


    #     arms_data.append(angle)

    #     left_arm_data.append(angle_la)
    #     right_arm_data.append(angle_ra)
    #     left_leg_data.append(angle_ll)
    #     right_leg_data.append(angle_rl)

        legs.append(leg_1)
        legs.append(leg_2)
#         hips.append(hip_1)
#         hips.append(hip_2)
#         shoulder.append(shoulder_1)
#         shoulder.append(shoulder_2)
        arms.append(arms_1)
        arms.append(arms_2)
#         hip_angle_left.append(sinle_line_left )
#         hip_angle_right.append(sinle_line_right)
        hip_to_nose.append(hip_1_1)
        hip_to_nose.append(hip_2_2)



    # Sample data
    # data = [angle]

    # # Specify the file name
    # csv_file = "data.csv"

    # # Write data to CSV file
    # with open(csv_file, mode='a', newline='') as file:
    #     writer = csv.writer(file)
    #     writer.writerow(data)
# Out:
# HIP_1:  134.62726633194652 	HIP_2:  138.94689901887673
#
# HIP_1:  121.39645933884637 	HIP_2:  120.50752658300695
#
# HIP_1:  154.48554003472466 	HIP_2:  159.58540924568624
#
# HIP_1:  126.71569917383242 	HIP_2:  124.0379806338145
#
# HIP_1:  140.41111189008907 	HIP_2:  143.11447974839282
#
# HIP_1:  110.91669419455627 	HIP_2:  111.33743908043574
#
# HIP_1:  136.46570312792016 	HIP_2:  137.98092160246995
#
# HIP_1:  121.72782044798588 	HIP_2:  122.3387249496226
#
# HIP_1:  137.35475405377485 	HIP_2:  144.29685385528066
#
# HIP_1:  123.90664752706219 	HIP_2:  123.3691282119187
#
# HIP_1:  122.86996791718755 	HIP_2:  121.97997584991754
#
# HIP_1:  132.8433332410993 	HIP_2:  133.6119606969589
#
# HIP_1:  127.27157852642543 	HIP_2:  123.25470055559677
#
# HIP_1:  140.51000707865495 	HIP_2:  140.5541573219101
#
# HIP_1:  141.07358189578798 	HIP_2:  142.9769106208242
#
# HIP_1:  123.21995653827747 	HIP_2:  123.216185630448
#
# HIP_1:  126.13554869137457 	HIP_2:  122.6269059736057
#
# HIP_1:  160.12441887106186 	HIP_2:  150.29564254518675
#
# HIP_1:  138.92855958505638 	HIP_2:  142.13603511571864
#
# HIP_1:  106.42044009226663 	HIP_2:  106.14665910222456
#
# HIP_1:  131.29246298919102 	HIP_2:  127.34696076291107
#
# HIP_1:  140.0206910257687 	HIP_2:  140.01060657518912
#
# HIP_1:  96.90572495704089 	HIP_2:  100.21838540113686
#
# HIP_1:  107.72618229646686 	HIP_2:  105.04253852904526
#
# HIP_1:  113.00384337899729 	HIP_2:  114.24572283425404
#
# HIP_1:  98.00590621905609 	HIP_2:  100.63552451371592
#
# HIP_1:  113.4810223303121 	HIP_2:  114.1279727645913
#
# HIP_1:  122.04877186675135 	HIP_2:  121.82216232059696
#
# HIP_1:  127.57376164311987 	HIP_2:  129.59452601440765
#
# HIP_1:  139.4240626289805 	HIP_2:  132.9502985563651
#
# HIP_1:  131.41991955423342 	HIP_2:  134.49086583156912
#
# HIP_1:  149.724696980537 	HIP_2:  62.754762291037835
#
# HIP_1:  99.86491079993776 	HIP_2:  92.07690999989445
#
# HIP_1:  152.3546291941484 	HIP_2:  141.18711312113908
#
# HIP_1:  122.65612100645859 	HIP_2:  121.99785550110005
#
# HIP_1:  136.8659574819436 	HIP_2:  136.00724796128515
#
# HIP_1:  155.2277289958893 	HIP_2:  156.15661959442104
#
# HIP_1:  179.43266306629323 	HIP_2:  170.35664879071314
#
# HIP_1:  132.9744728123996 	HIP_2:  134.95900973544232
#
# HIP_1:  96.90572495704089 	HIP_2:  100.21838540113686
#
# HIP_1:  128.94701721716018 	HIP_2:  125.87805984044937
#
# HIP_1:  61.805865013318304 	HIP_2:  132.4266200678176
#
# HIP_1:  140.0206910257687 	HIP_2:  140.01060657518912
#
# HIP_1:  96.29591536685697 	HIP_2:  97.70090267373413
#
# HIP_1:  152.9292168625516 	HIP_2:  96.73606673851651
#
# HIP_1:  140.87589866462002 	HIP_2:  141.28185506602532
#
# HIP_1:  138.44667183976114 	HIP_2:  141.31397093210686
#
# HIP_1:  120.48092050547106 	HIP_2:  119.25541764760554
#
# HIP_1:  127.57376164311987 	HIP_2:  129.59452601440765
#
# HIP_1:  157.85188436042344 	HIP_2:  156.90245489693834
#
# HIP_1:  111.99229439541725 	HIP_2:  115.17493701019754
#
# HIP_1:  129.7358942030048 	HIP_2:  128.1298917443367
#
# HIP_1:  111.85195988170406 	HIP_2:  109.7010536527776
#
# HIP_1:  122.00761623290045 	HIP_2:  122.12985701396991
#
# HIP_1:  127.23637559589972 	HIP_2:  125.88941876508608
#
# HIP_1:  89.89548845662762 	HIP_2:  88.38658278571603
#
# HIP_1:  144.20014120986048 	HIP_2:  139.4809668056821
#
# HIP_1:  133.19902438144106 	HIP_2:  139.88651997332286
#
# HIP_1:  111.62975706142262 	HIP_2:  112.13077433236313
#
# HIP_1:  115.41736251159182 	HIP_2:  106.9181225246253
#
# HIP_1:  121.16080327803958 	HIP_2:  105.80115170085645
#
# HIP_1:  83.55433911080277 	HIP_2:  89.36703238018778
#
# HIP_1:  106.10165239437265 	HIP_2:  103.14556909102262
#
# HIP_1:  121.7919338580344 	HIP_2:  122.5471055212081
#
# HIP_1:  156.84197121230272 	HIP_2:  149.91633824754024
#
# HIP_1:  162.9850906748352 	HIP_2:  165.39355721861227
#
# HIP_1:  127.77093470366853 	HIP_2:  129.61890113313166
#
# HIP_1:  116.93431052882902 	HIP_2:  120.32439110261836
#
# HIP_1:  132.83429959597592 	HIP_2:  131.8372420585145
#
# HIP_1:  134.61987841426122 	HIP_2:  137.41882494234457
#
# HIP_1:  135.90085776987095 	HIP_2:  138.87055890063627
#
# HIP_1:  134.9120921756642 	HIP_2:  133.58841589772726
#
# HIP_1:  114.81879264540655 	HIP_2:  114.51796454464159
#
# HIP_1:  127.0817870434573 	HIP_2:  130.2290942313984
#
# HIP_1:  121.16648772138305 	HIP_2:  120.95286276740272
#
# HIP_1:  89.50632497625017 	HIP_2:  92.9153501490279
#
# HIP_1:  133.98645111263062 	HIP_2:  137.01809419639363
#
# HIP_1:  106.6770558451417 	HIP_2:  109.6200100265232
#
# HIP_1:  139.72460959675246 	HIP_2:  137.26141306146312
#
# HIP_1:  139.3513976997914 	HIP_2:  136.19723428143908
#
# HIP_1:  130.98854037894571 	HIP_2:  128.22335930430776
#
# HIP_1:  156.88227383607293 	HIP_2:  122.7942633955463
#
# HIP_1:  118.76227428916815 	HIP_2:  118.65194743203182
#
# HIP_1:  122.80590553103556 	HIP_2:  122.46120958117811
#
# HIP_1:  111.02287728302711 	HIP_2:  112.24087719417038
#
# HIP_1:  123.1737031415577 	HIP_2:  123.62106480473315
#
# HIP_1:  93.52583025437298 	HIP_2:  97.76332118388204
#
# HIP_1:  132.08386619304284 	HIP_2:  134.36021360782024
#
# HIP_1:  123.81526584383722 	HIP_2:  122.8164815460759
#
# HIP_1:  107.9222783860162 	HIP_2:  114.29963959131702
#
# HIP_1:  118.0700470214181 	HIP_2:  118.5892866259361
#
# HIP_1:  121.20125467210963 	HIP_2:  120.73510660041399
#
# HIP_1:  118.30512585329433 	HIP_2:  116.85887872490551
#
# HIP_1:  116.58100232893528 	HIP_2:  116.74066096382445
#
# HIP_1:  104.4997317397718 	HIP_2:  100.5041497691661
#
# HIP_1:  134.7927596926404 	HIP_2:  137.1761989626313

# %%
import csv

# Sample data

data = zip(legs,arms,hip_to_nose)
# Specify the file name
csv_file = "bitlasana.csv"

# Write data to CSV file
with open(csv_file, mode='a', newline="") as file:
    writer = csv.writer(file)
    writer.writerow(['LEGS','ARMS','HIP_TO_NOSE'])
    
    for row in data:
        writer.writerow(row)

# %%
        
import pandas as pd
df = pd.read_csv('bitlasana.csv')

# %%
df.head()
# Out:
#         LEGS        ARMS  HIP_TO_NOSE
# 0  94.649624  175.949273   134.627266
# 1  90.055918  176.178021   138.946899
# 2  81.434394  174.483446   121.396459
# 3  83.676884  175.114903   120.507527
# 4  96.566977  175.241335   154.485540

# %%
s=0
ARM=0
HIP=0
LEG=0
for i in arms:
    s+=i
ARM=s/len(arms)
s=0
for i in hip_to_nose:
    s+=i
HIP=s/len(hip_to_nose)
s=0
for i in legs:
    s+=i
LEG=s/len(legs)

# %%
print("ARMS:",ARM,"\nHIPS: ",HIP,"\nLEGS: ",LEG)
# Out:
# ARMS: 173.62562830162256
# HIPS:  125.15980674279945
# LEGS:  87.26663664449586

# %%
hip_to_nose
# Out:
# [134.62726633194652,
#  138.94689901887673,
#  121.39645933884637,
#  120.50752658300695,
#  154.48554003472466,
#  159.58540924568624,
#  126.71569917383242,
#  124.0379806338145,
#  140.41111189008907,
#  143.11447974839282,
#  110.91669419455627,
#  111.33743908043574,
#  136.46570312792016,
#  137.98092160246995,
#  121.72782044798588,
#  122.3387249496226,
#  137.35475405377485,
#  144.29685385528066,
#  123.90664752706219,
#  123.3691282119187,
#  122.86996791718755,
#  121.97997584991754,
#  132.8433332410993,
#  133.6119606969589,
#  127.27157852642543,
#  123.25470055559677,
#  140.51000707865495,
#  140.5541573219101,
#  141.07358189578798,
#  142.9769106208242,
#  123.21995653827747,
#  123.216185630448,
#  126.13554869137457,
#  122.6269059736057,
#  160.12441887106186,
#  150.29564254518675,
#  138.92855958505638,
#  142.13603511571864,
#  106.42044009226663,
#  106.14665910222456,
#  131.29246298919102,
#  127.34696076291107,
#  140.0206910257687,
#  140.01060657518912,
#  96.90572495704089,
#  100.21838540113686,
#  107.72618229646686,
#  105.04253852904526,
#  113.00384337899729,
#  114.24572283425404,
#  98.00590621905609,
#  100.63552451371592,
#  113.4810223303121,
#  114.1279727645913,
#  122.04877186675135,
#  121.82216232059696,
#  127.57376164311987,
#  129.59452601440765,
#  139.4240626289805,
#  132.9502985563651,
#  131.41991955423342,
#  134.49086583156912,
#  149.724696980537,
#  62.754762291037835,
#  99.86491079993776,
#  92.07690999989445,
#  152.3546291941484,
#  141.18711312113908,
#  122.65612100645859,
#  121.99785550110005,
#  136.8659574819436,
#  136.00724796128515,
#  155.2277289958893,
#  156.15661959442104,
#  179.43266306629323,
#  170.35664879071314,
#  132.9744728123996,
#  134.95900973544232,
#  96.90572495704089,
#  100.21838540113686,
#  128.94701721716018,
#  125.87805984044937,
#  61.805865013318304,
#  132.4266200678176,
#  140.0206910257687,
#  140.01060657518912,
#  96.29591536685697,
#  97.70090267373413,
#  152.9292168625516,
#  96.73606673851651,
#  140.87589866462002,
#  141.28185506602532,
#  138.44667183976114,
#  141.31397093210686,
#  120.48092050547106,
#  119.25541764760554,
#  127.57376164311987,
#  129.59452601440765,
#  157.85188436042344,
#  156.90245489693834,
#  111.99229439541725,
#  115.17493701019754,
#  129.7358942030048,
#  128.1298917443367,
#  111.85195988170406,
#  109.7010536527776,
#  122.00761623290045,
#  122.12985701396991,
#  127.23637559589972,
#  125.88941876508608,
#  89.89548845662762,
#  88.38658278571603,
#  144.20014120986048,
#  139.4809668056821,
#  133.19902438144106,
#  139.88651997332286,
#  111.62975706142262,
#  112.13077433236313,
#  115.41736251159182,
#  106.9181225246253,
#  121.16080327803958,
#  105.80115170085645,
#  83.55433911080277,
#  89.36703238018778,
#  106.10165239437265,
#  103.14556909102262,
#  121.7919338580344,
#  122.5471055212081,
#  156.84197121230272,
#  149.91633824754024,
#  162.9850906748352,
#  165.39355721861227,
#  127.77093470366853,
#  129.61890113313166,
#  116.93431052882902,
#  120.32439110261836,
#  132.83429959597592,
#  131.8372420585145,
#  134.61987841426122,
#  137.41882494234457,
#  135.90085776987095,
#  138.87055890063627,
#  134.9120921756642,
#  133.58841589772726,
#  114.81879264540655,
#  114.51796454464159,
#  127.0817870434573,
#  130.2290942313984,
#  121.16648772138305,
#  120.95286276740272,
#  89.50632497625017,
#  92.9153501490279,
#  133.98645111263062,
#  137.01809419639363,
#  106.6770558451417,
#  109.6200100265232,
#  139.72460959675246,
#  137.26141306146312,
#  139.3513976997914,
#  136.19723428143908,
#  130.98854037894571,
#  128.22335930430776,
#  156.88227383607293,
#  122.7942633955463,
#  118.76227428916815,
#  118.65194743203182,
#  122.80590553103556,
#  122.46120958117811,
#  111.02287728302711,
#  112.24087719417038,
#  123.1737031415577,
#  123.62106480473315,
#  93.52583025437298,
#  97.76332118388204,
#  132.08386619304284,
#  134.36021360782024,
#  123.81526584383722,
#  122.8164815460759,
#  107.9222783860162,
#  114.29963959131702,
#  118.0700470214181,
#  118.5892866259361,
#  121.20125467210963,
#  120.73510660041399,
#  118.30512585329433,
#  116.85887872490551,
#  116.58100232893528,
#  116.74066096382445,
#  104.4997317397718,
#  100.5041497691661,
#  134.7927596926404,
#  137.1761989626313]

# %%
# Out:
# [164.02078966226054,
#  15.377020548963134,
#  16.111737105120323,
#  26.77248731395613,
#  10.601270007731127,
#  7.859611293871329,
#  11.245940247218133,
#  164.1622549621576,
#  6.088502188479615,
#  163.1806853518243,
#  166.88819415178423,
#  16.836494422517724,
#  7.2206740334610835,
#  0.4646293130143815,
#  9.310877878356719,
#  163.2884884882056,
#  1.1382717183116027,
#  163.9373461744656,
#  167.40868136265286,
#  6.088502188479615,
#  157.45762791270184,
#  2.120321571351568,
#  165.66069178316314,
#  21.48449983289692,
#  172.6010355351543,
#  21.48449983289692,
#  163.2884884882056,
#  22.600532091359383,
#  14.155351577021225,
#  169.9638200913403,
#  40.20701426415029,
#  7.658383888285053,
#  22.884582855450976,
#  168.47823518239713,
#  5.3432143182605545,
#  16.187251458026164,
#  10.039095520727576,
#  22.600532091359383,
#  6.8346829505319695,
#  22.600532091359383,
#  177.05422313326164,
#  2.641199313553087,
#  155.0201256670894,
#  175.53725956047845,
#  6.769685118083784,
#  6.639786431169786,
#  12.082055534410987,
#  3.8915282741554695,
#  167.44895437021415,
#  12.778398307686922,
#  157.02694836565914,
#  23.631115729631826,
#  21.261767596407054,
#  23.406197827591846,
#  170.87958655837474,
#  4.348959319628333,
#  2.501513709546875,
#  175.84252718350075,
#  168.0276946280546,
#  175.46650251885143,
#  9.53880498512518,
#  163.47653684641622,
#  11.420244560018624,
#  161.7292815798832,
#  15.882691794607606,
#  4.584996745948512,
#  159.84223436898714,
#  6.639786431169786,
#  15.882691794607606,
#  174.5584622508439,
#  3.616706248840691,
#  139.70470417464202,
#  7.0960958187083385,
#  7.622460379109064,
#  163.50688514150815,
#  176.886802749533,
#  10.77217352790942,
#  10.77217352790942]

# %%
s=0
cat=0

for i in hip_to_nose:
    s+=i
cat=s/len(hip_to_nose)

# %%
cat
# Out:
# 125.15980674279945

# %% [markdown]
# # camel pose

# %%
import os
from PIL import Image

# Folder path containing images
folder_path = "E:/capstone/Dataset/possible_Ones/bitilasana/camel"

# # List to store image data
# images = []

# # Iterate over files in the folder
# for filename in os.listdir(folder_path):
#     # Check if the file is an image (you might want to add more image extensions)
#     if filename.endswith(".jpg") or filename.endswith(".png"):
#         # Construct the full file path
#         file_path = os.path.join(folder_path, filename)
#         # Open the image using Pillow
#         img = Image.open(file_path)
#         # Append the image to the list
#         images.append(img)
#         # You can perform any processing or testing here with the image

# # Now you have all the images loaded in the 'images' list
# # You can loop through this list to perform testing or processing




# List to store image paths
image_paths = []

# Iterate over files in the folder
for filename in os.listdir(folder_path):
    # Check if the file is an image (you might want to add more image extensions)
    if filename.endswith(".jpg") or filename.endswith(".png"):
        # Construct the full file path
        file_path = os.path.join(folder_path, filename)
        # Append the file path to the list
        file_path.replace("\\",'/')
        image_paths.append(file_path)

# %%
image_paths
# Out:
# ['E:/capstone/Dataset/possible_Ones/bitilasana/camel\\0-0 (2).png',
#  'E:/capstone/Dataset/possible_Ones/bitilasana/camel\\0-0.png',
#  'E:/capstone/Dataset/possible_Ones/bitilasana/camel\\1-0.png',
#  'E:/capstone/Dataset/possible_Ones/bitilasana/camel\\10-1.png',
#  'E:/capstone/Dataset/possible_Ones/bitilasana/camel\\12-0 (2).png',
#  'E:/capstone/Dataset/possible_Ones/bitilasana/camel\\12-0.png',
#  'E:/capstone/Dataset/possible_Ones/bitilasana/camel\\13-0.png',
#  'E:/capstone/Dataset/possible_Ones/bitilasana/camel\\14-0 (2).png',
#  'E:/capstone/Dataset/possible_Ones/bitilasana/camel\\15-0 (2).png',
#  'E:/capstone/Dataset/possible_Ones/bitilasana/camel\\15-1.png',
#  'E:/capstone/Dataset/possible_Ones/bitilasana/camel\\16-0 (2).png',
#  'E:/capstone/Dataset/possible_Ones/bitilasana/camel\\16-0.png',
#  'E:/capstone/Dataset/possible_Ones/bitilasana/camel\\17-0.png',
#  'E:/capstone/Dataset/possible_Ones/bitilasana/camel\\17-1.png',
#  'E:/capstone/Dataset/possible_Ones/bitilasana/camel\\19-0.png',
#  'E:/capstone/Dataset/possible_Ones/bitilasana/camel\\19-1.png',
#  'E:/capstone/Dataset/possible_Ones/bitilasana/camel\\2-0.png',
#  'E:/capstone/Dataset/possible_Ones/bitilasana/camel\\2-1 (2).png',
#  'E:/capstone/Dataset/possible_Ones/bitilasana/camel\\24-0.png',
#  'E:/capstone/Dataset/possible_Ones/bitilasana/camel\\24-1.png',
#  'E:/capstone/Dataset/possible_Ones/bitilasana/camel\\26-1.png',
#  'E:/capstone/Dataset/possible_Ones/bitilasana/camel\\27-0.png',
#  'E:/capstone/Dataset/possible_Ones/bitilasana/camel\\27-1.png',
#  'E:/capstone/Dataset/possible_Ones/bitilasana/camel\\28-0 (2).png',
#  'E:/capstone/Dataset/possible_Ones/bitilasana/camel\\28-0.png',
#  'E:/capstone/Dataset/possible_Ones/bitilasana/camel\\29-1.png',
#  'E:/capstone/Dataset/possible_Ones/bitilasana/camel\\3-0 (2).png',
#  'E:/capstone/Dataset/possible_Ones/bitilasana/camel\\3-0.png',
#  'E:/capstone/Dataset/possible_Ones/bitilasana/camel\\3-1.png',
#  'E:/capstone/Dataset/possible_Ones/bitilasana/camel\\30-0.png',
#  'E:/capstone/Dataset/possible_Ones/bitilasana/camel\\31-0 (2).png',
#  'E:/capstone/Dataset/possible_Ones/bitilasana/camel\\31-0.png',
#  'E:/capstone/Dataset/possible_Ones/bitilasana/camel\\32-0.png',
#  'E:/capstone/Dataset/possible_Ones/bitilasana/camel\\34-1.png',
#  'E:/capstone/Dataset/possible_Ones/bitilasana/camel\\38-0.png',
#  'E:/capstone/Dataset/possible_Ones/bitilasana/camel\\39-0 (2).png',
#  'E:/capstone/Dataset/possible_Ones/bitilasana/camel\\4-1.png',
#  'E:/capstone/Dataset/possible_Ones/bitilasana/camel\\4-2 copy.png',
#  'E:/capstone/Dataset/possible_Ones/bitilasana/camel\\40-1.png',
#  'E:/capstone/Dataset/possible_Ones/bitilasana/camel\\41-0.png',
#  'E:/capstone/Dataset/possible_Ones/bitilasana/camel\\43-1.png',
#  'E:/capstone/Dataset/possible_Ones/bitilasana/camel\\44-0.png',
#  'E:/capstone/Dataset/possible_Ones/bitilasana/camel\\45-0 (2).png',
#  'E:/capstone/Dataset/possible_Ones/bitilasana/camel\\49-0.png',
#  'E:/capstone/Dataset/possible_Ones/bitilasana/camel\\49-1.png',
#  'E:/capstone/Dataset/possible_Ones/bitilasana/camel\\5-0.png',
#  'E:/capstone/Dataset/possible_Ones/bitilasana/camel\\50-0.png',
#  'E:/capstone/Dataset/possible_Ones/bitilasana/camel\\55-0.png',
#  'E:/capstone/Dataset/possible_Ones/bitilasana/camel\\55-1.png',
#  'E:/capstone/Dataset/possible_Ones/bitilasana/camel\\58-1.png',
#  'E:/capstone/Dataset/possible_Ones/bitilasana/camel\\6-1.png',
#  'E:/capstone/Dataset/possible_Ones/bitilasana/camel\\61-0.png',
#  'E:/capstone/Dataset/possible_Ones/bitilasana/camel\\62-0.png',
#  'E:/capstone/Dataset/possible_Ones/bitilasana/camel\\63-0.png',
#  'E:/capstone/Dataset/possible_Ones/bitilasana/camel\\63-1.png',
#  'E:/capstone/Dataset/possible_Ones/bitilasana/camel\\65-0.png',
#  'E:/capstone/Dataset/possible_Ones/bitilasana/camel\\68-0 (2).png',
#  'E:/capstone/Dataset/possible_Ones/bitilasana/camel\\68-0.png',
#  'E:/capstone/Dataset/possible_Ones/bitilasana/camel\\7-0.png',
#  'E:/capstone/Dataset/possible_Ones/bitilasana/camel\\7-1.png',
#  'E:/capstone/Dataset/possible_Ones/bitilasana/camel\\71-0.png',
#  'E:/capstone/Dataset/possible_Ones/bitilasana/camel\\72-0.png',
#  'E:/capstone/Dataset/possible_Ones/bitilasana/camel\\76-0.png',
#  'E:/capstone/Dataset/possible_Ones/bitilasana/camel\\77-0.png',
#  'E:/capstone/Dataset/possible_Ones/bitilasana/camel\\8-1.png',
#  'E:/capstone/Dataset/possible_Ones/bitilasana/camel\\82-0 (2).png',
#  'E:/capstone/Dataset/possible_Ones/bitilasana/camel\\83-0.png',
#  'E:/capstone/Dataset/possible_Ones/bitilasana/camel\\84-1.png',
#  'E:/capstone/Dataset/possible_Ones/bitilasana/camel\\84-6.png',
#  'E:/capstone/Dataset/possible_Ones/bitilasana/camel\\86-0.png',
#  'E:/capstone/Dataset/possible_Ones/bitilasana/camel\\87-0.png',
#  'E:/capstone/Dataset/possible_Ones/bitilasana/camel\\88-0.png',
#  'E:/capstone/Dataset/possible_Ones/bitilasana/camel\\89-0.png',
#  'E:/capstone/Dataset/possible_Ones/bitilasana/camel\\9-0.png',
#  'E:/capstone/Dataset/possible_Ones/bitilasana/camel\\90-0.png',
#  'E:/capstone/Dataset/possible_Ones/bitilasana/camel\\90-2.png',
#  'E:/capstone/Dataset/possible_Ones/bitilasana/camel\\93-0.png',
#  'E:/capstone/Dataset/possible_Ones/bitilasana/camel\\93-1.png',
#  'E:/capstone/Dataset/possible_Ones/bitilasana/camel\\94-0.png',
#  'E:/capstone/Dataset/possible_Ones/bitilasana/camel\\98-0.png']

# %% [markdown]
# # testing

# %%
import csv

def angle_of_singleline(a, b):
    """ Calculate angle of a single line """
#     x_diff = point2[0] - point1[0]
#     y_diff = point2[1] - point1[1]
#     return math.degrees(math.atan2(y_diff, x_diff))

    radians = np.arctan2(b[1]-a[1],b[0]-a[0])
    angle = np.abs(radians*180/np.pi)
    if angle > 180.0:
        angle = 360-angle
    return angle
    



def calculate_angles(a,b,c):
    a = np.array(a) # First
    b = np.array(b) # Second 
    c = np.array(c) # Third
    
    radians = np.arctan2(c[1]-b[1], c[0]-b[0]) - np.arctan2(a[1]-b[1], a[0]-b[0])
    angle = np.abs(radians*180.0/np.pi)
    
    if angle > 180.0:
        angle = 360-angle
    return angle


# left_arm_data = []
# right_arm_data = []
# left_leg_data = []
# right_leg_data = []

legs=[]
hips=[]
shoulder=[]
arms=[]
hip_angle_left=[]
hip_angle_right=[]
hip_to_nose=[]

for image_path in image_paths:
#     image_path = "E:/capstone/Capstone_Project/DATASET/TEST/tree\\00000031.jpg"
    output = cv2.imread(image_path)

    image_pose = output 
    pose = pose_image
    draw = True
    display = True
    # def detectPose(image_pose, pose, draw=False, display=False):

    original_image = image_pose.copy()

    image_in_RGB = cv2.cvtColor(image_pose, cv2.COLOR_BGR2RGB)

    resultant = pose.process(image_in_RGB)
    
    if resultant.pose_landmarks and draw:    


        landmarks = resultant.pose_landmarks.landmark



    ####################################################################
        right_shoulder = [landmarks[mp_pose.PoseLandmark.RIGHT_SHOULDER.value].x,landmarks[mp_pose.PoseLandmark.RIGHT_SHOULDER.value].y] 
        left_shoulder = [landmarks[mp_pose.PoseLandmark.LEFT_SHOULDER.value].x,landmarks[mp_pose.PoseLandmark.LEFT_SHOULDER.value].y]

        right_elbow = [landmarks[mp_pose.PoseLandmark.RIGHT_ELBOW.value].x,landmarks[mp_pose.PoseLandmark.RIGHT_ELBOW.value].y]
        left_elbow = [landmarks[mp_pose.PoseLandmark.LEFT_ELBOW.value].x,landmarks[mp_pose.PoseLandmark.LEFT_ELBOW.value].y]

        right_wrist = [landmarks[mp_pose.PoseLandmark.RIGHT_WRIST.value].x,landmarks[mp_pose.PoseLandmark.RIGHT_WRIST.value].y]
        left_wrist = [landmarks[mp_pose.PoseLandmark.LEFT_WRIST.value].x,landmarks[mp_pose.PoseLandmark.LEFT_WRIST.value].y]

        right_hip = [landmarks[mp_pose.PoseLandmark.RIGHT_HIP.value].x,landmarks[mp_pose.PoseLandmark.RIGHT_HIP.value].y]
        left_hip = [landmarks[mp_pose.PoseLandmark.LEFT_HIP.value].x,landmarks[mp_pose.PoseLandmark.LEFT_HIP.value].y]


        right_knee = [landmarks[mp_pose.PoseLandmark.RIGHT_KNEE.value].x,landmarks[mp_pose.PoseLandmark.RIGHT_KNEE.value].y]
        left_knee = [landmarks[mp_pose.PoseLandmark.LEFT_KNEE.value].x,landmarks[mp_pose.PoseLandmark.LEFT_KNEE.value].y]

        right_ankle = [landmarks[mp_pose.PoseLandmark.RIGHT_ANKLE.value].x,landmarks[mp_pose.PoseLandmark.RIGHT_ANKLE.value].y]
        left_ankle = [landmarks[mp_pose.PoseLandmark.LEFT_ANKLE.value].x,landmarks[mp_pose.PoseLandmark.LEFT_ANKLE.value].y]

        
        nose = [landmarks[mp_pose.PoseLandmark.NOSE.value].x,landmarks[mp_pose.PoseLandmark.NOSE.value].y]




















    #########################################################
        # CALCULATE THE ANGLE
    #     angle_la = calculate_angles(left_wrist,left_elbow,left_shoulder)  
    #     angle_ra = calculate_angles(right_wrist,right_elbow,right_shoulder)  
    #     angle_ll = calculate_angles(left_hip,left_knee,left_ankle)  
    #     angle_rl = calculate_angles(right_hip,right_knee,right_ankle)  


        leg_1 = calculate_angles(left_ankle,left_knee,left_hip)
        leg_2 = calculate_angles(right_ankle,right_knee,right_hip)

#         hip_1 = calculate_angles(left_knee,left_hip,left_shoulder)
#         hip_2 = calculate_angles(right_knee,right_hip,right_shoulder)
        
        hip_1_1 = calculate_angles(left_knee,left_hip,nose)
        hip_2_2 = calculate_angles(right_knee,right_hip,nose)
        print("\nHIP_1: ",hip_1_1,"\tHIP_2: ",hip_2_2)

#         shoulder_1 = calculate_angles(left_hip,left_shoulder,left_elbow)
#         shoulder_2 = calculate_angles(right_hip,right_shoulder,right_elbow)
        
        arms_1 = calculate_angles(left_shoulder,left_elbow,left_wrist)
        arms_2 = calculate_angles(right_shoulder,right_elbow,right_wrist)
    
    
#         sinle_line_left = angle_of_singleline(left_hip,left_shoulder)
        
#         sinle_line_right = angle_of_singleline(right_hip,right_shoulder)
        
        
        
        sinle_line_left = angle_of_singleline(left_hip,nose)
        
        sinle_line_right = angle_of_singleline(right_hip,nose)



    #     print(angle)


    #     arms_data.append(angle)

    #     left_arm_data.append(angle_la)
    #     right_arm_data.append(angle_ra)
    #     left_leg_data.append(angle_ll)
    #     right_leg_data.append(angle_rl)

        legs.append(leg_1)
        legs.append(leg_2)
#         hips.append(hip_1)
#         hips.append(hip_2)
#         shoulder.append(shoulder_1)
#         shoulder.append(shoulder_2)
        arms.append(arms_1)
        arms.append(arms_2)
#         hip_angle_left.append(sinle_line_left )
#         hip_angle_right.append(sinle_line_right)
        hip_to_nose.append(hip_1_1)
        hip_to_nose.append(hip_2_2)



    # Sample data
    # data = [angle]

    # # Specify the file name
    # csv_file = "data.csv"

    # # Write data to CSV file
    # with open(csv_file, mode='a', newline='') as file:
    #     writer = csv.writer(file)
    #     writer.writerow(data)
# Out:
# HIP_1:  76.51815876727031 	HIP_2:  71.72583412178244
#
# HIP_1:  81.65430734703855 	HIP_2:  83.76493799933775
#
# HIP_1:  64.7848207802434 	HIP_2:  68.49626026049474
#
# HIP_1:  64.09847048444465 	HIP_2:  61.71819316296789
#
# HIP_1:  80.01068694111117 	HIP_2:  82.20090739208784
#
# HIP_1:  81.24411088246168 	HIP_2:  81.27892753258227
#
# HIP_1:  73.08566356650807 	HIP_2:  87.35825232597752
#
# HIP_1:  70.95096291308421 	HIP_2:  67.54856161975759
#
# HIP_1:  30.408447559787817 	HIP_2:  92.68299094451183
#
# HIP_1:  68.33105065931608 	HIP_2:  65.44187428078973
#
# HIP_1:  76.48743220386626 	HIP_2:  71.85019256210674
#
# HIP_1:  70.88403100243247 	HIP_2:  70.50203216062967
#
# HIP_1:  87.64367412741612 	HIP_2:  91.43615583708873
#
# HIP_1:  89.4148163226833 	HIP_2:  95.7900270697786
#
# HIP_1:  87.92929983267038 	HIP_2:  87.69213698438497
#
# HIP_1:  67.78525365100685 	HIP_2:  65.35836781555723
#
# HIP_1:  86.77348644915871 	HIP_2:  89.7574428991467
#
# HIP_1:  74.72612373909308 	HIP_2:  73.51381462422218
#
# HIP_1:  76.34737386461141 	HIP_2:  70.78374462873616
#
# HIP_1:  30.408447559787817 	HIP_2:  92.68299094451183
#
# HIP_1:  118.26969007400913 	HIP_2:  119.5430305770883
#
# HIP_1:  86.4866594490141 	HIP_2:  87.80332763647654
#
# HIP_1:  29.36696999965226 	HIP_2:  77.08778422104814
#
# HIP_1:  73.7004946070556 	HIP_2:  80.42894618176896
#
# HIP_1:  80.0920798613042 	HIP_2:  77.52563987800717
#
# HIP_1:  73.7004946070556 	HIP_2:  80.42894618176896
#
# HIP_1:  67.78525365100685 	HIP_2:  65.35836781555723
#
# HIP_1:  68.78366119959313 	HIP_2:  69.79010020293107
#
# HIP_1:  76.57511419888493 	HIP_2:  80.58382479145526
#
# HIP_1:  82.45943881059559 	HIP_2:  87.31880100148572
#
# HIP_1:  53.53191509553676 	HIP_2:  55.402043890851324
#
# HIP_1:  86.38687870362058 	HIP_2:  86.99600200600304
#
# HIP_1:  127.46655057454137 	HIP_2:  123.60475570194482
#
# HIP_1:  84.22576739142626 	HIP_2:  81.10401532036417
#
# HIP_1:  81.63343906701493 	HIP_2:  80.5621637741446
#
# HIP_1:  75.00908176921934 	HIP_2:  79.17236032154652
#
# HIP_1:  84.0785671475229 	HIP_2:  84.43686744633479
#
# HIP_1:  68.78366119959313 	HIP_2:  69.79010020293107
#
# HIP_1:  85.68427446942601 	HIP_2:  89.24394371477662
#
# HIP_1:  68.78366119959313 	HIP_2:  69.79010020293107
#
# HIP_1:  89.69789227493642 	HIP_2:  87.72221523703506
#
# HIP_1:  83.83179364206848 	HIP_2:  83.54307735751833
#
# HIP_1:  72.47688684060304 	HIP_2:  71.07708239977754
#
# HIP_1:  90.16028990562853 	HIP_2:  89.00714597644337
#
# HIP_1:  86.05108749558752 	HIP_2:  88.09765556068311
#
# HIP_1:  83.79394222358333 	HIP_2:  87.64575841545529
#
# HIP_1:  70.19719949418244 	HIP_2:  71.54131164739302
#
# HIP_1:  89.21841599127904 	HIP_2:  89.74081493102216
#
# HIP_1:  80.60598175710597 	HIP_2:  85.81834803876175
#
# HIP_1:  73.15429540990868 	HIP_2:  72.52689674825646
#
# HIP_1:  69.57163801872825 	HIP_2:  64.0127924212185
#
# HIP_1:  76.35047685869222 	HIP_2:  75.0170042426738
#
# HIP_1:  68.17319984068766 	HIP_2:  65.2969950574786
#
# HIP_1:  67.24529287943011 	HIP_2:  64.8545441830496
#
# HIP_1:  79.70415497363466 	HIP_2:  74.54673173726097
#
# HIP_1:  93.86776352431126 	HIP_2:  96.70306471861683
#
# HIP_1:  81.08952519400678 	HIP_2:  80.72488895955243
#
# HIP_1:  84.26412039402662 	HIP_2:  88.13205943783078
#
# HIP_1:  77.59422837091434 	HIP_2:  66.11655408463703
#
# HIP_1:  100.42022362620776 	HIP_2:  88.4456012895495
#
# HIP_1:  82.81037058624365 	HIP_2:  85.5509729872732
#
# HIP_1:  75.05635635765104 	HIP_2:  73.93090285500634
#
# HIP_1:  70.66834256687451 	HIP_2:  72.90425096440687
#
# HIP_1:  71.03771175698301 	HIP_2:  71.01132952704924
#
# HIP_1:  72.52345291926896 	HIP_2:  74.23111311411905
#
# HIP_1:  83.72788348928027 	HIP_2:  86.32723790399767
#
# HIP_1:  67.08505932388199 	HIP_2:  66.50751939140163
#
# HIP_1:  83.79394222358333 	HIP_2:  87.64575841545529
#
# HIP_1:  72.52345291926896 	HIP_2:  74.23111311411905
#
# HIP_1:  85.1565483817703 	HIP_2:  86.24286447112998
#
# HIP_1:  81.6368444827099 	HIP_2:  80.91405442763653
#
# HIP_1:  14.579419502160988 	HIP_2:  57.56461603926179
#
# HIP_1:  82.39096646988214 	HIP_2:  87.52507392396916
#
# HIP_1:  81.6915443405255 	HIP_2:  85.86379355447832
#
# HIP_1:  68.26748451835562 	HIP_2:  66.17875516087454
#
# HIP_1:  87.27535358558337 	HIP_2:  84.07376019624981
#
# HIP_1:  73.02635220085985 	HIP_2:  74.24284843023588
#
# HIP_1:  73.02635220085985 	HIP_2:  74.24284843023588

# %%
s=0
ARM=0
HIP=0
LEG=0
for i in arms:
    s+=i
ARM=s/len(arms)
s=0
for i in hip_to_nose:
    s+=i
HIP=s/len(hip_to_nose)
s=0
for i in legs:
    s+=i
LEG=s/len(legs)

# %%
print("ARMS:",ARM,"\nHIPS: ",HIP,"\nLEGS: ",LEG)
# Out:
# ARMS: 173.9138107366895
# HIPS:  77.90609128114043
# LEGS:  87.62639685738088

# %%
s=0
camel=0

for i in hip_to_nose:
    s+=i
camel=s/len(hip_to_nose)

# %%
camel
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 camel
#
# NameError: name 'camel' is not defined

# %%
pip install pygame
# Out:
# Requirement already satisfied: pygame in c:\users\user\anaconda3\envs\tens_old\lib\site-packages (2.5.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import cv2
import mediapipe as mp
import matplotlib.pyplot as plt
import os
from PIL import Image
from pydub import AudioSegment
from pydub.playback import play
import numpy as np
from tkinter import *
from winsound import PlaySound, SND_FILENAME, SND_LOOP, SND_ASYNC
import winsound
import pygame

# %%
pygame.mixer.init()

def callback(sv):
    if sv == "PLAY":
        play_audio()
    else:
        stop_audio()
        
def play_audio():
    pygame.mixer.init()
    pygame.mixer.music.load("C:/Users/User/Downloads/f1_team_radio_loud.wav")
    pygame.mixer.music.play(-1)  # -1 indicates looping indefinitely

def stop_audio():
    pygame.mixer.music.stop()

# %%
callback("LAY")

# %%
# !pip install tkinter
# Out:
# ERROR: Could not find a version that satisfies the requirement tkinter (from versions: none)
# ERROR: No matching distribution found for tkinter

# %% [markdown]
# # DYNAMIC SECTION

# %%
from tkinter import * 

def callback(sv):    
    if(sv=="PLAY"):
     winsound.PlaySound("C:/Users/User/Downloads/f1_team_radio_loud.wav", winsound.SND_FILENAME|SND_LOOP|SND_ASYNC)
    else:
     winsound.PlaySound(None, SND_FILENAME)


root = Tk()
entry1 = StringVar()
entry1.trace("w", lambda name, index, mode, sv=entry1: callback(sv))
e = Entry(root, textvariable=entry1)
e.pack()
root.mainloop()

# %%
landmarks[mp_pose.PoseLandmark.LEFT_SHOULDER.value]
# Out:
# x: 0.5829268097877502
# y: 0.6165787577629089
# z: -0.24847516417503357
# visibility: 0.9998975396156311

# %% [markdown]
# # ANGLE CALCULATION

# %%
# CALCULATE ANGLES

def calculate_angles(a,b,c):
    a = np.array(a) # First
    b = np.array(b) # Second 
    c = np.array(c) # Third
    
    radians = np.arctan2(c[1]-b[1], c[0]-b[0]) - np.arctan2(a[1]-b[1], a[0]-b[0])
    angle = np.abs(radians*180.0/np.pi)
    
    if angle > 180.0:
        angle = 360-angle
    return angle

# %% [markdown]
# # SOUND PRODUCTION

# %%
# !pip install pygame
# Out:
# Requirement already satisfied: pygame in c:\users\user\anaconda3\envs\tens_old\lib\site-packages (2.5.2)

# %%
# def callback(sv):    
#     if(sv=="PLAY"):
#      winsound.PlaySound("C:/Users/User/Downloads/f1_team_radio_loud.wav", winsound.SND_FILENAME|SND_LOOP|SND_ASYNC)
#     else:
#      winsound.PlaySound(None, SND_FILENAME)
from pygame import *
import pygame
pygame.mixer.init()

def play_audio():
    pygame.mixer.init()
    pygame.mixer.music.load("C:/Users/User/Downloads/f1_team_radio_loud.wav")
    pygame.mixer.music.play(-1)  # -1 indicates looping indefinitely

def stop_audio():
    pygame.mixer.music.stop()

def callback(sv):
    if sv == "PLAY":
        play_audio()
    else:
        stop_audio()

# %%
callback("PAY")

# %% [markdown]
# # adho mukha savasana

# %%
pygame.mixer.init()
def play_audio():
    pygame.mixer.init()
    sound = pygame.mixer.Sound("C:/Users/User/Downloads/f1_team_radio_loud.wav")
    if not pygame.mixer.get_busy():
        sound.play(-1)  # -1 indicates looping indefinitely

def stop_audio():
    pygame.mixer.stop()

def callback(sv):
    if sv == "PLAY":
        play_audio()
    else:
        stop_audio()
        
        
## SHOULDER PRESS


# MAKE DETECTIONS

  
cap = cv2.VideoCapture(0)


# CURL COUNTER VARIABLES

counter = 0
stage = None
audio_duration = 2
sum = 0



with mp_pose.Pose(min_detection_confidence=0.5, min_tracking_confidence=0.5) as pose :
    while cap.isOpened():
        ret, frame = cap.read()
        width = 1200
        height = 880
        dim = (width, height)

        frame = cv2.resize(frame, dim, interpolation=cv2.INTER_AREA)
        
        # DETECT STUFF AND RENDER
        
        #RECOLOR IMAGE TO RGB
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        image.flags.writeable = False
        
        # MAKE DETECTION
        results = pose.process(image)
        
        #RECOLOR BACK TO BGR
        image.flags.writeable = True
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
        
        # PLAY AUDIO ALERT
        
#         sum=0
        
        # EXTRACT LANDMARKS
        
        try:
            landmarks = results.pose_landmarks.landmark
            
            # GET COORDINATES
            right_shoulder = [landmarks[mp_pose.PoseLandmark.RIGHT_SHOULDER.value].x,landmarks[mp_pose.PoseLandmark.RIGHT_SHOULDER.value].y] 
            left_shoulder = [landmarks[mp_pose.PoseLandmark.LEFT_SHOULDER.value].x,landmarks[mp_pose.PoseLandmark.LEFT_SHOULDER.value].y]

            right_elbow = [landmarks[mp_pose.PoseLandmark.RIGHT_ELBOW.value].x,landmarks[mp_pose.PoseLandmark.RIGHT_ELBOW.value].y]
            left_elbow = [landmarks[mp_pose.PoseLandmark.LEFT_ELBOW.value].x,landmarks[mp_pose.PoseLandmark.LEFT_ELBOW.value].y]

            right_wrist = [landmarks[mp_pose.PoseLandmark.RIGHT_WRIST.value].x,landmarks[mp_pose.PoseLandmark.RIGHT_WRIST.value].y]
            left_wrist = [landmarks[mp_pose.PoseLandmark.LEFT_WRIST.value].x,landmarks[mp_pose.PoseLandmark.LEFT_WRIST.value].y]

            right_hip = [landmarks[mp_pose.PoseLandmark.RIGHT_HIP.value].x,landmarks[mp_pose.PoseLandmark.RIGHT_HIP.value].y]
            left_hip = [landmarks[mp_pose.PoseLandmark.LEFT_HIP.value].x,landmarks[mp_pose.PoseLandmark.LEFT_HIP.value].y]


            right_knee = [landmarks[mp_pose.PoseLandmark.RIGHT_KNEE.value].x,landmarks[mp_pose.PoseLandmark.RIGHT_KNEE.value].y]
            left_knee = [landmarks[mp_pose.PoseLandmark.LEFT_KNEE.value].x,landmarks[mp_pose.PoseLandmark.LEFT_KNEE.value].y]

            right_ankle = [landmarks[mp_pose.PoseLandmark.RIGHT_ANKLE.value].x,landmarks[mp_pose.PoseLandmark.RIGHT_ANKLE.value].y]
            left_ankle = [landmarks[mp_pose.PoseLandmark.LEFT_ANKLE.value].x,landmarks[mp_pose.PoseLandmark.LEFT_ANKLE.value].y]


            nose = [landmarks[mp_pose.PoseLandmark.NOSE.value].x,landmarks[mp_pose.PoseLandmark.NOSE.value].y]

            
            # CALCULATE THE ANGLE
            lower_body_1 = calculate_angles(left_ankle,left_knee,left_hip)
            lower_body_2 = calculate_angles(right_ankle,right_knee,right_hip)

            middle_body_1 = calculate_angles(left_knee,left_hip,left_shoulder)
            middle_body_2 = calculate_angles(right_knee,right_hip,right_shoulder)

            upper_body_1 = calculate_angles(left_hip,left_shoulder,left_wrist)
            upper_body_2 = calculate_angles(right_hip,right_shoulder,right_wrist)
            
            
            # VISUALIZE ANGLE
            cv2.putText(image,str(lower_body_1),
                       tuple(np.multiply(left_knee, [1200,880]).astype(int)),
                            cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255,255,255), 2, cv2.LINE_AA
                       )
            cv2.putText(image,str(lower_body_2),
                       tuple(np.multiply(right_knee, [1200,880]).astype(int)),
                            cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255,255,255), 2, cv2.LINE_AA
                       )
            cv2.putText(image,str(middle_body_1),
                       tuple(np.multiply(left_hip, [1200,880]).astype(int)),
                            cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255,255,255), 2, cv2.LINE_AA
                       )
            cv2.putText(image,str(middle_body_2),
                       tuple(np.multiply(right_hip, [1200,880]).astype(int)),
                            cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255,255,255), 2, cv2.LINE_AA
                       )
            cv2.putText(image,str(upper_body_1),
                       tuple(np.multiply(left_shoulder, [1200,880]).astype(int)),
                            cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255,255,255), 2, cv2.LINE_AA
                       )
            cv2.putText(image,str(upper_body_2),
                       tuple(np.multiply(right_shoulder, [1200,880]).astype(int)),
                            cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255,255,255), 2, cv2.LINE_AA
                       )
            
#             CHECKING CONDITIONS

            lb = (lower_body_1 + lower_body_2)/2
            mb = (middle_body_1 + middle_body_2)/2
            ub = (upper_body_1 + upper_body_2)/2
            sum=0
            for it in landmarks:
                sum+=it.visibility
            avg=sum/len(landmarks)
            avg="{0:.4f}".format(avg)
            avg=str(avg)

#             print(avg)
#             print(sum)
            
#             if angle > 160 and angle2 < 110:
#                 song = AudioSegment.from_mp3("E:/capstone/alert.mp3")
#                 play_audio("E:/capstone/alert.mp3",audio_duration)
#                 stage="down"
#             if angle < 110 and angle2 > 150:
            if((lb>=160 and lb<=180) and (mb>=50 and mb<=90) and (ub>=150 and ub<=180)):
#                 if stage == "down":
                stop_audio()
                stage="OK"
                counter+=1
                print(stage)
#                 pygame.mixer.music.stop()

#                 callback("NO")
#                 winsound.PlaySound(None, SND_FILENAME)
                    

            else:
                
                stage="INCORRECT"
                play_audio()
#                 pygame.mixer.init()
#                 pygame.mixer.music.load("C:/Users/User/Downloads/f1_team_radio_loud.wav")
#                 pygame.mixer.music.play(-1)  # -1 indicates looping indefinitely
#                 callback("PLAY")
#                 winsound.PlaySound("C:/Users/User/Downloads/f1_team_radio_loud.wav", winsound.SND_FILENAME|SND_LOOP|SND_ASYNC)

#                 print(stage)
#             print(landmarks)
        except:
            avg="0"
            pass
        
#         sum=0
#         for it in landmarks:
#             sum+=it.visibility
#         avg=sum/33
#         avg="{0:.3f}".format(avg)
#         avg=str(avg)
        
#         print(avg)

        
        # RENDER CURL COUNTER
        # setup status box
        
        cv2.rectangle(image,(0,0), (255,93), (245,117,16), -1)
        
        # REP DATA
        
#         cv2.putText(image, 'REPS', (15,12),
#                     cv2.FONT_HERSHEY_SIMPLEX, 0.5 , (0,0,0), 1, cv2.LINE_AA)
#         cv2.putText(image, str(counter),
#                    (10,60),
#                    cv2.FONT_HERSHEY_SIMPLEX, 2, (255,255,255), 2, cv2.LINE_AA)
        
        
        
         # STAGE DATA
        
        cv2.putText(image, 'STAGE-> ', (1,32),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.5 , (0,0,0), 1, cv2.LINE_AA)
        cv2.putText(image, stage,
                   (75,40),
                   cv2.FONT_HERSHEY_SIMPLEX, 1, (255,255,255), 2, cv2.LINE_AA)
        cv2.putText(image, 'CONF.-> ', (1,78),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.5 , (0,0,0), 1, cv2.LINE_AA)
        cv2.putText(image, avg,
                   (90,80),
                   cv2.FONT_HERSHEY_SIMPLEX, 1, (255,255,255), 2, cv2.LINE_AA)
        
        
        
        
#         print(results)

        # RENDER DETECTIONS
        mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_pose.POSE_CONNECTIONS,
                                 mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=2),
                                 mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2),
                                 )
        
        
        cv2.imshow('MediaPipe Feed', image)

        if cv2.waitKey(10) & 0xFF == ord('q'):
#             callback("NO")
#             pygame.mixer.music.stop()
            stop_audio()

            break
    cap.release()
    cv2.destroyAllWindows()

# %%
sum=0
for it in landmarks:
    sum+=it.visibility
avg=sum/33

print(avg)
# Out:
# 0.6698434330297239

# %%
len(landmarks)
# Out:
# 33

# %% [markdown]
# # ardha uttanasana

# %%
pygame.mixer.init()
def play_audio():
    pygame.mixer.init()
    sound = pygame.mixer.Sound("C:/Users/User/Downloads/f1_team_radio_loud.wav")
    if not pygame.mixer.get_busy():
        sound.play(-1)  # -1 indicates looping indefinitely

def stop_audio():
    pygame.mixer.stop()

def callback(sv):
    if sv == "PLAY":
        play_audio()
    else:
        stop_audio()
        
        

cap = cv2.VideoCapture(0)


# CURL COUNTER VARIABLES

counter = 0
stage = None
audio_duration = 2
sum=0


with mp_pose.Pose(min_detection_confidence=0.5, min_tracking_confidence=0.5) as pose :
    while cap.isOpened():
        ret, frame = cap.read()
        width = 1200
        height = 880
        dim = (width, height)

        frame = cv2.resize(frame, dim, interpolation=cv2.INTER_AREA)
        # DETECT STUFF AND RENDER
        
        #RECOLOR IMAGE TO RGB
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        image.flags.writeable = False
        
        # MAKE DETECTION
        results = pose.process(image)
        
        #RECOLOR BACK TO BGR
        image.flags.writeable = True
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
        
      
        
        # EXTRACT LANDMARKS
        
        try:
            landmarks = results.pose_landmarks.landmark
            
            # GET COORDINATES
            right_shoulder = [landmarks[mp_pose.PoseLandmark.RIGHT_SHOULDER.value].x,landmarks[mp_pose.PoseLandmark.RIGHT_SHOULDER.value].y] 
            left_shoulder = [landmarks[mp_pose.PoseLandmark.LEFT_SHOULDER.value].x,landmarks[mp_pose.PoseLandmark.LEFT_SHOULDER.value].y]

            right_elbow = [landmarks[mp_pose.PoseLandmark.RIGHT_ELBOW.value].x,landmarks[mp_pose.PoseLandmark.RIGHT_ELBOW.value].y]
            left_elbow = [landmarks[mp_pose.PoseLandmark.LEFT_ELBOW.value].x,landmarks[mp_pose.PoseLandmark.LEFT_ELBOW.value].y]

            right_wrist = [landmarks[mp_pose.PoseLandmark.RIGHT_WRIST.value].x,landmarks[mp_pose.PoseLandmark.RIGHT_WRIST.value].y]
            left_wrist = [landmarks[mp_pose.PoseLandmark.LEFT_WRIST.value].x,landmarks[mp_pose.PoseLandmark.LEFT_WRIST.value].y]

            right_hip = [landmarks[mp_pose.PoseLandmark.RIGHT_HIP.value].x,landmarks[mp_pose.PoseLandmark.RIGHT_HIP.value].y]
            left_hip = [landmarks[mp_pose.PoseLandmark.LEFT_HIP.value].x,landmarks[mp_pose.PoseLandmark.LEFT_HIP.value].y]


            right_knee = [landmarks[mp_pose.PoseLandmark.RIGHT_KNEE.value].x,landmarks[mp_pose.PoseLandmark.RIGHT_KNEE.value].y]
            left_knee = [landmarks[mp_pose.PoseLandmark.LEFT_KNEE.value].x,landmarks[mp_pose.PoseLandmark.LEFT_KNEE.value].y]

            right_ankle = [landmarks[mp_pose.PoseLandmark.RIGHT_ANKLE.value].x,landmarks[mp_pose.PoseLandmark.RIGHT_ANKLE.value].y]
            left_ankle = [landmarks[mp_pose.PoseLandmark.LEFT_ANKLE.value].x,landmarks[mp_pose.PoseLandmark.LEFT_ANKLE.value].y]


            nose = [landmarks[mp_pose.PoseLandmark.NOSE.value].x,landmarks[mp_pose.PoseLandmark.NOSE.value].y]

            
            # CALCULATE THE ANGLE
            leg_1 = calculate_angles(left_ankle,left_knee,left_hip)
            leg_2 = calculate_angles(right_ankle,right_knee,right_hip)

            hip_1 = calculate_angles(left_knee,left_hip,left_shoulder)
            hip_2 = calculate_angles(right_knee,right_hip,right_shoulder)

            shoulder_1 = calculate_angles(left_hip,left_shoulder,left_elbow)
            shoulder_2 = calculate_angles(right_hip,right_shoulder,right_elbow)

            arms_1 = calculate_angles(left_shoulder,left_elbow,left_wrist)
            arms_2 = calculate_angles(right_shoulder,right_elbow,right_wrist)
            
            
            # VISUALIZE ANGLE
            cv2.putText(image,str(leg_1),
                       tuple(np.multiply(left_knee, [1200,880]).astype(int)),
                            cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255,255,255), 2, cv2.LINE_AA
                       )
            cv2.putText(image,str(leg_2),
                       tuple(np.multiply(right_knee, [1200,880]).astype(int)),
                            cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255,255,255), 2, cv2.LINE_AA
                       )
            cv2.putText(image,str(hip_1),
                       tuple(np.multiply(left_hip, [1200,880]).astype(int)),
                            cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255,255,255), 2, cv2.LINE_AA
                       )
            cv2.putText(image,str(hip_2),
                       tuple(np.multiply(right_hip, [1200,880]).astype(int)),
                            cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255,255,255), 2, cv2.LINE_AA
                       )
            cv2.putText(image,str(shoulder_1),
                       tuple(np.multiply(left_shoulder, [1200,880]).astype(int)),
                            cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255,255,255), 2, cv2.LINE_AA
                       )
            cv2.putText(image,str(shoulder_2),
                       tuple(np.multiply(right_shoulder, [1200,880]).astype(int)),
                            cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255,255,255), 2, cv2.LINE_AA
                       )
            cv2.putText(image,str(arms_1),
                       tuple(np.multiply(left_elbow, [1200,880]).astype(int)),
                            cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255,255,255), 2, cv2.LINE_AA
                       )
            cv2.putText(image,str(arms_2),
                       tuple(np.multiply(right_elbow, [1200,880]).astype(int)),
                            cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255,255,255), 2, cv2.LINE_AA
                       )
            
            
            
#             CHECKING CONDITIONS

            arms = (arms_1 + arms_2)/2
            shoulder = (shoulder_1 + shoulder_2)/2
            hips = (hip_1 + hip_2)/2
            legs = (leg_1 + leg_2)/2

            sum=0
            for it in landmarks:
                sum+=it.visibility
            avg=sum/len(landmarks)
            avg="{0:.4f}".format(avg)
            avg=str(avg)
                
            
            

            if((arms>=140 and arms<=180) and (shoulder>=75 and shoulder<=105) and (hips>=40 and hips<=70) and (legs>=150 and legs<=180)):
                stop_audio()

                stage="OK"
                counter+=1
                print(stage)
            else:
                stage="INCORRECT"
                play_audio()
               
        except:
            avg="0"
            pass
        
        
        # setup status box
        
        cv2.rectangle(image,(0,0), (255,93), (245,117,16), -1)


        

        
        
         # STAGE DATA
        
        cv2.putText(image, 'STAGE-> ', (1,32),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.5 , (0,0,0), 1, cv2.LINE_AA)
        cv2.putText(image, stage,
                   (75,40),
                   cv2.FONT_HERSHEY_SIMPLEX, 1, (255,255,255), 2, cv2.LINE_AA)
        cv2.putText(image, 'CONF.-> ', (1,78),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.5 , (0,0,0), 1, cv2.LINE_AA)
        cv2.putText(image, avg,
                   (90,80),
                   cv2.FONT_HERSHEY_SIMPLEX, 1, (255,255,255), 2, cv2.LINE_AA)
        
        
        
        
#         print(results)

        # RENDER DETECTIONS
        mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_pose.POSE_CONNECTIONS,
                                 mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=2),
                                 mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2),
                                 )
        
        
        cv2.imshow('MediaPipe Feed', image)

        if cv2.waitKey(10) & 0xFF == ord('q'):
            stop_audio()
            break
    cap.release()
    cv2.destroyAllWindows()
# Out:
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK

# %% [markdown]
# # BALASANA

# %%
pygame.mixer.init()
def play_audio():
    pygame.mixer.init()
    sound = pygame.mixer.Sound("C:/Users/User/Downloads/f1_team_radio_loud.wav")
    if not pygame.mixer.get_busy():
        sound.play(-1)  # -1 indicates looping indefinitely

def stop_audio():
    pygame.mixer.stop()

def callback(sv):
    if sv == "PLAY":
        play_audio()
    else:
        stop_audio()
        
    
    
    

cap = cv2.VideoCapture(0)


# CURL COUNTER VARIABLES

counter = 0
stage = None
audio_duration = 2
sum = 0



with mp_pose.Pose(min_detection_confidence=0.5, min_tracking_confidence=0.5) as pose :
    while cap.isOpened():
        ret, frame = cap.read()
        width = 1200
        height = 880
        dim = (width, height)

        frame = cv2.resize(frame, dim, interpolation=cv2.INTER_AREA)
        # DETECT STUFF AND RENDER
        
        #RECOLOR IMAGE TO RGB
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        image.flags.writeable = False
        
        # MAKE DETECTION
        results = pose.process(image)
        
        #RECOLOR BACK TO BGR
        image.flags.writeable = True
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
        
    
        
        # EXTRACT LANDMARKS
        
        try:
            landmarks = results.pose_landmarks.landmark
            
            # GET COORDINATES
            right_shoulder = [landmarks[mp_pose.PoseLandmark.RIGHT_SHOULDER.value].x,landmarks[mp_pose.PoseLandmark.RIGHT_SHOULDER.value].y] 
            left_shoulder = [landmarks[mp_pose.PoseLandmark.LEFT_SHOULDER.value].x,landmarks[mp_pose.PoseLandmark.LEFT_SHOULDER.value].y]

            right_elbow = [landmarks[mp_pose.PoseLandmark.RIGHT_ELBOW.value].x,landmarks[mp_pose.PoseLandmark.RIGHT_ELBOW.value].y]
            left_elbow = [landmarks[mp_pose.PoseLandmark.LEFT_ELBOW.value].x,landmarks[mp_pose.PoseLandmark.LEFT_ELBOW.value].y]

            right_wrist = [landmarks[mp_pose.PoseLandmark.RIGHT_WRIST.value].x,landmarks[mp_pose.PoseLandmark.RIGHT_WRIST.value].y]
            left_wrist = [landmarks[mp_pose.PoseLandmark.LEFT_WRIST.value].x,landmarks[mp_pose.PoseLandmark.LEFT_WRIST.value].y]

            right_hip = [landmarks[mp_pose.PoseLandmark.RIGHT_HIP.value].x,landmarks[mp_pose.PoseLandmark.RIGHT_HIP.value].y]
            left_hip = [landmarks[mp_pose.PoseLandmark.LEFT_HIP.value].x,landmarks[mp_pose.PoseLandmark.LEFT_HIP.value].y]


            right_knee = [landmarks[mp_pose.PoseLandmark.RIGHT_KNEE.value].x,landmarks[mp_pose.PoseLandmark.RIGHT_KNEE.value].y]
            left_knee = [landmarks[mp_pose.PoseLandmark.LEFT_KNEE.value].x,landmarks[mp_pose.PoseLandmark.LEFT_KNEE.value].y]

            right_ankle = [landmarks[mp_pose.PoseLandmark.RIGHT_ANKLE.value].x,landmarks[mp_pose.PoseLandmark.RIGHT_ANKLE.value].y]
            left_ankle = [landmarks[mp_pose.PoseLandmark.LEFT_ANKLE.value].x,landmarks[mp_pose.PoseLandmark.LEFT_ANKLE.value].y]


            nose = [landmarks[mp_pose.PoseLandmark.NOSE.value].x,landmarks[mp_pose.PoseLandmark.NOSE.value].y]

            
            # CALCULATE THE ANGLE
            lower_body_1 = calculate_angles(left_ankle,left_knee,left_hip)
            lower_body_2 = calculate_angles(right_ankle,right_knee,right_hip)

            middle_body_1 = calculate_angles(left_knee,left_hip,left_shoulder)
            middle_body_2 = calculate_angles(right_knee,right_hip,right_shoulder)

            upper_body_1 = calculate_angles(left_shoulder,left_elbow,left_wrist)
            upper_body_2 = calculate_angles(right_shoulder,right_elbow,right_wrist)


            
            
            # VISUALIZE ANGLE
            cv2.putText(image,str(lower_body_1),
                       tuple(np.multiply(left_knee, [1200,880]).astype(int)),
                            cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255,255,255), 2, cv2.LINE_AA
                       )
            cv2.putText(image,str(lower_body_2),
                       tuple(np.multiply(right_knee, [1200,880]).astype(int)),
                            cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255,255,255), 2, cv2.LINE_AA
                       )
            cv2.putText(image,str(middle_body_1),
                       tuple(np.multiply(left_hip, [1200,880]).astype(int)),
                            cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255,255,255), 2, cv2.LINE_AA
                       )
            cv2.putText(image,str(middle_body_2),
                       tuple(np.multiply(right_hip, [1200,880]).astype(int)),
                            cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255,255,255), 2, cv2.LINE_AA
                       )
            cv2.putText(image,str(upper_body_1),
                       tuple(np.multiply(left_elbow, [1200,880]).astype(int)),
                            cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255,255,255), 2, cv2.LINE_AA
                       )
            cv2.putText(image,str(upper_body_2),
                       tuple(np.multiply(right_elbow, [1200,880]).astype(int)),
                            cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255,255,255), 2, cv2.LINE_AA
                       )
            
#             CHECKING CONDITIONS

            lb = (lower_body_1 + lower_body_2)/2
            mb = (middle_body_1 + middle_body_2)/2
            ub = (upper_body_1 + upper_body_2)/2
            sum=0
            for it in landmarks:
                sum+=it.visibility
            avg=sum/len(landmarks)
            avg="{0:.4f}".format(avg)
            avg=str(avg)            
                
            
            

            if((lb>=30 and lb<=55) and (mb>=20 and mb<=50) and (ub>=140 and ub<=170)):
                stop_audio()
                stage="OK"
                counter+=1
                print(stage)
            else:
                stage="INCORRECT"
                play_audio()
#             print(landmarks)
        except:
            avg="0"
            pass
        
        
        # setup status box
        
#         cv2.rectangle(image,(0,0), (455,73), (245,117,16), -1)
        cv2.rectangle(image,(0,0), (255,93), (245,117,16), -1)
        

        
        
        
         # STAGE DATA
        
        cv2.putText(image, 'STAGE-> ', (1,32),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.5 , (0,0,0), 1, cv2.LINE_AA)
        cv2.putText(image, stage,
                   (75,40),
                   cv2.FONT_HERSHEY_SIMPLEX, 1, (255,255,255), 2, cv2.LINE_AA)
        cv2.putText(image, 'CONF.-> ', (1,78),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.5 , (0,0,0), 1, cv2.LINE_AA)
        cv2.putText(image, avg,
                   (90,80),
                   cv2.FONT_HERSHEY_SIMPLEX, 1, (255,255,255), 2, cv2.LINE_AA)
        
        
        
        
#         print(results)

        # RENDER DETECTIONS
        mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_pose.POSE_CONNECTIONS,
                                 mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=2),
                                 mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2),
                                 )
        
        
        cv2.imshow('MediaPipe Feed', image)

        if cv2.waitKey(10) & 0xFF == ord('q'):
            stop_audio()
            break
    cap.release()
    cv2.destroyAllWindows()

# %% [markdown]
# # bhujangasana

# %%
pygame.mixer.init()
def play_audio():
    pygame.mixer.init()
    sound = pygame.mixer.Sound("C:/Users/User/Downloads/f1_team_radio_loud.wav")
    if not pygame.mixer.get_busy():
        sound.play(-1)  # -1 indicates looping indefinitely

def stop_audio():
    pygame.mixer.stop()

def callback(sv):
    if sv == "PLAY":
        play_audio()
    else:
        stop_audio()



        
cap = cv2.VideoCapture(0)


# CURL COUNTER VARIABLES

counter = 0
stage = None
audio_duration = 2
sum = 0



with mp_pose.Pose(min_detection_confidence=0.5, min_tracking_confidence=0.5) as pose :
    while cap.isOpened():
        ret, frame = cap.read()
        width = 1200
        height = 880
        dim = (width, height)

        frame = cv2.resize(frame, dim, interpolation=cv2.INTER_AREA)
        # DETECT STUFF AND RENDER
        
        #RECOLOR IMAGE TO RGB
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        image.flags.writeable = False
        
        # MAKE DETECTION
        results = pose.process(image)
        
        #RECOLOR BACK TO BGR
        image.flags.writeable = True
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
        
      
        
        # EXTRACT LANDMARKS
        
        try:
            landmarks = results.pose_landmarks.landmark
            
            # GET COORDINATES
            right_shoulder = [landmarks[mp_pose.PoseLandmark.RIGHT_SHOULDER.value].x,landmarks[mp_pose.PoseLandmark.RIGHT_SHOULDER.value].y] 
            left_shoulder = [landmarks[mp_pose.PoseLandmark.LEFT_SHOULDER.value].x,landmarks[mp_pose.PoseLandmark.LEFT_SHOULDER.value].y]

            right_elbow = [landmarks[mp_pose.PoseLandmark.RIGHT_ELBOW.value].x,landmarks[mp_pose.PoseLandmark.RIGHT_ELBOW.value].y]
            left_elbow = [landmarks[mp_pose.PoseLandmark.LEFT_ELBOW.value].x,landmarks[mp_pose.PoseLandmark.LEFT_ELBOW.value].y]

            right_wrist = [landmarks[mp_pose.PoseLandmark.RIGHT_WRIST.value].x,landmarks[mp_pose.PoseLandmark.RIGHT_WRIST.value].y]
            left_wrist = [landmarks[mp_pose.PoseLandmark.LEFT_WRIST.value].x,landmarks[mp_pose.PoseLandmark.LEFT_WRIST.value].y]

            right_hip = [landmarks[mp_pose.PoseLandmark.RIGHT_HIP.value].x,landmarks[mp_pose.PoseLandmark.RIGHT_HIP.value].y]
            left_hip = [landmarks[mp_pose.PoseLandmark.LEFT_HIP.value].x,landmarks[mp_pose.PoseLandmark.LEFT_HIP.value].y]


            right_knee = [landmarks[mp_pose.PoseLandmark.RIGHT_KNEE.value].x,landmarks[mp_pose.PoseLandmark.RIGHT_KNEE.value].y]
            left_knee = [landmarks[mp_pose.PoseLandmark.LEFT_KNEE.value].x,landmarks[mp_pose.PoseLandmark.LEFT_KNEE.value].y]

            right_ankle = [landmarks[mp_pose.PoseLandmark.RIGHT_ANKLE.value].x,landmarks[mp_pose.PoseLandmark.RIGHT_ANKLE.value].y]
            left_ankle = [landmarks[mp_pose.PoseLandmark.LEFT_ANKLE.value].x,landmarks[mp_pose.PoseLandmark.LEFT_ANKLE.value].y]


            nose = [landmarks[mp_pose.PoseLandmark.NOSE.value].x,landmarks[mp_pose.PoseLandmark.NOSE.value].y]

            
            # CALCULATE THE ANGLE
            lower_body_1 = calculate_angles(left_ankle,left_knee,left_hip)
            lower_body_2 = calculate_angles(right_ankle,right_knee,right_hip)

            middle_body_1 = calculate_angles(left_knee,left_hip,left_shoulder)
            middle_body_2 = calculate_angles(right_knee,right_hip,right_shoulder)

            upper_body_1 = calculate_angles(left_shoulder,left_elbow,left_wrist)
            upper_body_2 = calculate_angles(right_shoulder,right_elbow,right_wrist)


            
            
            # VISUALIZE ANGLE
            cv2.putText(image,str(lower_body_1),
                       tuple(np.multiply(left_knee, [1200,880]).astype(int)),
                            cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255,255,255), 2, cv2.LINE_AA
                       )
            cv2.putText(image,str(lower_body_2),
                       tuple(np.multiply(right_knee, [1200,880]).astype(int)),
                            cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255,255,255), 2, cv2.LINE_AA
                       )
            cv2.putText(image,str(middle_body_1),
                       tuple(np.multiply(left_hip, [1200,880]).astype(int)),
                            cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255,255,255), 2, cv2.LINE_AA
                       )
            cv2.putText(image,str(middle_body_2),
                       tuple(np.multiply(right_hip, [1200,880]).astype(int)),
                            cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255,255,255), 2, cv2.LINE_AA
                       )
            cv2.putText(image,str(upper_body_1),
                       tuple(np.multiply(left_elbow, [1200,880]).astype(int)),
                            cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255,255,255), 2, cv2.LINE_AA
                       )
            cv2.putText(image,str(upper_body_2),
                       tuple(np.multiply(right_elbow, [1200,880]).astype(int)),
                            cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255,255,255), 2, cv2.LINE_AA
                       )
            
#             CHECKING CONDITIONS

            lb = (lower_body_1 + lower_body_2)/2
            mb = (middle_body_1 + middle_body_2)/2
            ub = (upper_body_1 + upper_body_2)/2
            sum=0
            for it in landmarks:
                sum+=it.visibility
            avg=sum/len(landmarks)
            avg="{0:.4f}".format(avg)
            avg=str(avg)
                

            if((lb>=150 and lb<=180) and (mb>=100 and mb<=150) and (ub>=130 and ub<=180)):
                stop_audio()
                stage="OK"
                counter+=1
                print(stage)
            else:
                stage="INCORRECT"
                play_audio()
#             print(landmarks)
        except:
            avg="0"
            pass
        
        
        # RENDER CURL COUNTER
        # setup status box
        
        cv2.rectangle(image,(0,0), (255,93), (245,117,16), -1)

        
        
        
         # STAGE DATA
        
        cv2.putText(image, 'STAGE-> ', (1,32),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.5 , (0,0,0), 1, cv2.LINE_AA)
        cv2.putText(image, stage,
                   (75,40),
                   cv2.FONT_HERSHEY_SIMPLEX, 1, (255,255,255), 2, cv2.LINE_AA)
        cv2.putText(image, 'CONF.-> ', (1,78),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.5 , (0,0,0), 1, cv2.LINE_AA)
        cv2.putText(image, avg,
                   (90,80),
                   cv2.FONT_HERSHEY_SIMPLEX, 1, (255,255,255), 2, cv2.LINE_AA)
        
        
        
        
#         print(results)

        # RENDER DETECTIONS
        mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_pose.POSE_CONNECTIONS,
                                 mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=2),
                                 mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2),
                                 )
        
        
        cv2.imshow('MediaPipe Feed', image)

        if cv2.waitKey(10) & 0xFF == ord('q'):
            stop_audio()
            break
    cap.release()
    cv2.destroyAllWindows()
# Out:
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK
# OK

# %% [markdown]
# # setu bandha sarvangasana

# %%
pygame.mixer.init()
def play_audio():
    pygame.mixer.init()
    sound = pygame.mixer.Sound("C:/Users/User/Downloads/f1_team_radio_loud.wav")
    if not pygame.mixer.get_busy():
        sound.play(-1)  # -1 indicates looping indefinitely

def stop_audio():
    pygame.mixer.stop()

def callback(sv):
    if sv == "PLAY":
        play_audio()
    else:
        stop_audio()
        


cap = cv2.VideoCapture(0)


# CURL COUNTER VARIABLES

counter = 0
stage = None
audio_duration = 2
sum = 0


with mp_pose.Pose(min_detection_confidence=0.5, min_tracking_confidence=0.5) as pose :
    while cap.isOpened():
        ret, frame = cap.read()
        width = 1200
        height = 880
        dim = (width, height)

        frame = cv2.resize(frame, dim, interpolation=cv2.INTER_AREA)
        # DETECT STUFF AND RENDER
        
        #RECOLOR IMAGE TO RGB
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        image.flags.writeable = False
        
        # MAKE DETECTION
        results = pose.process(image)
        
        #RECOLOR BACK TO BGR
        image.flags.writeable = True
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
        

        
        # EXTRACT LANDMARKS
        
        try:
            landmarks = results.pose_landmarks.landmark
            
            # GET COORDINATES
            right_shoulder = [landmarks[mp_pose.PoseLandmark.RIGHT_SHOULDER.value].x,landmarks[mp_pose.PoseLandmark.RIGHT_SHOULDER.value].y] 
            left_shoulder = [landmarks[mp_pose.PoseLandmark.LEFT_SHOULDER.value].x,landmarks[mp_pose.PoseLandmark.LEFT_SHOULDER.value].y]

            right_elbow = [landmarks[mp_pose.PoseLandmark.RIGHT_ELBOW.value].x,landmarks[mp_pose.PoseLandmark.RIGHT_ELBOW.value].y]
            left_elbow = [landmarks[mp_pose.PoseLandmark.LEFT_ELBOW.value].x,landmarks[mp_pose.PoseLandmark.LEFT_ELBOW.value].y]

            right_wrist = [landmarks[mp_pose.PoseLandmark.RIGHT_WRIST.value].x,landmarks[mp_pose.PoseLandmark.RIGHT_WRIST.value].y]
            left_wrist = [landmarks[mp_pose.PoseLandmark.LEFT_WRIST.value].x,landmarks[mp_pose.PoseLandmark.LEFT_WRIST.value].y]

            right_hip = [landmarks[mp_pose.PoseLandmark.RIGHT_HIP.value].x,landmarks[mp_pose.PoseLandmark.RIGHT_HIP.value].y]
            left_hip = [landmarks[mp_pose.PoseLandmark.LEFT_HIP.value].x,landmarks[mp_pose.PoseLandmark.LEFT_HIP.value].y]


            right_knee = [landmarks[mp_pose.PoseLandmark.RIGHT_KNEE.value].x,landmarks[mp_pose.PoseLandmark.RIGHT_KNEE.value].y]
            left_knee = [landmarks[mp_pose.PoseLandmark.LEFT_KNEE.value].x,landmarks[mp_pose.PoseLandmark.LEFT_KNEE.value].y]

            right_ankle = [landmarks[mp_pose.PoseLandmark.RIGHT_ANKLE.value].x,landmarks[mp_pose.PoseLandmark.RIGHT_ANKLE.value].y]
            left_ankle = [landmarks[mp_pose.PoseLandmark.LEFT_ANKLE.value].x,landmarks[mp_pose.PoseLandmark.LEFT_ANKLE.value].y]


            nose = [landmarks[mp_pose.PoseLandmark.NOSE.value].x,landmarks[mp_pose.PoseLandmark.NOSE.value].y]

            
            # CALCULATE THE ANGLE
            leg_1 = calculate_angles(left_ankle,left_knee,left_hip)
            leg_2 = calculate_angles(right_ankle,right_knee,right_hip)

            hip_1 = calculate_angles(left_knee,left_hip,left_shoulder)
            hip_2 = calculate_angles(right_knee,right_hip,right_shoulder)

            shoulder_1 = calculate_angles(left_hip,left_shoulder,left_elbow)
            shoulder_2 = calculate_angles(right_hip,right_shoulder,right_elbow)

            arms_1 = calculate_angles(left_shoulder,left_elbow,left_wrist)
            arms_2 = calculate_angles(right_shoulder,right_elbow,right_wrist)
            
            
            # VISUALIZE ANGLE
            cv2.putText(image,str(leg_1),
                       tuple(np.multiply(left_knee, [1200,880]).astype(int)),
                            cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255,255,255), 2, cv2.LINE_AA
                       )
            cv2.putText(image,str(leg_2),
                       tuple(np.multiply(right_knee, [1200,880]).astype(int)),
                            cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255,255,255), 2, cv2.LINE_AA
                       )
            cv2.putText(image,str(hip_1),
                       tuple(np.multiply(left_hip, [1200,880]).astype(int)),
                            cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255,255,255), 2, cv2.LINE_AA
                       )
            cv2.putText(image,str(hip_2),
                       tuple(np.multiply(right_hip, [1200,880]).astype(int)),
                            cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255,255,255), 2, cv2.LINE_AA
                       )
            cv2.putText(image,str(shoulder_1),
                       tuple(np.multiply(left_shoulder, [1200,880]).astype(int)),
                            cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255,255,255), 2, cv2.LINE_AA
                       )
            cv2.putText(image,str(shoulder_2),
                       tuple(np.multiply(right_shoulder, [1200,880]).astype(int)),
                            cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255,255,255), 2, cv2.LINE_AA
                       )
            cv2.putText(image,str(arms_1),
                       tuple(np.multiply(left_elbow, [1200,880]).astype(int)),
                            cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255,255,255), 2, cv2.LINE_AA
                       )
            cv2.putText(image,str(arms_2),
                       tuple(np.multiply(right_elbow, [1200,880]).astype(int)),
                            cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255,255,255), 2, cv2.LINE_AA
                       )
            
            
            
#             CHECKING CONDITIONS

            arms = (arms_1 + arms_2)/2
            shoulder = (shoulder_1 + shoulder_2)/2
            hips = (hip_1 + hip_2)/2
            legs = (leg_1 + leg_2)/2

            sum=0
            for it in landmarks:
                sum+=it.visibility
            avg=sum/len(landmarks)
            avg="{0:.4f}".format(avg)
            avg=str(avg)

            
                
            

            if((arms>=150 and arms<=180) and (shoulder>=20 and shoulder<=50) and (hips>=150 and hips<=180) and (legs>=30 and legs<=65)):
                stop_audio()
                stage="OK"
                counter+=1
#                 print(stage)
            else:
                stage="INCORRECT"
                play_audio()
#             print(landmarks)
        except:
            avg="0"
            pass
        
        
        # RENDER CURL COUNTER
        # setup status box
        
        cv2.rectangle(image,(0,0), (255,93), (245,117,16), -1)
        

        
        
        
         # STAGE DATA
        
        
        cv2.putText(image, 'STAGE-> ', (1,32),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.5 , (0,0,0), 1, cv2.LINE_AA)
        cv2.putText(image, stage,
                   (75,40),
                   cv2.FONT_HERSHEY_SIMPLEX, 1, (255,255,255), 2, cv2.LINE_AA)
        cv2.putText(image, 'CONF.-> ', (1,78),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.5 , (0,0,0), 1, cv2.LINE_AA)
        cv2.putText(image, avg,
                   (90,80),
                   cv2.FONT_HERSHEY_SIMPLEX, 1, (255,255,255), 2, cv2.LINE_AA)
        
        
        
        
#         print(results)

        # RENDER DETECTIONS
        mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_pose.POSE_CONNECTIONS,
                                 mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=2),
                                 mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2),
                                 )
        
        
        cv2.imshow('MediaPipe Feed', image)

        if cv2.waitKey(10) & 0xFF == ord('q'):
            stop_audio()
            break
    cap.release()
    cv2.destroyAllWindows()

# %% [markdown]
# # utthita trikonasana

# %%
pygame.mixer.init()
def play_audio():
    pygame.mixer.init()
    sound = pygame.mixer.Sound("C:/Users/User/Downloads/f1_team_radio_loud.wav")
    if not pygame.mixer.get_busy():
        sound.play(-1)  # -1 indicates looping indefinitely

def stop_audio():
    pygame.mixer.stop()

def callback(sv):
    if sv == "PLAY":
        play_audio()
    else:
        stop_audio()
        


cap = cv2.VideoCapture(0)


# CURL COUNTER VARIABLES

counter = 0
stage = None
audio_duration = 2
sum = 0



with mp_pose.Pose(min_detection_confidence=0.5, min_tracking_confidence=0.5) as pose :
    while cap.isOpened():
        ret, frame = cap.read()
        width = 1200
        height = 880
        dim = (width, height)

        frame = cv2.resize(frame, dim, interpolation=cv2.INTER_AREA)
        # DETECT STUFF AND RENDER
        
        #RECOLOR IMAGE TO RGB
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        image.flags.writeable = False
        
        # MAKE DETECTION
        results = pose.process(image)
        
        #RECOLOR BACK TO BGR
        image.flags.writeable = True
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
        

        
        # EXTRACT LANDMARKS
        
        try:
            landmarks = results.pose_landmarks.landmark
            
            # GET COORDINATES
            right_shoulder = [landmarks[mp_pose.PoseLandmark.RIGHT_SHOULDER.value].x,landmarks[mp_pose.PoseLandmark.RIGHT_SHOULDER.value].y] 
            left_shoulder = [landmarks[mp_pose.PoseLandmark.LEFT_SHOULDER.value].x,landmarks[mp_pose.PoseLandmark.LEFT_SHOULDER.value].y]

            right_elbow = [landmarks[mp_pose.PoseLandmark.RIGHT_ELBOW.value].x,landmarks[mp_pose.PoseLandmark.RIGHT_ELBOW.value].y]
            left_elbow = [landmarks[mp_pose.PoseLandmark.LEFT_ELBOW.value].x,landmarks[mp_pose.PoseLandmark.LEFT_ELBOW.value].y]

            right_wrist = [landmarks[mp_pose.PoseLandmark.RIGHT_WRIST.value].x,landmarks[mp_pose.PoseLandmark.RIGHT_WRIST.value].y]
            left_wrist = [landmarks[mp_pose.PoseLandmark.LEFT_WRIST.value].x,landmarks[mp_pose.PoseLandmark.LEFT_WRIST.value].y]

            right_hip = [landmarks[mp_pose.PoseLandmark.RIGHT_HIP.value].x,landmarks[mp_pose.PoseLandmark.RIGHT_HIP.value].y]
            mid_hip_pt = [(left_hip[0]+right_hip[0])/2 , (left_hip[1]+right_hip[1])/2]
            left_hip = [landmarks[mp_pose.PoseLandmark.LEFT_HIP.value].x,landmarks[mp_pose.PoseLandmark.LEFT_HIP.value].y]

            print("L: ",left_hip,"\nR: ",right_hip,"\n",mid_hip_pt)

            right_knee = [landmarks[mp_pose.PoseLandmark.RIGHT_KNEE.value].x,landmarks[mp_pose.PoseLandmark.RIGHT_KNEE.value].y]
            left_knee = [landmarks[mp_pose.PoseLandmark.LEFT_KNEE.value].x,landmarks[mp_pose.PoseLandmark.LEFT_KNEE.value].y]

            right_ankle = [landmarks[mp_pose.PoseLandmark.RIGHT_ANKLE.value].x,landmarks[mp_pose.PoseLandmark.RIGHT_ANKLE.value].y]
            left_ankle = [landmarks[mp_pose.PoseLandmark.LEFT_ANKLE.value].x,landmarks[mp_pose.PoseLandmark.LEFT_ANKLE.value].y]



            nose = [landmarks[mp_pose.PoseLandmark.NOSE.value].x,landmarks[mp_pose.PoseLandmark.NOSE.value].y]

            
            # CALCULATE THE ANGLE
#             leg_1 = calculate_angles(left_ankle,left_knee,left_hip)
#             leg_2 = calculate_angles(right_ankle,right_knee,right_hip)

#             hip_1 = calculate_angles(left_knee,left_hip,left_shoulder)
#             hip_2 = calculate_angles(right_knee,right_hip,right_shoulder)

#             shoulder_1 = calculate_angles(left_hip,left_shoulder,left_elbow)
#             shoulder_2 = calculate_angles(right_hip,right_shoulder,right_elbow)

#             arms_1 = calculate_angles(left_shoulder,left_elbow,left_wrist)
#             arms_2 = calculate_angles(right_shoulder,right_elbow,right_wrist)
            leg_1 = calculate_angles(left_ankle,left_knee,left_hip)
            leg_2 = calculate_angles(right_ankle,right_knee,right_hip)

            hip_1 = calculate_angles(left_knee,left_hip,left_shoulder)
            hip_triangle = calculate_angles(left_ankle,mid_hip_pt,right_ankle)
            hip_2 = calculate_angles(right_knee,right_hip,right_shoulder)

            shoulder_1 = calculate_angles(left_hip,left_shoulder,left_elbow)
            shoulder_2 = calculate_angles(right_hip,right_shoulder,right_elbow)

            arms_1 = calculate_angles(left_shoulder,left_elbow,left_wrist)
            arms_2 = calculate_angles(right_shoulder,right_elbow,right_wrist)

            
            
            # VISUALIZE ANGLE
            cv2.putText(image,str(leg_1),
                       tuple(np.multiply(left_knee, [1200,880]).astype(int)),
                            cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255,255,255), 2, cv2.LINE_AA
                       )
            cv2.putText(image,str(leg_2),
                       tuple(np.multiply(right_knee, [1200,880]).astype(int)),
                            cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255,255,255), 2, cv2.LINE_AA
                       )
            cv2.putText(image,str(hip_triangle),
                       tuple(np.multiply(mid_hip_pt, [1200,880]).astype(int)),
                            cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255,255,255), 2, cv2.LINE_AA
                       )
#             cv2.putText(image,str(hip_1),
#                        tuple(np.multiply(left_hip, [640,480]).astype(int)),
#                             cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255,255,255), 2, cv2.LINE_AA
#                        )
#             cv2.putText(image,str(hip_2),
#                        tuple(np.multiply(right_hip, [640,480]).astype(int)),
#                             cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255,255,255), 2, cv2.LINE_AA
#                        )
            cv2.putText(image,str(shoulder_1),
                       tuple(np.multiply(left_shoulder, [1200,880]).astype(int)),
                            cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255,255,255), 2, cv2.LINE_AA
                       )
            cv2.putText(image,str(shoulder_2),
                       tuple(np.multiply(right_shoulder, [1200,880]).astype(int)),
                            cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255,255,255), 2, cv2.LINE_AA
                       )
            cv2.putText(image,str(arms_1),
                       tuple(np.multiply(left_elbow, [1200,880]).astype(int)),
                            cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255,255,255), 2, cv2.LINE_AA
                       )
            cv2.putText(image,str(arms_2),
                       tuple(np.multiply(right_elbow, [1200,880]).astype(int)),
                            cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255,255,255), 2, cv2.LINE_AA
                       )
            
            
            
#             CHECKING CONDITIONS

            arms = (arms_1 + arms_2)/2
            shoulder = (shoulder_1 + shoulder_2)/2
#             hips = (hips_1 + hips_2)/2
            hips = hip_triangle *2
            legs = (leg_1 + leg_2)/2
            sum=0
            for it in landmarks:
                sum+=it.visibility
            avg=sum/len(landmarks)
            avg="{0:.4f}".format(avg)
            avg=str(avg)
            
                

            if((arms>=160 and arms<=180) and (shoulder>=80 and shoulder<=110) and (hips>=80 and hips<=105) and (legs>=160 and legs<=180)):
                stop_audio()
                stage="OK"
                counter+=1
                print(stage)
            else:
                stage="INCORRECT"
                play_audio()
#             print(landmarks)
        except:
            avg="0"
            pass
        
        
        # RENDER CURL COUNTER
        # setup status box
        
        cv2.rectangle(image,(0,0), (255,93), (245,117,16), -1)
        

         # STAGE DATA
        
        cv2.putText(image, 'STAGE-> ', (1,32),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.5 , (0,0,0), 1, cv2.LINE_AA)
        cv2.putText(image, stage,
                   (75,40),
                   cv2.FONT_HERSHEY_SIMPLEX, 1, (255,255,255), 2, cv2.LINE_AA)
        cv2.putText(image, 'CONF.-> ', (1,78),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.5 , (0,0,0), 1, cv2.LINE_AA)
        cv2.putText(image, avg,
                   (90,80),
                   cv2.FONT_HERSHEY_SIMPLEX, 1, (255,255,255), 2, cv2.LINE_AA)
        
        
        
        
#         print(results)

        # RENDER DETECTIONS
        mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_pose.POSE_CONNECTIONS,
                                 mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=2),
                                 mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2),
                                 )
        
        
        cv2.imshow('MediaPipe Feed', image)

        if cv2.waitKey(10) & 0xFF == ord('q'):
            stop_audio()
            break
    cap.release()
    cv2.destroyAllWindows()
# Out:
# L:  [0.6022041440010071, 1.4882351160049438]
# R:  [0.31882908940315247, 1.4819426536560059]
#  [0.45538677275180817, 1.4893885254859924]
# L:  [0.6022294759750366, 1.4969483613967896]
# R:  [0.31890156865119934, 1.490026831626892]
#  [0.4605528563261032, 1.489130973815918]
# L:  [0.6021220684051514, 1.5016571283340454]
# R:  [0.31888699531555176, 1.49410080909729]
#  [0.4605582356452942, 1.4955245852470398]
# L:  [0.6009693145751953, 1.5016039609909058]
# R:  [0.31846368312835693, 1.4942952394485474]
#  [0.46029287576675415, 1.4979761838912964]
# L:  [0.5995412468910217, 1.5016688108444214]
# R:  [0.3178320527076721, 1.4945034980773926]
#  [0.4594006836414337, 1.4980537295341492]
# L:  [0.5987042784690857, 1.502906084060669]
# R:  [0.3175123929977417, 1.4955209493637085]
#  [0.4585268199443817, 1.498594880104065]
# L:  [0.5980793237686157, 1.5034445524215698]
# R:  [0.3168308138847351, 1.4960753917694092]
#  [0.4577675461769104, 1.499490737915039]
# L:  [0.5973774790763855, 1.5041455030441284]
# R:  [0.3160085678100586, 1.4968194961547852]
#  [0.45704394578933716, 1.5001320242881775]
# L:  [0.5954511761665344, 1.5089449882507324]
# R:  [0.3140723407268524, 1.4997094869613647]
#  [0.45572490990161896, 1.5019274950027466]
# L:  [0.5953919291496277, 1.5122853517532349]
# R:  [0.3135618567466736, 1.5013649463653564]
#  [0.454506516456604, 1.5051549673080444]
# L:  [0.5948390960693359, 1.5121618509292603]
# R:  [0.3130458891391754, 1.501639485359192]
#  [0.45421890914440155, 1.5069624185562134]
# L:  [0.5946893095970154, 1.5120571851730347]
# R:  [0.31298068165779114, 1.5018186569213867]
#  [0.45390988886356354, 1.5069902539253235]
# L:  [0.5947814583778381, 1.5128124952316284]
# R:  [0.31296685338020325, 1.5027862787246704]
#  [0.4538280814886093, 1.5074217319488525]
# L:  [0.5948981642723083, 1.513641119003296]
# R:  [0.31296610832214355, 1.5037976503372192]
#  [0.45387378334999084, 1.5083050727844238]
# L:  [0.5946398377418518, 1.5144035816192627]
# R:  [0.312005877494812, 1.5039441585540771]
#  [0.4534520208835602, 1.5087926387786865]
# L:  [0.5945844054222107, 1.515162467956543]
# R:  [0.31152644753456116, 1.5042816400527954]
#  [0.4530831426382065, 1.509342610836029]
# L:  [0.5956759452819824, 1.516776442527771]
# R:  [0.31187987327575684, 1.5062355995178223]
#  [0.45323213934898376, 1.5106990337371826]
# L:  [0.5961733460426331, 1.5180070400238037]
# R:  [0.31196627020835876, 1.5075013637542725]
#  [0.4538211077451706, 1.5121389031410217]
# L:  [0.596652626991272, 1.5182421207427979]
# R:  [0.3121604025363922, 1.5080931186676025]
#  [0.45416687428951263, 1.5130500793457031]
# L:  [0.5970322489738464, 1.5185216665267944]
# R:  [0.3123704493045807, 1.5088138580322266]
#  [0.45451153814792633, 1.5135279893875122]
# L:  [0.597283124923706, 1.5187773704528809]
# R:  [0.3122367262840271, 1.5088529586791992]
#  [0.45463448762893677, 1.5136873126029968]
# L:  [0.5973907709121704, 1.5188133716583252]
# R:  [0.31213170289993286, 1.5088478326797485]
#  [0.45470741391181946, 1.5138126015663147]
# L:  [0.5973725318908691, 1.5193498134613037]
# R:  [0.3121227025985718, 1.5092346668243408]
#  [0.4547567367553711, 1.514024019241333]
# L:  [0.5973944067955017, 1.5211174488067627]
# R:  [0.31191521883010864, 1.5106221437454224]
#  [0.4546438753604889, 1.514985978603363]
# L:  [0.5974032878875732, 1.522787094116211]
# R:  [0.3117024600505829, 1.5118237733840942]
#  [0.4545484334230423, 1.5164706110954285]
# L:  [0.5988298058509827, 1.5222277641296387]
# R:  [0.31357818841934204, 1.51181960105896]
#  [0.45549073815345764, 1.5173033475875854]
# L:  [0.5998389720916748, 1.5218698978424072]
# R:  [0.31488651037216187, 1.5118305683135986]
#  [0.45685815811157227, 1.5170291662216187]
# L:  [0.5998698472976685, 1.5220835208892822]
# R:  [0.31487545371055603, 1.5120816230773926]
#  [0.4573572129011154, 1.5169757604599]
# L:  [0.5999762415885925, 1.522430181503296]
# R:  [0.31487300992012024, 1.5125410556793213]
#  [0.45737142860889435, 1.5173122882843018]
# L:  [0.5994935631752014, 1.5230754613876343]
# R:  [0.31434208154678345, 1.5129234790802002]
#  [0.457159161567688, 1.517676830291748]
# L:  [0.5992305874824524, 1.5238085985183716]
# R:  [0.31394636631011963, 1.5134644508361816]
#  [0.4567199647426605, 1.518269956111908]
# L:  [0.5995513200759888, 1.5252149105072021]
# R:  [0.31409338116645813, 1.5152276754379272]
#  [0.45666198432445526, 1.5195181369781494]
# L:  [0.5998546481132507, 1.526495337486267]
# R:  [0.3142088055610657, 1.516776442527771]
#  [0.4568800628185272, 1.5209956765174866]
# L:  [0.6001617312431335, 1.5244132280349731]
# R:  [0.31507882475852966, 1.5164313316345215]
#  [0.4574667364358902, 1.5214633345603943]
# L:  [0.6001827716827393, 1.5233595371246338]
# R:  [0.3153674006462097, 1.516229271888733]
#  [0.45776456594467163, 1.520321249961853]
# L:  [0.6001887917518616, 1.5260591506958008]
# R:  [0.31455039978027344, 1.5170950889587402]
#  [0.45736658573150635, 1.520227313041687]
# L:  [0.600322961807251, 1.5280606746673584]
# R:  [0.31428638100624084, 1.5179897546768188]
#  [0.4572375863790512, 1.5220244526863098]
# L:  [0.602120578289032, 1.5296719074249268]
# R:  [0.3152914047241211, 1.520238995552063]
#  [0.45780718326568604, 1.5241498351097107]
# L:  [0.6036744117736816, 1.5309507846832275]
# R:  [0.31627994775772095, 1.5219517946243286]
#  [0.45920026302337646, 1.5258118510246277]

# %% [markdown]
# # bitlasana

# %%
def angle_of_singleline(a, b):
    """ Calculate angle of a single line """
#     x_diff = point2[0] - point1[0]
#     y_diff = point2[1] - point1[1]
#     return math.degrees(math.atan2(y_diff, x_diff))

    radians = np.arctan2(b[1]-a[1],b[0]-a[0])
    angle = np.abs(radians*180/np.pi)
    if angle > 180.0:
        angle = 360-angle
    return angle

# %%
pygame.mixer.init()
def play_audio():
    pygame.mixer.init()
    sound = pygame.mixer.Sound("C:/Users/User/Downloads/f1_team_radio_loud.wav")
    if not pygame.mixer.get_busy():
        sound.play(-1)  # -1 indicates looping indefinitely

def stop_audio():
    pygame.mixer.stop()

def callback(sv):
    if sv == "PLAY":
        play_audio()
    else:
        stop_audio()
        
        

cap = cv2.VideoCapture(0)


# CURL COUNTER VARIABLES

counter = 0
stage = None
audio_duration = 2
sum = 0


with mp_pose.Pose(min_detection_confidence=0.5, min_tracking_confidence=0.5) as pose :
    while cap.isOpened():
        ret, frame = cap.read()
        width = 1200
        height = 880
        dim = (width, height)

        frame = cv2.resize(frame, dim, interpolation=cv2.INTER_AREA)
        # DETECT STUFF AND RENDER
        
        #RECOLOR IMAGE TO RGB
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        image.flags.writeable = False
        
        # MAKE DETECTION
        results = pose.process(image)
        
        #RECOLOR BACK TO BGR
        image.flags.writeable = True
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)

        
        # EXTRACT LANDMARKS
        
        try:
            landmarks = results.pose_landmarks.landmark
            
            # GET COORDINATES
            right_shoulder = [landmarks[mp_pose.PoseLandmark.RIGHT_SHOULDER.value].x,landmarks[mp_pose.PoseLandmark.RIGHT_SHOULDER.value].y] 
            left_shoulder = [landmarks[mp_pose.PoseLandmark.LEFT_SHOULDER.value].x,landmarks[mp_pose.PoseLandmark.LEFT_SHOULDER.value].y]

            right_elbow = [landmarks[mp_pose.PoseLandmark.RIGHT_ELBOW.value].x,landmarks[mp_pose.PoseLandmark.RIGHT_ELBOW.value].y]
            left_elbow = [landmarks[mp_pose.PoseLandmark.LEFT_ELBOW.value].x,landmarks[mp_pose.PoseLandmark.LEFT_ELBOW.value].y]

            right_wrist = [landmarks[mp_pose.PoseLandmark.RIGHT_WRIST.value].x,landmarks[mp_pose.PoseLandmark.RIGHT_WRIST.value].y]
            left_wrist = [landmarks[mp_pose.PoseLandmark.LEFT_WRIST.value].x,landmarks[mp_pose.PoseLandmark.LEFT_WRIST.value].y]

            right_hip = [landmarks[mp_pose.PoseLandmark.RIGHT_HIP.value].x,landmarks[mp_pose.PoseLandmark.RIGHT_HIP.value].y]
            left_hip = [landmarks[mp_pose.PoseLandmark.LEFT_HIP.value].x,landmarks[mp_pose.PoseLandmark.LEFT_HIP.value].y]


            right_knee = [landmarks[mp_pose.PoseLandmark.RIGHT_KNEE.value].x,landmarks[mp_pose.PoseLandmark.RIGHT_KNEE.value].y]
            left_knee = [landmarks[mp_pose.PoseLandmark.LEFT_KNEE.value].x,landmarks[mp_pose.PoseLandmark.LEFT_KNEE.value].y]

            right_ankle = [landmarks[mp_pose.PoseLandmark.RIGHT_ANKLE.value].x,landmarks[mp_pose.PoseLandmark.RIGHT_ANKLE.value].y]
            left_ankle = [landmarks[mp_pose.PoseLandmark.LEFT_ANKLE.value].x,landmarks[mp_pose.PoseLandmark.LEFT_ANKLE.value].y]


            nose = [landmarks[mp_pose.PoseLandmark.NOSE.value].x,landmarks[mp_pose.PoseLandmark.NOSE.value].y]

            
            # CALCULATE THE ANGLE
            leg_1 = calculate_angles(left_ankle,left_knee,left_hip)
            leg_2 = calculate_angles(right_ankle,right_knee,right_hip)

#             hip_1 = calculate_angles(left_knee,left_hip,left_shoulder)
#             hip_2 = calculate_angles(right_knee,right_hip,right_shoulder)

#             shoulder_1 = calculate_angles(left_hip,left_shoulder,left_elbow)
#             shoulder_2 = calculate_angles(right_hip,right_shoulder,right_elbow)
            hip_1_1 = calculate_angles(left_knee,left_hip,nose)
            hip_2_2 = calculate_angles(right_knee,right_hip,nose)

            arms_1 = calculate_angles(left_shoulder,left_elbow,left_wrist)
            arms_2 = calculate_angles(right_shoulder,right_elbow,right_wrist)
            
            
            
            sinle_line_left = angle_of_singleline(left_hip,nose)
        
            sinle_line_right = angle_of_singleline(right_hip,nose)
        
        
            # VISUALIZE ANGLE
            cv2.putText(image,str(leg_1),
                       tuple(np.multiply(left_knee, [1200,880]).astype(int)),
                            cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255,255,255), 2, cv2.LINE_AA
                       )
            cv2.putText(image,str(leg_2),
                       tuple(np.multiply(right_knee, [1200,880]).astype(int)),
                            cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255,255,255), 2, cv2.LINE_AA
                       )
            cv2.putText(image,str(hip_1_1),
                       tuple(np.multiply(left_hip, [1200,880]).astype(int)),
                            cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255,255,255), 2, cv2.LINE_AA
                       )
            cv2.putText(image,str(hip_2_2),
                       tuple(np.multiply(right_hip, [1200,880]).astype(int)),
                            cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255,255,255), 2, cv2.LINE_AA
                       )
#             cv2.putText(image,str(shoulder_1),
#                        tuple(np.multiply(left_shoulder, [1200,880]).astype(int)),
#                             cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255,255,255), 2, cv2.LINE_AA
#                        )
#             cv2.putText(image,str(shoulder_2),
#                        tuple(np.multiply(right_shoulder, [1200,880]).astype(int)),
#                             cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255,255,255), 2, cv2.LINE_AA
#                        )
            cv2.putText(image,str(arms_1),
                       tuple(np.multiply(left_elbow, [1200,880]).astype(int)),
                            cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255,255,255), 2, cv2.LINE_AA
                       )
            cv2.putText(image,str(arms_2),
                       tuple(np.multiply(right_elbow, [1200,880]).astype(int)),
                            cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255,255,255), 2, cv2.LINE_AA
                       )
            
            
            
#             CHECKING CONDITIONS

            arms = (arms_1 + arms_2)/2
#             shoulder = (shoulder_1 + shoulder_2)/2
            hips = (hip_1_1 + hip_2_2)/2
            legs = (leg_1 + leg_2)/2
            sum=0
            for it in landmarks:
                sum+=it.visibility
            avg=sum/len(landmarks)
            avg="{0:.4f}".format(avg)
            avg=str(avg)

            
                
            
            

            if((arms>=160 and arms<=180) and (hips<=90) and (legs>=70 and legs<=95)):
                stop_audio()
                stage="CAMEL"
                counter+=1
                print(stage)
            
            elif((arms>=160 and arms<=180) and (hips>=100) and (legs>=70 and legs<=95)):
                stop_audio()
                stage="CAT"
                counter+=1
                print(stage)
            
            else:
                stage="INCORRECT"
                play_audio()
#             print(landmarks)
        except:
            avg="0"
            pass
        
        
        # RENDER CURL COUNTER
        # setup status box
        
        cv2.rectangle(image,(0,0), (255,93), (245,117,16), -1)
        

        
        
        
         # STAGE DATA
        
        
        cv2.putText(image, 'STAGE-> ', (1,32),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.5 , (0,0,0), 1, cv2.LINE_AA)
        cv2.putText(image, stage,
                   (75,40),
                   cv2.FONT_HERSHEY_SIMPLEX, 1, (255,255,255), 2, cv2.LINE_AA)
        cv2.putText(image, 'CONF.-> ', (1,78),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.5 , (0,0,0), 1, cv2.LINE_AA)
        cv2.putText(image, avg,
                   (90,80),
                   cv2.FONT_HERSHEY_SIMPLEX, 1, (255,255,255), 2, cv2.LINE_AA)
        
        
        
        
#         print(results)

        # RENDER DETECTIONS
        mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_pose.POSE_CONNECTIONS,
                                 mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=2),
                                 mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2),
                                 )
        
        
        cv2.imshow('MediaPipe Feed', image)

        if cv2.waitKey(10) & 0xFF == ord('q'):
            stop_audio()
            break
    cap.release()
    cv2.destroyAllWindows()

# %%
## SHOULDER PRESS


# MAKE DETECTIONS

  
cap = cv2.VideoCapture(0)


# CURL COUNTER VARIABLES

counter = 0
stage = None
audio_duration = 2



with mp_pose.Pose(min_detection_confidence=0.5, min_tracking_confidence=0.5) as pose :
    while cap.isOpened():
        ret, frame = cap.read()
        
        # DETECT STUFF AND RENDER
        
        #RECOLOR IMAGE TO RGB
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        image.flags.writeable = False
        
        # MAKE DETECTION
        results = pose.process(image)
        
        #RECOLOR BACK TO BGR
        image.flags.writeable = True
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
        
        # PLAY AUDIO ALERT
        
        def play_audio(filename,duration):
            try:
                winsound.PlaySound(filename, winsound.SND_FILENAME)
                time.sleep(duration)
            except OSError as e:
                print("AUDIO ERROR: {e}")
        
        # EXTRACT LANDMARKS
        
        try:
            landmarks = results.pose_landmarks.landmark
            
            # GET COORDINATES
            right_shoulder = [landmarks[mp_pose.PoseLandmark.RIGHT_SHOULDER.value].x,landmarks[mp_pose.PoseLandmark.RIGHT_SHOULDER.value].y]
            left_shoulder = [landmarks[mp_pose.PoseLandmark.LEFT_SHOULDER.value].x,landmarks[mp_pose.PoseLandmark.LEFT_SHOULDER.value].y]
            left_elbow = [landmarks[mp_pose.PoseLandmark.LEFT_ELBOW.value].x,landmarks[mp_pose.PoseLandmark.LEFT_ELBOW.value].y]
            left_wrist = [landmarks[mp_pose.PoseLandmark.LEFT_WRIST.value].x,landmarks[mp_pose.PoseLandmark.LEFT_WRIST.value].y]
            left_hip = [landmarks[mp_pose.PoseLandmark.LEFT_HIP.value].x,landmarks[mp_pose.PoseLandmark.LEFT_HIP.value].y]
            
            # CALCULATE THE ANGLE
            angle = calculate_angles(right_shoulder,left_shoulder,left_elbow)
            angle2 = calculate_angles(left_shoulder,left_elbow,left_wrist)
            
            
            # VISUALIZE ANGLE
            cv2.putText(image,str(angle),
                       tuple(np.multiply(left_shoulder, [640,480]).astype(int)),
                            cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255,255,255), 2, cv2.LINE_AA
                       )
            cv2.putText(image,str(angle),
                       tuple(np.multiply(left_elbow, [640,480]).astype(int)),
                            cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255,255,255), 2, cv2.LINE_AA
                       )
            
            if angle > 160 and angle2 < 110:
#                 song = AudioSegment.from_mp3("E:/capstone/alert.mp3")
#                 play_audio("E:/capstone/alert.mp3",audio_duration)
                stage="down"
            if angle < 110 and angle2 > 150:
                if stage == "down":
                    stage="up"
                    counter+=1
                    print(counter)
#             print(landmarks)
        except:
            pass
        
        
        # RENDER CURL COUNTER
        # setup status box
        
        cv2.rectangle(image,(0,0), (255,73), (245,117,16), -1)
        
        # REP DATA
        
        cv2.putText(image, 'REPS', (15,12),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.5 , (0,0,0), 1, cv2.LINE_AA)
        cv2.putText(image, str(counter),
                   (10,60),
                   cv2.FONT_HERSHEY_SIMPLEX, 2, (255,255,255), 2, cv2.LINE_AA)
        
        
        
         # STAGE DATA
        
        cv2.putText(image, 'STAGE', (65,12),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.5 , (0,0,0), 1, cv2.LINE_AA)
        cv2.putText(image, stage,
                   (60,60),
                   cv2.FONT_HERSHEY_SIMPLEX, 2, (255,255,255), 2, cv2.LINE_AA)
        
        
        
        
#         print(results)

        # RENDER DETECTIONS
        mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_pose.POSE_CONNECTIONS,
                                 mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=2),
                                 mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2),
                                 )
        
        
        cv2.imshow('MediaPipe Feed', image)

        if cv2.waitKey(10) & 0xFF == ord('q'):
            break
    cap.release()
    cv2.destroyAllWindows()
